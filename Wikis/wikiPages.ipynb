# %% [markdown]
# # WikiPage fetcher and cleaner notebook
#
# _This notebook is dedicated towards WikiPages, fetching them and storing. From navigating the Harry Potter Fandom wiki, to downloading the pages and handling redirects._
#
# **Some imports**:

# %%
import urllib.request as urllib2
import urllib
import re
import json
import pandas as pd
import numpy as np
import os
import mwparserfromhell
import pickle

# %%
# Defining home directory
hd = os.getcwd()
print(hd)
# Out:
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis

# %% [markdown]
# ---

# %% [markdown]
# # Setup
#
# _Defining the books, and fetching the WikiPages first appearing in these books._

# %%
# Creating a list of all the wikilinks of characters and another list of in which book each character appeared first
wikilinks = []
book_nrs = []

books = ['Harry_Potter_and_the_Philosopher%27s_Stone_(character_index)', 
'Harry_Potter_and_the_Chamber_of_Secrets_(character_index)', 
'Harry_Potter_and_the_Prisoner_of_Azkaban_(character_index)',
'Harry_Potter_and_the_Goblet_of_Fire_(character_index)',
'Harry_Potter_and_the_Order_of_the_Phoenix_(character_index)',
'Harry_Potter_and_the_Half-Blood_Prince_(character_index)',
'Harry_Potter_and_the_Deathly_Hallows_(character_index)']

for book in books:

    # Get characters from each book
    baseurl = 'https://harrypotter.fandom.com/api.php?action=query&prop=revisions&rvprop=content&rvslots=main&format=json&utf8=1&titles='
    title = book
    wikiresponse_list = urllib2.urlopen(baseurl+title) # generate the complete query url
    wikihtml_list = wikiresponse_list.read().decode("utf-8") # Decode the results
    wikijson = json.loads(wikihtml_list) # Load the json 

    # Fetching the book text from json
    text = wikijson['query']['pages'][next(iter(wikijson['query']['pages']))]['revisions'][0]['slots']['main']['*']

    # Extracting all the links from the text
    links = re.findall(r"\[\[(.*?)\]\]", text)
    
    # Cleaning the links
    links_clean = [l.split('|')[0] for l in links if l.startswith(('File', 'nl:', 'Category:', 'pl:', 'ru:', 'Harry Potter and the ')) == False]
    
    # Determining book number
    book_nr = [books.index(book)+1 for i in range(len(set(links_clean)))]
    
    # Adding indication which book the character first appeared in
    wikilinks.extend(set(links_clean))
    book_nrs.extend(book_nr)

# %%
# Creating a dataframe for wikis and their respective book numbers

df_wiki = pd.DataFrame(list(zip(wikilinks,book_nrs)), columns=['wiki','book'])
len(df_wiki)
# Out:
# 810

# %%
df_wiki.head(3)
# Out:
#                                        wiki  book
# 0                                     Tufty     1
# 1                          Mirror of Erised     1
# 2  Quirinus Quirrell's first mountain troll     1

# %%
# We have a few duplicates that we need to drop. 

# We like to keep the first instance where the characters appeared
df_wiki = df_wiki.drop_duplicates(subset=['wiki'], keep='first')

len(df_wiki)
# Out:
# 789

# %% [markdown]
# ---

# %% [markdown]
# # Fetching WikiPages
#
# _Now that the dataframe is set up, we fetch the pages from the Fandom page. We also have to handle redirects and make sure we're storing the correct data. The pages are stored in their respective book's folders (book1 - book7), as text files._

# %%
# Surpress warning message for SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# Now we must loop through all the character wikis and download all of their text into files
folders = ['book1','book2','book3', 'book4', 'book5', 'book6', 'book7']
for folder in folders:
    if not os.path.exists(folder):
        os.mkdir(folder)

# Define the working directory
wd = hd

# Keep information about which links redirect -> 
# That way we can make sure the information is displayed as correctly as possible
df_wiki['alternative_wiki'] = None

for idx, row in df_wiki.iterrows():
    # Check if working directory is correct based on the next row - we want to save each character into their book's folder
    expected_path = wd + '/book' + str(row['book'])
    if os.getcwd() != expected_path:
        print("Setting working directory")
        print(expected_path)
        os.chdir(expected_path)

    # Get info about the character
    baseurl = 'https://harrypotter.fandom.com/api.php?action=query&prop=revisions&rvprop=content&rvslots=main&format=json&utf8=1&titles='
    title = urllib.parse.quote(row.wiki)
    file_name = row.wiki

    print("Book: ", row.book, " Character: ", row.wiki)

    wikiresponse = urllib2.urlopen(baseurl+title) # generate the complete query url
    wikihtml = wikiresponse.read().decode("utf-8") # Decode the results
    wikijson = json.loads(wikihtml) # Load the json 

    # Extract the page text from the json, these are located at different places 
    try:
        text = wikijson['query']['pages'][next(iter(wikijson['query']['pages']))]['revisions'][0]['slots']['main']['*']
    except:
        try:
            text = wikijson['query']['pages'][next(iter(wikijson['query']['pages']))]['revisions'][0]['*']
        except:
            if wikijson['query']['pages'][next(iter(wikijson['query']['pages']))]['missing'] == '':
                text = ''
   
    # Before we continue we must check if there is a redirect on the text - otherwise we will get no info on the character
    if text.startswith('#REDIRECT'):
        
        link = re.findall(r"\[\[(.*?)\]\]", text)
        new_title = urllib.parse.quote(link[0])
        print("WAS REDIRECTED TO: ", link[0])

        #Redo the steps above with the new_title
        wikiresponse = urllib2.urlopen(baseurl+new_title) # generate the complete query url
        wikihtml = wikiresponse.read().decode("utf-8") # Decode the results
        wikijson = json.loads(wikihtml) # Load the json

        try:
            text = wikijson['query']['pages'][next(iter(wikijson['query']['pages']))]['revisions'][0]['slots']['main']['*']
        except:
            try:
                text = wikijson['query']['pages'][next(iter(wikijson['query']['pages']))]['revisions'][0]['*']
            except:
                if wikijson['query']['pages'][next(iter(wikijson['query']['pages']))]['missing'] == '':
                    text = ''

        # Update the wiki redirects to
        df_wiki.at[idx, 'alternative_wiki'] = link[0]
        file_name = link[0]

    # Create a txt file of the text contained on the wikipage
    file = open(file_name + '.txt', "w") 
    file.write(text) 
    file.close() 

# going back to home directory
os.chdir(hd)
# Out:
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book1
# Book:  1  Character:  Tufty
# Book:  1  Character:  Mirror of Erised
# Book:  1  Character:  Quirinus Quirrell's first mountain troll
# Book:  1  Character:  Owner of the Railview Hotel
# Book:  1  Character:  George Weasley
# Book:  1  Character:  Ronald Weasley
# Book:  1  Character:  Fluffy
# Book:  1  Character:  Cliodna
# Book:  1  Character:  Arabella Figg
# Book:  1  Character:  Gellert Grindelwald
# Book:  1  Character:  Quirinus Quirrell
# Book:  1  Character:  Peter Pettigrew
# Book:  1  Character:  Neville Longbottom
# Book:  1  Character:  Vernon Dursley's secretary
# Book:  1  Character:  Circe
# Book:  1  Character:  Gordon
# Book:  1  Character:  Draco Malfoy
# Book:  1  Character:  Mandy Brocklehurst
# Book:  1  Character:  Violet-cloaked wizard
# Book:  1  Character:  Albus Dumbledore
# Book:  1  Character:  Piers Polkiss's mother
# Book:  1  Character:  Theodore Nott
# Book:  1  Character:  Argus Filch
# Book:  1  Character:  Vernon Dursley
# Book:  1  Character:  Percy Weasley
# Book:  1  Character:  Fred Weasley
# Book:  1  Character:  Quidditch
# Book:  1  Character:  Vanishing Spell
# Book:  1  Character:  Newton Scamander
# Book:  1  Character:  Millicent Bulstrode
# Book:  1  Character:  Fat Lady
# Book:  1  Character:  Justin Finch-Fletchley
# Book:  1  Character:  Hogwarts Express
# Book:  1  Character:  Gringotts Head Goblin
# Book:  1  Character:  Arthur Weasley
# Book:  1  Character:  Fang
# Book:  1  Character:  Dudley Dursley's tortoise
# Book:  1  Character:  Vincent Crabbe
# Book:  1  Character:  Platform Nine and Three-Quarters
# Book:  1  Character:  Seamus Finnigan's mother
# Book:  1  Character:  Sorting Hat
# Book:  1  Character:  Terry Boot
# Book:  1  Character:  Parvati Patil
# Book:  1  Character:  Gorilla at the Zoo
# Book:  1  Character:  Piers Polkiss
# Book:  1  Character:  McKinnon family
# Book:  1  Character:  Phillipus von Hohenheim
# Book:  1  Character:  Dean Thomas
# Book:  1  Character:  Keeper of Keys and Grounds
# Book:  1  Character:  Norberta
# Book:  1  Character:  Bones family
# Book:  1  Character:  James Potter I
# Book:  1  Character:  Sally-Anne Perks
# Book:  1  Character:  Lee Jordan
# Book:  1  Character:  Emeric the Evil
# Book:  1  Character:  Pomona Sprout
# Book:  1  Character:  Susan Bones
# Book:  1  Character:  Alberic Grunnion
# Book:  1  Character:  Lisa Turpin
# Book:  1  Character:  Trevor
# Book:  1  Character:  Bane
# Book:  1  Character:  Hermione Granger
# Book:  1  Character:  Perenelle Flamel
# Book:  1  Character:  King's Cross Station
# Book:  1  Character:  Oliver Wood
# Book:  1  Character:  Forbidden Forest
# Book:  1  Character:  Boa constrictor at the Zoo
# Book:  1  Character:  Duelling
# Book:  1  Character:  Hedwig
# Book:  1  Character:  Jim McGuffin
# Book:  1  Character:  Bathilda Bagshot
# Book:  1  Character:  Wizardkind
# Book:  1  Character:  Mr Tibbles
# Book:  1  Character:  Mr Paws
# Book:  1  Character:  Evans sisters' father
# Book:  1  Character:  Bloody Baron
# Book:  1  Character:  Quirinus Quirrell's second mountain troll
# Book:  1  Character:  Dennis
# Book:  1  Character:  Hallowe'en
# Book:  1  Character:  Nicholas de Mimsy-Porpington
# Book:  1  Character:  Severus Snape
# Book:  1  Character:  Rubeus Hagrid
# Book:  1  Character:  Alicia Spinnet
# Book:  1  Character:  Lucius Malfoy
# Book:  1  Character:  Hengist of Woodcroft
# Book:  1  Character:  Miles Bletchley
# Book:  1  Character:  Petunia Dursley
# Book:  1  Character:  Lily Moon
# Book:  1  Character:  Terence Higgs
# Book:  1  Character:  Zoo director
# Book:  1  Character:  Emeric Switch
# Book:  1  Character:  Quentin Trimble
# Book:  1  Character:  Evans sisters' mother
# Book:  1  Character:  Filius Flitwick
# Book:  1  Character:  Dudley Dursley's parrot
# Book:  1  Character:  Garrick Ollivander
# Book:  1  Character:  Ronan
# Book:  1  Character:  Fat Friar
# Book:  1  Character:  Algie Longbottom
# Book:  1  Character:  Peeves
# Book:  1  Character:  Phyllida Spore
# Book:  1  Character:  Morag MacDougal
# Book:  1  Character:  Dudley Dursley
# Book:  1  Character:  Doris Crockford
# Book:  1  Character:  Enid (disambiguation)
# Book:  1  Character:  Malcolm
# Book:  1  Character:  Gregory the Smarmy
# Book:  1  Character:  Lavender Brown
# Book:  1  Character:  Merlin
# Book:  1  Character:  Diagon Alley
# Book:  1  Character:  Angelina Johnson
# Book:  1  Character:  Ginevra Weasley
# Book:  1  Character:  Firenze
# Book:  1  Character:  Marcus Flint
# Book:  1  Character:  Hogwarts Express conductor
# Book:  1  Character:  Helena Ravenclaw
# Book:  1  Character:  Hogwarts acceptance letter
# Book:  1  Character:  Mrs Norris
# Book:  1  Character:  Cornelius Fudge
# Book:  1  Character:  Miranda Goshawk
# Book:  1  Character:  Sirius Black
# Book:  1  Character:  Baruffio
# Book:  1  Character:  Minerva McGonagall
# Book:  1  Character:  Draco Malfoy's eagle owl
# Book:  1  Character:  Cuthbert Binns
# Book:  1  Character:  Arsenius Jigger
# Book:  1  Character:  Norwegian Ridgeback
# Book:  1  Character:  Morgan le Fay
# Book:  1  Character:  Katie Bell
# Book:  1  Character:  Ptolemy
# Book:  1  Character:  William Weasley
# Book:  1  Character:  King's Cross Station guard
# Book:  1  Character:  Griphook
# Book:  1  Character:  Hermes
# Book:  1  Character:  Lily J. Potter
# Book:  1  Character:  Hannah Abbott
# Book:  1  Character:  Adrian Pucey
# Book:  1  Character:  Seamus Finnigan's father
# Book:  1  Character:  Tom Riddle
# Book:  1  Character:  Poppy Pomfrey
# Book:  1  Character:  Blaise Zabini
# Book:  1  Character:  Yvonne
# Book:  1  Character:  Vindictus Viridian
# Book:  1  Character:  Cornelius Agrippa
# Book:  1  Character:  Gregory Goyle
# Book:  1  Character:  Elfric the Eager
# Book:  1  Character:  Prewett family
# Book:  1  Character:  Padma Patil
# Book:  1  Character:  Tom
# Book:  1  Character:  Charlie Weasley's colleagues
# WAS REDIRECTED TO:  Charles Weasley's colleagues
# Book:  1  Character:  Keeper of the reptile house
# Book:  1  Character:  Lee Jordan's tarantula
# Book:  1  Character:  Charles Weasley
# Book:  1  Character:  Battle in the Philosopher's Stone Chambers
# WAS REDIRECTED TO:  Skirmish in the Underground Chambers
# Book:  1  Character:  Molly Weasley
# Book:  1  Character:  Adalbert Waffling
# Book:  1  Character:  Rowboat owner
# Book:  1  Character:  Seamus Finnigan
# Book:  1  Character:  Snowy
# Book:  1  Character:  Rolanda Hooch
# Book:  1  Character:  Marjorie Dursley
# Book:  1  Character:  Hogwarts Giant Squid
# Book:  1  Character:  Unicorn
# Book:  1  Character:  Narcissa Malfoy
# Book:  1  Character:  Dedalus Diggle
# Book:  1  Character:  Pansy Parkinson
# Book:  1  Character:  Harry Potter
# Book:  1  Character:  Augusta Longbottom
# Book:  1  Character:  Uric the Oddball
# Book:  1  Character:  Nicolas Flamel
# Book:  1  Character:  Madam Malkin's Robes for All Occasions
# Book:  1  Character:  Ted
# Book:  1  Character:  Irma Pince
# Book:  1  Character:  Trolley witch
# Book:  1  Character:  Bertie Bott
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book2
# Book:  2  Character:  Portly ghost
# Book:  2  Character:  Aurora Sinistra
# Book:  2  Character:  Yeti
# Book:  2  Character:  Whomping Willow
# Book:  2  Character:  Flourish and Blotts
# Book:  2  Character:  Dr Filibuster's Fireworks
# Book:  2  Character:  Mundungus Fletcher
# Book:  2  Character:  Dobby
# Book:  2  Character:  Forbidden Forest Acromantula colony
# Book:  2  Character:  Wagga Wagga Werewolf
# Book:  2  Character:  Salazar Slytherin
# Book:  2  Character:  Transylvania
# Book:  2  Character:  Penelope Clearwater
# Book:  2  Character:  Gilderoy Lockhart
# Book:  2  Character:  Hetty Bayliss
# Book:  2  Character:  Godric Gryffindor
# Book:  2  Character:  Helga Hufflepuff
# Book:  2  Character:  Parseltongue
# Book:  2  Character:  gnome
# Book:  2  Character:  Ogden
# Book:  2  Character:  Hogwarts Board of Governors
# Book:  2  Character:  Angus Fleet
# Book:  2  Character:  Serpent of Slytherin
# Book:  2  Character:  dwarf
# Book:  2  Character:  Patrick Delaney-Podmore
# Book:  2  Character:  Justin Finch-Fletchley's mother
# Book:  2  Character:  Skower
# Book:  2  Character:  Chicken (animal)
# Book:  2  Character:  Mafalda Hopkirk
# Book:  2  Character:  Aged witch
# Book:  2  Character:  Mason's wife
# Book:  2  Character:  Hermione Granger's mother
# Book:  2  Character:  Ghost
# Book:  2  Character:  Dobby's Bludger
# WAS REDIRECTED TO:  Rogue bludger
# Book:  2  Character:  pixie
# Book:  2  Character:  Fawkes
# Book:  2  Character:  Martin Miggs
# Book:  2  Character:  Bozo
# Book:  2  Character:  Gladys Gudgeon
# Book:  2  Character:  Demetrius Prod
# Book:  2  Character:  Nicholas de Mimsy-Porpington's five-hundredth Deathday Party
# Book:  2  Character:  Mortlake
# Book:  2  Character:  Mason
# Book:  2  Character:  Z. Nettles
# Book:  2  Character:  Wailing Widow
# Book:  2  Character:  Bandon Banshee
# Book:  2  Character:  Borgin
# Book:  2  Character:  Fire Dwelling Salamander
# Book:  2  Character:  Olive Hornby
# Book:  2  Character:  Mudblood
# Book:  2  Character:  Vampire
# Book:  2  Character:  Weasley family
# Book:  2  Character:  Veronica Smethley
# Book:  2  Character:  Manager of Flourish and Blotts
# Book:  2  Character:  Perkins
# Book:  2  Character:  Horcrux
# Book:  2  Character:  Armando Dippet
# Book:  2  Character:  Millicent Bulstrode's cat
# Book:  2  Character:  Chamber of Secrets
# Book:  2  Character:  Errol
# Book:  2  Character:  Chudley Cannons
# Book:  2  Character:  Aragog
# Book:  2  Character:  Weasley family ghoul
# Book:  2  Character:  Ernest Macmillan
# Book:  2  Character:  Harry Potter's twelfth birthday
# Book:  2  Character:  Mosag
# Book:  2  Character:  Myrtle Warren
# Book:  2  Character:  Duelling Club
# Book:  2  Character:  Hermione Granger's father
# Book:  2  Character:  Father Christmas
# Book:  2  Character:  Celestina Warbeck
# Book:  2  Character:  Colin Creevey
# Book:  2  Character:  Blood-Sucking Bugbear
# Book:  2  Character:  Fawcett
# Book:  2  Character:  Rowena Ravenclaw
# Book:  2  Character:  Polyjuice Potion
# Book:  2  Character:  The Burrow
# Book:  2  Character:  Tom Riddle's diary
# WAS REDIRECTED TO:  T. M. Riddle's Diary
# Book:  2  Character:  Harry Potter's sock
# Book:  2  Character:  Colin Creevey's father
# WAS REDIRECTED TO:  Creevey brothers' father
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book3
# Book:  3  Character:  Marsh
# Book:  3  Character:  Unidentified Hogwarts owl
# Book:  3  Character:  Ripper
# Book:  3  Character:  Cassius Warrington
# Book:  3  Character:  Hinkypunk
# Book:  3  Character:  Silvanus Kettleburn
# Book:  3  Character:  Cadogan
# Book:  3  Character:  Remus Lupin
# Book:  3  Character:  Septima Vector
# Book:  3  Character:  Lyall Lupin
# Book:  3  Character:  Dementor
# Book:  3  Character:  Cedric Diggory
# Book:  3  Character:  Ambrosius Flume's wife
# Book:  3  Character:  Boggart
# Book:  3  Character:  Wendelin the Weird
# Book:  3  Character:  Cho Chang
# Book:  3  Character:  Prime Minister
# Book:  3  Character:  Unidentified Gryffindor girls
# Book:  3  Character:  Lucian Bole
# Book:  3  Character:  Florean Fortescue
# Book:  3  Character:  Cassandra Vablatsky
# Book:  3  Character:  Buckbeak
# Book:  3  Character:  Ernest Prang
# Book:  3  Character:  Graham Montague
# Book:  3  Character:  Roger Davies
# Book:  3  Character:  Dishevelled Wizard
# Book:  3  Character:  Rosmerta
# Book:  3  Character:  Unidentified Committee for the Disposal of Dangerous Creatures member
# Book:  3  Character:  Walden Macnair
# Book:  3  Character:  Derek
# Book:  3  Character:  Stanley Shunpike
# Book:  3  Character:  Pigwidgeon
# Book:  3  Character:  Davey Gudgeon
# Book:  3  Character:  Fubster
# Book:  3  Character:  Hope Howell
# Book:  3  Character:  Magical Menagerie saleswoman
# Book:  3  Character:  Peter Pettigrew's mother
# Book:  3  Character:  Crookshanks
# Book:  3  Character:  Security Troll
# WAS REDIRECTED TO:  Security troll
# Book:  3  Character:  Fleetwood
# Book:  3  Character:  Peregrine Derrick
# Book:  3  Character:  Bilius
# Book:  3  Character:  Unidentified Muggle woman (II)
# Book:  3  Character:  Grindylow
# Book:  3  Character:  Sybill Trelawney
# Book:  3  Character:  Ambrosius Flume
# Book:  3  Character:  Binky
# Book:  3  Character:  Hogwarts Hippogriff herd
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book4
# Book:  4  Character:  Bill Weasley's Brazilian pen-friend
# WAS REDIRECTED TO:  William Weasley's South American pen-friend
# Book:  4  Character:  Hassan Mostafa
# Book:  4  Character:  Igor Karkaroff
# Book:  4  Character:  Unidentified female Chinese Fireball
# Book:  4  Character:  Merope Riddle
# Book:  4  Character:  Joey Jenkins
# Book:  4  Character:  Omnioculars
# Book:  4  Character:  Broderick Bode
# Book:  4  Character:  Clara Ivanova
# Book:  4  Character:  Malcolm Baddock
# Book:  4  Character:  Unidentified female Common Welsh Green
# Book:  4  Character:  Oliver Wood's mother
# Book:  4  Character:  Viktor Krum's mother
# Book:  4  Character:  Rubeus Hagrid's father
# Book:  4  Character:  Tom Riddle Senior
# Book:  4  Character:  Landlord of The Hanged Man
# Book:  4  Character:  Unidentified fifth year girl
# Book:  4  Character:  Great Lake Merpeople colony
# Book:  4  Character:  Crabbe
# Book:  4  Character:  Lovegood family
# Book:  4  Character:  Aidan Lynch
# Book:  4  Character:  Bodrod the Bearded
# Book:  4  Character:  Laura Madley
# Book:  4  Character:  Frank Bryce
# Book:  4  Character:  Antonin Dolohov
# Book:  4  Character:  Apolline Delacour
# Book:  4  Character:  Nagini
# Book:  4  Character:  Sphinx
# Book:  4  Character:  Roddy Pontner
# Book:  4  Character:  Alexei Levski
# Book:  4  Character:  Leprechaun
# Book:  4  Character:  Riddle House
# Book:  4  Character:  Mungo Bonham
# Book:  4  Character:  Mykew Gregorovitch
# Book:  4  Character:  Arnold Peasegood
# Book:  4  Character:  Violet
# Book:  4  Character:  Natalie McDonald
# Book:  4  Character:  Care of Magical Creatures
# Book:  4  Character:  Goyle
# Book:  4  Character:  Veela
# Book:  4  Character:  Cuthbert Mockridge
# Book:  4  Character:  Emma Dobbs
# Book:  4  Character:  Bertha Jorkins's aunt
# Book:  4  Character:  Bartemius Crouch Snr's grandfather
# Book:  4  Character:  Little Whinging postman
# Book:  4  Character:  Wizard who claimed to be a dragon killer
# Book:  4  Character:  Alice Longbottom
# Book:  4  Character:  Barry Ryan
# Book:  4  Character:  Otto Bagman
# Book:  4  Character:  Quigley
# Book:  4  Character:  Oblansk
# Book:  4  Character:  Alastor Moody
# Book:  4  Character:  Connolly
# Book:  4  Character:  Little Hangleton boys
# Book:  4  Character:  Andorran Ministry of Magic
# Book:  4  Character:  Unidentified Beauxbatons students#Beauxbatons boy
# Book:  4  Character:  Ludovic Bagman
# Book:  4  Character:  Unidentified female Hungarian Horntail
# Book:  4  Character:  Kevin
# Book:  4  Character:  Evan Rosier
# Book:  4  Character:  Roberts
# Book:  4  Character:  Lee Jordan's father
# Book:  4  Character:  Bertha Jorkins's second cousin
# Book:  4  Character:  Florence's boyfriend
# Book:  4  Character:  Owen Cauldwell
# Book:  4  Character:  Salem Witches' Institute
# Book:  4  Character:  Abraxan
# Book:  4  Character:  Ogg
# Book:  4  Character:  Ivan Volkov
# Book:  4  Character:  Cedric Diggory's mother
# Book:  4  Character:  Troy
# Book:  4  Character:  Wilhelmina Grubbly-Plank
# Book:  4  Character:  Lev Zograf
# Book:  4  Character:  Winky's grandmother
# Book:  4  Character:  Apolline Delacour's mother
# Book:  4  Character:  Kevin's father
# Book:  4  Character:  Rabastan Lestrange
# Book:  4  Character:  Basil
# Book:  4  Character:  Kevin's mother
# Book:  4  Character:  Wizard who claimed to be a Vampire Hunter
# Book:  4  Character:  Viktor Krum
# Book:  4  Character:  Avery (Marauder-era)
# WAS REDIRECTED TO:  Avery II
# Book:  4  Character:  Great Hangleton
# Book:  4  Character:  Orla Quirke
# Book:  4  Character:  Olive Hornby's brother
# Book:  4  Character:  Smeltings Academy
# Book:  4  Character:  Agatha Timms
# Book:  4  Character:  Roberts's Obliviator
# WAS REDIRECTED TO:  Roberts' Obliviator
# Book:  4  Character:  Cornelius Fudge's wife
# Book:  4  Character:  Bartemius Crouch Senior
# Book:  4  Character:  Triwizard Maze
# Book:  4  Character:  Riddles' cook
# Book:  4  Character:  Saul Croaker
# Book:  4  Character:  Travers
# Book:  4  Character:  Thomas Riddle
# Book:  4  Character:  Riddles' maid
# Book:  4  Character:  Vasily Dimitrov
# Book:  4  Character:  Unidentified female Council of Magical Law juror
# Book:  4  Character:  Unidentified Ministry of Magic Wizard at the 1994 Quidditch World Cup
# Book:  4  Character:  Stewart Ackerley
# Book:  4  Character:  Archie Aymslowe
# Book:  4  Character:  Summers
# Book:  4  Character:  Pyotr Vulchanov
# Book:  4  Character:  Blast-Ended Skrewt
# Book:  4  Character:  Poliakoff
# Book:  4  Character:  Wilkes
# Book:  4  Character:  Unidentified Hufflepuff girl (III)
# Book:  4  Character:  Winky
# Book:  4  Character:  Bertha Jorkins
# Book:  4  Character:  Eloise Midgen
# Book:  4  Character:  Niffler
# Book:  4  Character:  Kevin Whitby
# Book:  4  Character:  Spider
# Book:  4  Character:  Ludovic Bagman's father
# Book:  4  Character:  Amos Diggory
# Book:  4  Character:  Stebbins (Potter-era)
# Book:  4  Character:  Gabrielle Delacour
# Book:  4  Character:  Olympe Maxime
# Book:  4  Character:  Mulciber (Marauder-era)
# WAS REDIRECTED TO:  Mulciber II
# Book:  4  Character:  Gilbert Wimple
# Book:  4  Character:  Dot
# Book:  4  Character:  Apollyon Pringle
# Book:  4  Character:  Mary Riddle
# Book:  4  Character:  Augustus Rookwood
# Book:  4  Character:  Payne
# Book:  4  Character:  Murcus
# Book:  4  Character:  Moran
# Book:  4  Character:  Bartemius Crouch Jr's mother
# WAS REDIRECTED TO:  Bartemius Crouch Junior's mother
# Book:  4  Character:  Beauxbatons Academy of Magic
# Book:  4  Character:  Nott
# Book:  4  Character:  Fleur Delacour
# Book:  4  Character:  Hogwarts house-elves
# Book:  4  Character:  Weird Sisters
# Book:  4  Character:  Fridwulfa
# Book:  4  Character:  Roberts children
# Book:  4  Character:  Fawcett family
# Book:  4  Character:  Eleanor Branstone
# Book:  4  Character:  Rodolphus Lestrange
# Book:  4  Character:  Florence
# Book:  4  Character:  Aberforth Dumbledore
# Book:  4  Character:  Unidentified female Swedish Shortsnout
# Book:  4  Character:  Little Hangleton
# Book:  4  Character:  Bartemius Crouch Junior
# Book:  4  Character:  Great Lake
# Book:  4  Character:  Viktor Krum's father
# Book:  4  Character:  Boris the Bewildered
# Book:  4  Character:  Unidentified Beauxbatons students#Beauxbatons girl (I)
# Book:  4  Character:  Ali Bashir
# Book:  4  Character:  Mullet
# Book:  4  Character:  Ludovic Bagman's goblin creditors
# Book:  4  Character:  Roberts's wife
# Book:  4  Character:  Urg the Unclean
# Book:  4  Character:  Bellatrix Lestrange
# Book:  4  Character:  Rita Skeeter
# Book:  4  Character:  Graham Pritchard
# Book:  4  Character:  Dennis Creevey
# Book:  4  Character:  Frank Longbottom
# Book:  4  Character:  Oliver Wood's father
# Book:  4  Character:  Winky's mother
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book5
# Book:  5  Character:  St Mungo's Welcome Witch
# Book:  5  Character:  12 Grimmauld Place
# Book:  5  Character:  Curious Gryffindor Girl
# Book:  5  Character:  Mark Evans
# Book:  5  Character:  Ladislaw Zamojski
# Book:  5  Character:  Will
# Book:  5  Character:  Kenneth Towler
# Book:  5  Character:  Euphemia Potter
# Book:  5  Character:  Cassandra Trelawney
# Book:  5  Character:  Unidentified Thestrals
# Book:  5  Character:  Edward Tonks
# Book:  5  Character:  Tiberius Ogden
# Book:  5  Character:  Bob
# Book:  5  Character:  Inigo Imago
# Book:  5  Character:  Stebbins (Marauder-era)
# Book:  5  Character:  Marietta Edgecombe
# Book:  5  Character:  Cho Chang's mother
# Book:  5  Character:  Jack Sloper
# Book:  5  Character:  Karkus' wife
# WAS REDIRECTED TO:  Karkus's wife
# Book:  5  Character:  Rose Zeller
# Book:  5  Character:  Portrait of a Healer in St Mungo's Hospital
# Book:  5  Character:  Phineas Nigellus Black
# Book:  5  Character:  Gimlet-eyed Hogwarts Headmistress
# Book:  5  Character:  Jugson
# Book:  5  Character:  Fleamont Potter
# Book:  5  Character:  Tobias Snape
# Book:  5  Character:  Summerby
# Book:  5  Character:  Pandora Lovegood
# Book:  5  Character:  Kingsley Shacklebolt
# Book:  5  Character:  Magorian
# Book:  5  Character:  Araminta Meliflua Black
# Book:  5  Character:  Goblin
# Book:  5  Character:  Bowtruckle
# Book:  5  Character:  Dolores Umbridge
# Book:  5  Character:  Arcturus Black III
# Book:  5  Character:  Eric Munch
# Book:  5  Character:  Doxy
# Book:  5  Character:  John Dawlish
# Book:  5  Character:  Kreacher
# Book:  5  Character:  Nottingham
# Book:  5  Character:  Lachlan the Lanky
# Book:  5  Character:  Marlene McKinnon
# Book:  5  Character:  Gideon Prewett
# Book:  5  Character:  Doris Purkiss
# Book:  5  Character:  Bungy
# Book:  5  Character:  Alphard Black
# Book:  5  Character:  Unidentified Gryffindor boy
# Book:  5  Character:  Graham Montague's father
# Book:  5  Character:  Griselda Marchbanks
# Book:  5  Character:  Hippocrates Smethwyck
# Book:  5  Character:  Dummy at Purge and Dowse, Ltd
# Book:  5  Character:  Sixth-Year Inquisitorial Squad Member
# Book:  5  Character:  Luna Lovegood
# Book:  5  Character:  Mary Dorkins
# Book:  5  Character:  Dr Ubbly's Oblivious Unction
# Book:  5  Character:  Elfrida Cragg
# Book:  5  Character:  Eileen Prince
# Book:  5  Character:  Orion Black
# Book:  5  Character:  Kreacher's mother
# Book:  5  Character:  Bradley
# Book:  5  Character:  Neville Longbottom's grandfather
# WAS REDIRECTED TO:  Frank Longbottom's father
# Book:  5  Character:  Miriam Strout
# Book:  5  Character:  Unidentified hard-faced grey centaur
# Book:  5  Character:  Tofty
# Book:  5  Character:  Geoffrey Hooper
# Book:  5  Character:  Augustus Pye
# Book:  5  Character:  Edgar Bones
# Book:  5  Character:  Dai Llewellyn
# Book:  5  Character:  Mrs Number Seven
# Book:  5  Character:  Dilys Derwent
# Book:  5  Character:  Agnes
# Book:  5  Character:  Willy Widdershins
# Book:  5  Character:  Dexter Fortescue
# Book:  5  Character:  Walburga Black
# Book:  5  Character:  Patricia Stimpson
# Book:  5  Character:  Emmeline Vance
# Book:  5  Character:  Donaghan Tremlett
# Book:  5  Character:  Unidentified male Seer
# Book:  5  Character:  Barnabas the Barmy
# Book:  5  Character:  Unidentified female Seer
# Book:  5  Character:  Everard
# Book:  5  Character:  Hogwarts Thestral herd
# Book:  5  Character:  Hestia Jones
# Book:  5  Character:  Marietta Edgecombe's mother
# WAS REDIRECTED TO:  Edgecombe
# Book:  5  Character:  Regulus Black
# Book:  5  Character:  Millicent Bagnold
# Book:  5  Character:  Unidentified dun-coloured centaur
# Book:  5  Character:  Unidentified bearded centaur
# Book:  5  Character:  Caradoc Dearborn
# Book:  5  Character:  Wilfred the Wistful
# Book:  5  Character:  Janus Thickey
# Book:  5  Character:  Benjy Fenwick
# Book:  5  Character:  Karkus
# Book:  5  Character:  Williamson
# Book:  5  Character:  Dean Thomas's father
# Book:  5  Character:  Unidentified Gryffindor boy's friend
# Book:  5  Character:  Elladora Black
# Book:  5  Character:  Chambers
# Book:  5  Character:  Fabian Prewett
# Book:  5  Character:  Stubby Boardman
# Book:  5  Character:  Eddie Carmichael
# Book:  5  Character:  Harold Dingle
# Book:  5  Character:  Puddifoot
# Book:  5  Character:  Vicky Frobisher
# Book:  5  Character:  Pierre Bonaccord
# Book:  5  Character:  Golgomath
# Book:  5  Character:  Ghoul
# Book:  5  Character:  Ragnok
# Book:  5  Character:  Xenophilius Lovegood
# Book:  5  Character:  Dean Thomas's mother
# Book:  5  Character:  Tenebrus
# Book:  5  Character:  Nymphadora Tonks
# Book:  5  Character:  Andromeda Tonks
# Book:  5  Character:  Agnes's son
# Book:  5  Character:  Zacharias Smith
# Book:  5  Character:  Graham Montague's mother
# Book:  5  Character:  Anthony Goldstein
# Book:  5  Character:  Elphias Doge
# Book:  5  Character:  Prentice
# Book:  5  Character:  Marietta Edgecombe's father
# Book:  5  Character:  Euan Abercrombie
# Book:  5  Character:  Amelia Bones
# Book:  5  Character:  Warty Harris
# Book:  5  Character:  Andrew Kirke
# Book:  5  Character:  Rufus Scrimgeour
# Book:  5  Character:  Sturgis Podmore
# Book:  5  Character:  Gargoyles at the staffroom entrance
# Book:  5  Character:  Roger Davies' date
# WAS REDIRECTED TO:  Roger Davies's girlfriend
# Book:  5  Character:  Daphne Greengrass
# Book:  5  Character:  Unidentified centaur
# Book:  5  Character:  Dorcas Meadowes
# Book:  5  Character:  Grawp
# Book:  5  Character:  Michael Corner
# Book:  5  Character:  Gregory Goyle's mother
# Book:  5  Character:  Urquhart Rackharrow
# Book:  5  Character:  Wilbert Slinkhard
# Book:  5  Character:  Cho Chang's father
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book6
# Book:  6  Character:  Savage
# Book:  6  Character:  Arkie Philpott
# Book:  6  Character:  Hepzibah Smith
# Book:  6  Character:  Mulciber (Riddle-era)
# WAS REDIRECTED TO:  Mulciber I
# Book:  6  Character:  Romilda Vane
# Book:  6  Character:  Marvolo Gaunt
# Book:  6  Character:  Eloise Midgen's father
# Book:  6  Character:  Prime Minister's political opponent
# Book:  6  Character:  Rupert Brookstanton
# Book:  6  Character:  Abraxas Malfoy
# Book:  6  Character:  Verity
# Book:  6  Character:  Amycus Carrow
# Book:  6  Character:  Avery (Riddle-era)
# WAS REDIRECTED TO:  Avery I
# Book:  6  Character:  Herbert Chorley
# Book:  6  Character:  Libatius Borage
# Book:  6  Character:  Demelza Robins
# Book:  6  Character:  Prime Minister's niece
# Book:  6  Character:  Muriel
# Book:  6  Character:  Marcus Belby's father
# Book:  6  Character:  Katie Bell's mother
# Book:  6  Character:  Cormac McLaggen
# Book:  6  Character:  Harper
# Book:  6  Character:  Lestrange
# Book:  6  Character:  Martha (disambiguation)
# Book:  6  Character:  Octavius Pepper
# Book:  6  Character:  Hannah Abbott's mother
# Book:  6  Character:  Morfin Gaunt
# Book:  6  Character:  Bertie Higgs
# Book:  6  Character:  Eric Whalley
# Book:  6  Character:  Jimmy Peakes
# Book:  6  Character:  Bertram Aubrey
# Book:  6  Character:  Montgomery sisters' mother
# WAS REDIRECTED TO:  Montgomery children's mother
# Book:  6  Character:  Ulick Gamp
# Book:  6  Character:  Caractacus Burke
# Book:  6  Character:  Romilda Vane's grandmother
# Book:  6  Character:  Ciceron Harkiss
# Book:  6  Character:  Alecto Carrow
# Book:  6  Character:  Galatea Merrythought
# Book:  6  Character:  Corban Yaxley
# Book:  6  Character:  Gibbon
# Book:  6  Character:  Billy Stubbs
# Book:  6  Character:  Barnabas Cuffe
# Book:  6  Character:  Horace Slughorn
# Book:  6  Character:  Chancellor of the Exchequer
# Book:  6  Character:  Fox near Spinner's End
# Book:  6  Character:  Rosalind Bungs
# Book:  6  Character:  Tiberius
# Book:  6  Character:  Katie Bell's father
# Book:  6  Character:  Proudfoot
# Book:  6  Character:  Fergus
# Book:  6  Character:  Blaise Zabini's mother
# Book:  6  Character:  Montgomery sisters
# Book:  6  Character:  Marcus Belby
# Book:  6  Character:  Cecilia
# Book:  6  Character:  Fenrir Greyback
# Book:  6  Character:  Odo
# Book:  6  Character:  Golpalott
# Book:  6  Character:  Sanguini
# Book:  6  Character:  Dirk Cresswell
# Book:  6  Character:  Amy Benson
# Book:  6  Character:  Ritchie Coote
# Book:  6  Character:  Amulet
# Book:  6  Character:  Eldred Worple
# Book:  6  Character:  Zacharias Smith's father
# Book:  6  Character:  Vaisey
# Book:  6  Character:  Patil twins' father
# Book:  6  Character:  Montgomery
# Book:  6  Character:  Scarpin
# Book:  6  Character:  Ceremony official
# Book:  6  Character:  Bob Ogden
# Book:  6  Character:  Cole
# Book:  6  Character:  Inferius
# Book:  6  Character:  Arnold
# Book:  6  Character:  Rosier
# Book:  6  Character:  Thorfinn Rowle
# Book:  6  Character:  Leanne
# Book:  6  Character:  Wilkie Twycross
# Book:  6  Character:  Gwenog Jones
# Book:  6  Character:  Urquhart
# Book:  6  Character:  Hector Dagworth-Granger
# Book:  6  Character:  Melinda Bobbin
# Book:  6  Character:  Gawain Robards
# Book:  6  Character:  Humphrey Belcher
# Book:  6  Character:  Hokey
# Book:  6  Character:  Patil twins' mother
# Book:  6  Character:  Dennis Bishop
# Book:  6  Character:  Damocles Belby
# Book:  6  Character:  Unidentified nine-year old
# Book:  6  Character:  Cadwallader
# Book:  6  Character:  Unidentified nine-year old's grandparents
# Book:  6  Character:  Unidentified Aurors
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book7
# Book:  7  Character:  Red-haired Muggle boy
# Book:  7  Character:  Astoria Malfoy
# Book:  7  Character:  Bowman Wright
# Book:  7  Character:  Ellie Cattermole
# Book:  7  Character:  Dirk Cresswell's wife
# Book:  7  Character:  Unidentified Mould-on-the-Wold boys
# Book:  7  Character:  Mary Macdonald
# Book:  7  Character:  Luchino Caffe
# Book:  7  Character:  Scorpius Malfoy
# Book:  7  Character:  James Potter II
# Book:  7  Character:  Maisie Cattermole
# Book:  7  Character:  Ivor Dillonsby
# Book:  7  Character:  The Last Will and Testament of Albus Percival Wulfric Brian Dumbledore
# Book:  7  Character:  Dursley family
# Book:  7  Character:  Enid Smeek
# Book:  7  Character:  Charity Burbage
# Book:  7  Character:  Dean Thomas's half-siblings
# Book:  7  Character:  Potters' cat
# Book:  7  Character:  Magical Maintenance Department
# Book:  7  Character:  Waitress at Luchino Caffe
# Book:  7  Character:  Bletchley
# Book:  7  Character:  Loxias
# Book:  7  Character:  Kendra Dumbledore
# Book:  7  Character:  Godelot
# Book:  7  Character:  Gamp
# Book:  7  Character:  Seven
# Book:  7  Character:  James Potter's owl
# WAS REDIRECTED TO:  James Potter II's owl
# Book:  7  Character:  Arkie Alderton's alleged son
# Book:  7  Character:  Lancelot (Healer)
# Book:  7  Character:  Death (The Tale of the Three Brothers)
# Book:  7  Character:  Cadmus Peverell
# Book:  7  Character:  Marius
# Book:  7  Character:  Selwyn
# Book:  7  Character:  Workmen at Tottenham Court Road
# Book:  7  Character:  Ragnuk
# Book:  7  Character:  Wandless
# Book:  7  Character:  Livius
# Book:  7  Character:  Dudley
# Book:  7  Character:  Alastor "Mad-Eye" Moody
# WAS REDIRECTED TO:  Alastor Moody
# Book:  7  Character:  Unidentified goblin killed by Voldemort
# Book:  7  Character:  Wedding of William Weasley and Fleur Delacour
# Book:  7  Character:  Viktor Krum's grandfather
# Book:  7  Character:  Mary Cattermole
# Book:  7  Character:  German-speaking woman
# Book:  7  Character:  Hereward
# Book:  7  Character:  Cresswell brothers
# Book:  7  Character:  Betty Braithwaite
# Book:  7  Character:  Alfred Cattermole
# Book:  7  Character:  Egbert the Egregious
# Book:  7  Character:  Gornuk
# Book:  7  Character:  Muggle-Born Registration Commission
# Book:  7  Character:  Snatchers
# Book:  7  Character:  Babbitty Rabbity
# Book:  7  Character:  Barnabus Finkley
# Book:  7  Character:  The Life and Lies of Albus Dumbledore
# Book:  7  Character:  Foul-smelling Snatcher
# Book:  7  Character:  Antioch Peverell
# Book:  7  Character:  Albert Runcorn
# Book:  7  Character:  Percival Dumbledore
# Book:  7  Character:  Band at Bill Weasley and Fleur Delacour's wedding
# WAS REDIRECTED TO:  Band at William Weasley and Fleur Delacour's wedding
# Book:  7  Character:  Bernie
# Book:  7  Character:  Delacour sisters' cousins
# Book:  7  Character:  Waiters at Bill Weasley and Fleur Delacour's wedding
# WAS REDIRECTED TO:  Waiters at William Weasley and Fleur Delacour's wedding
# Book:  7  Character:  Bogrod
# Book:  7  Character:  Ignotus Peverell
# Book:  7  Character:  Gringott's Dragon
# Book:  7  Character:  Magic is Might
# Book:  7  Character:  Arkie Alderton
# Book:  7  Character:  Ronald Weasley's uncle
# WAS REDIRECTED TO:  Weasley children's uncle
# Book:  7  Character:  Albus Potter's owl
# Book:  7  Character:  Ariana Dumbledore
# Book:  7  Character:  Edward Lupin
# Book:  7  Character:  German-speaking children
# Book:  7  Character:  Wakanda
# Book:  7  Character:  Unidentified Ravenclaw boy
# Book:  7  Character:  Ravenclaw
# Book:  7  Character:  Muriel's mother
# Book:  7  Character:  Delacour sisters' father
# Book:  7  Character:  Dirk Cresswell's friends
# Book:  7  Character:  Barnabas Deverill
# Book:  7  Character:  Patronus Charm
# Book:  7  Character:  Scabior
# Book:  7  Character:  Beedle the Bard
# Book:  7  Character:  Albus Potter
# Book:  7  Character:  Rose Granger-Weasley
# Book:  7  Character:  Reginald Cattermole
# Book:  7  Character:  Hugo Granger-Weasley
# Book:  7  Character:  Albino peacock
# Book:  7  Character:  British Ministry of Magic
# Book:  7  Character:  Godric's Hollow
# Book:  7  Character:  Hedwig's killer
# Book:  7  Character:  Lily Potter
# Book:  7  Character:  James Potter II's friends
# Book:  7  Character:  Arcus
# Book:  7  Character:  Pius Thicknesse
# Book:  7  Character:  Unidentified Gringotts guard (I)
# Book:  7  Character:  Dragomir Gorgovitch
# Book:  7  Character:  Victoire Weasley
# Book:  7  Character:  Abbott (Godric's Hollow)
# WAS REDIRECTED TO:  Abbott

# %%
df_wiki.head(3)
# Out:
#                                        wiki  book alternative_wiki
# 0                                     Tufty     1             None
# 1                          Mirror of Erised     1             None
# 2  Quirinus Quirrell's first mountain troll     1             None

# %% [markdown]
# **Now we have stored all the WikiPages. But the dataframe should contain the necessary information on alternative Wikis**:

# %%
# If the redirect links already exist in the dataframe we need to drop them

alternative_wikis = set(list(df_wiki.alternative_wiki))
df_wiki[df_wiki.wiki.isin(alternative_wikis)]
# Out:
#               wiki  book alternative_wiki
# 356  Alastor Moody     4             None

# %%
# So we override the alternative_wiki link for this row 
df_wiki[df_wiki.wiki == 'Alastor Moody']['alternative_wiki'] = 'Alastor "Mad-Eye" Moody'

#Finally we drop the row containing 'Alastor "Mad-Eye" Moody' in the wiki
df_wiki = df_wiki[df_wiki.wiki != 'Alastor "Mad-Eye" Moody']

# %%
len(df_wiki)
# Out:
# 788

# %%
df_wiki[df_wiki.wiki == 'Alastor Moody']
# Out:
#               wiki  book alternative_wiki
# 356  Alastor Moody     4             None

# %%
# Making sure we're in the wiki home directory

os.chdir(hd)

print(os.getcwd())
# Out:
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis

# %%
# Creating a new folder to store the dataframe and switching to it:
if not os.path.exists("dataframes"):
    os.mkdir("dataframes")
os.chdir(hd + "/dataframes")

# And fetching the files is done, saving the dataframe:
with open('original_wiki_df.pkl', 'wb') as f:
    pickle.dump(df_wiki, f)

# %% [markdown]
# ---

# %% [markdown]
# # WikiPage DataFrame cleaning and sorting
#
# _Now that we have all the files, we have to extract the valuable information from them. This is so we can build a network later._

# %%
# Start by fetching the dataframe from above and changing the directory:

os.chdir(hd)

# Fetching the original dataframe

with open('dataframes/original_wiki_df.pkl', 'rb') as f:
    df_wiki = pickle.load(f)

# %%
# Seeing if it loaded correctly 

df_wiki.head(3)
# Out:
#                                        wiki  book alternative_wiki
# 0                                     Tufty     1             None
# 1                          Mirror of Erised     1             None
# 2  Quirinus Quirrell's first mountain troll     1             None

# %% [markdown]
# _Now, we loop through the DataFrame that contains information about the WikiPages, and open the files that correspond with the row. Then, we fetch the links that are contained in the page, and various attributes such as the Hogwarts House, family and others._

# %%
# Now we need to loop through all the files and extract information to add to the dataframe

# Surpress warning message for SettingWithCopyWarning
pd.options.mode.chained_assignment = None

folders = ['book1','book2','book3', 'book4', 'book5', 'book6', 'book7']

# Define the working directory
wd = hd

# Add columns to the dataframe for the additional information
df_wiki['text'] = None
df_wiki['links'] = None
df_wiki['house'] = None
df_wiki['type'] = None
df_wiki['blood'] = None
df_wiki['job'] = None
df_wiki['family'] = None
df_wiki['loyalties'] = None

# Definitions for later
wiki_links = list(df_wiki.wiki)
alternative_links = list(df_wiki.alternative_wiki[df_wiki.alternative_wiki.notna()])
all_wiki_links = wiki_links + alternative_links

for idx, row in df_wiki.iterrows():
    # Check if working directory is correct based on the next row - we want to save each character into their book's folder
    expected_path = wd + '/book' + str(row['book'])
    if os.getcwd() != expected_path:
        print("Setting working directory")
        print(expected_path)
        os.chdir(expected_path)

    # Check if there was an alternative link for this character
    file_name = row.wiki
    if row.alternative_wiki != None:
        file_name = row.alternative_wiki

    # Opening the file containing the WikiPage
    file = open(file_name + '.txt', "r") 
    text = file.read()
    file.close() 

    # Print info so easier to see where loop is running
    #print("Book: ", row.book, " Character: ", file_name)

    # Finding the links in the entity's WikiPage
    links = re.findall(r"\[\[(.*?)\]\]", text)
    links_clean = [l.split('|')[0] for l in links if l.startswith(('File', 'nl:', 'Category:', 'pl:', 'ru:', 'Harry Potter and the ')) == False]
    
    # filter all the links based on characters in the dataframe
    wiki_links_clean = [l for l in links_clean if l in wiki_links]
    alternative_links_clean = [l for l in links_clean if l in alternative_links]

    # Clean up and overwrite link values where there are alternative wikis
    for i in range(len(alternative_links_clean)):
        alternative_links_clean[i] = df_wiki[df_wiki.alternative_wiki==alternative_links_clean[i]].wiki.item()

    # Combine both links into a single set
    clean_links = list(set(wiki_links_clean + alternative_links_clean))

    # Storing the WikiPage text and its links in the DataFrame
    df_wiki.at[idx, "text"] = text
    df_wiki.at[idx, "links"] = clean_links

    # We also want to extract more information from the text of each character.
    # Source for info: https://github.com/earwig/mwparserfromhell
    wikicode = mwparserfromhell.parse(text) # Convert to wikicode
    templates = wikicode.filter_templates() # Extract the templates of the wikicode

    # Checking whether the WikiPage is for an individual
    if len([t for t in templates if t.startswith('{{Individual infobox')]) > 0:
        
        # If the WikiPage is for an individual, we can start fetching information about the individual
        template = [t for t in templates if t.startswith('{{Individual infobox')][0] # Find the template containing the infobox

        # Extract the relevant information from the template
        if template.has_param('blood'):
            blood = re.findall(r"\[\[(.*?)\]\]", str(template.get('blood').value))
            #print(blood)
        if template.has_param('nationality'):
            nationality = re.findall(r"\[\[(.*?)\]\]", str(template.get('nationality').value))
            nationality = [n.split('|')[0] for n in nationality]
            #print(nationality)
        if template.has_param('species'):
            species = re.findall(r"\[\[(.*?)\]\]", str(template.get('species').value))
            #print(species)
        if template.has_param('gender'):
            gender = [template.get('gender').value.strip().split('<')[0]]
            #print(gender)
        if template.has_param('hair'):
            hair = [template.get('hair').value.strip().split('<')[0]]
            #print(hair)
        if template.has_param('eyes'):
            eyes = [template.get('eyes').value.strip().split('<')[0]]
            #print(eyes)
        if template.has_param('skin'):
            skin = [template.get('skin').value.strip().split('<')[0]]
            #print(skin)
        
        # Finding whether the character has family ties
        if template.has_param('family'):
            family_raw = re.findall(r"\[\[(.*?)\]\]", str(template.get('family').value))
            family = [l.split('|')[0] for l in family_raw]

        if template.has_param('house'):
            house = re.findall(r"\[\[(.*?)\]\]", str(template.get('house').value))
            
        if template.has_param('job'):
            job_raw = re.findall(r"\[\[(.*?)\]\]", str(template.get('job').value))
            job = [l.split('|')[0] for l in job_raw]
            
        if template.has_param('loyalty'):
            loyalties_raw = re.findall(r"\[\[(.*?)\]\]", str(template.get('loyalty').value))
            loyalties = [l.split('|')[0] for l in loyalties_raw]

        # Other topics: boggart, patronus

        # Write the relevant values into the dataframe
        if len(house) > 0:
            df_wiki.at[idx, "house"] = house[0]
            
        if len(job) > 0:
            df_wiki.at[idx, "job"] = job[0]
            
        if len(family) > 0:
            df_wiki.at[idx, "family"] = family
            
        if len(loyalties) > 0:
            df_wiki.at[idx, "loyalties"] = loyalties
            
        if len(blood) > 0:
            df_wiki.at[idx, "blood"] = blood
        
        # Finally, we're declaring the character as an individual
        df_wiki.at[idx, "type"] = "Individual"
    

    # If the WikiPage is not for an individual, here we store what type the entity is    
    elif len([t for t in templates if t.startswith('{{Object infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Object"
        
    elif len([t for t in templates if t.startswith('{{Pet individual infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Pet"
        
    elif len([t for t in templates if t.startswith('{{Creature infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Creature"
        
    elif len([t for t in templates if t.startswith('{{Letter_infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Letter"      

    elif len([t for t in templates if t.startswith('{{Family infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Family"      

    elif len([t for t in templates if t.startswith('{{Location infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Location"
        
    elif len([t for t in templates if t.startswith('{{Battle infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Battle" 

    elif len([t for t in templates if t.startswith('{{Quidditch Team infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Quidditch Team" 
        
    elif len([t for t in templates if t.startswith('{{Organisation infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Organisation" 
        
    elif len([t for t in templates if t.startswith('{{Potion infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Potion" 
        
    elif len([t for t in templates if t.startswith('{{Plant infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Plant" 
        
    elif len([t for t in templates if t.startswith('{{Spell infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Spell" 
    
    elif len([t for t in templates if t.startswith('{{Event infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Event" 
        
    elif len([t for t in templates if t.startswith('{{Official post')]) > 0:
        df_wiki.at[idx, "type"] = "Official post" 
        
    elif len([t for t in templates if t.startswith('{{School infobox')]) > 0 or len([t for t in templates if t.startswith('{{School_infobox')]) > 0:
        df_wiki.at[idx, "type"] = "School" 
        
    elif len([t for t in templates if t.startswith('{{Horcrux infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Horcrux" 
        
    elif len([t for t in templates if t.startswith('{{Class infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Class" 
        
    elif len([t for t in templates if t.startswith('{{Book infobox')]) > 0:
        df_wiki.at[idx, "type"] = "Book" 
        
    else:
        df_wiki.at[idx, "type"] = "Unknown"
    
# reset wd
os.chdir(wd)
# Out:
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book1
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book2
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book3
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book4
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book5
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book6
# Setting working directory
# /Users/teddi/Documents/DTU/FALL2020/Social Graphs & Interactions/Final Project/New segmented project/Wikis/book7

# %% [markdown]
# **Blood-type is often ambiguous - let's assume that if the following things are mentioned, they're true (in the row that they appear):**

# %%
for idx, row in df_wiki.iterrows():
    if row.blood:
        blood = [x.lower() for x in row.blood]
        if 'non-magic people|muggle' in blood:
            df_wiki.at[idx, 'blood'] = "Muggle"
        elif 'muggle-born' in blood:
            df_wiki.at[idx, 'blood'] = "Muggle-Born"
        elif 'pure-blood' in blood:
            df_wiki.at[idx, 'blood'] = "Pure-Blood"
        elif 'half-blood' in blood:
            df_wiki.at[idx, 'blood'] = "Half-Blood"
        else:
            df_wiki.at[idx, 'blood'] = "Unknown"
    else:
        df_wiki.at[idx, 'blood'] = "Unknown"

# %% [markdown]
# ---

# %%
# Let's see if the information was stored

df_wiki.head(3)
# Out:
#                                        wiki  book alternative_wiki  \
# 0                                     Tufty     1             None
# 1                          Mirror of Erised     1             None
# 2  Quirinus Quirrell's first mountain troll     1             None
#
#                                                 text  \
# 0  {{Pet individual infobox\n|image = \n|name = T...
# 1  {{Spoiler|PAS|WU}}\n{{Object infobox\n|name = ...
# 2  {{Youmay|the troll brought in on [[Hallowe'en]...
#
#                                                links house    type    blood  \
# 0  [Harry Potter, Mr Tibbles, Dudley Dursley, Ara...  None     Pet  Unknown
# 1  [Argus Filch, Percival Dumbledore, Ronald Weas...  None  Object  Unknown
# 2  [Harry Potter, Parvati Patil, Minerva McGonaga...  None     Pet  Unknown
#
#     job family loyalties
# 0  None   None      None
# 1  None   None      None
# 2  None   None      None

# %% [markdown]
# # Success!
#
# _The different attributes are now stored in the dataframe, and we can start analysing the different entities fetched from the WikiPage._
#
# **Storing this version of the DataFrame:**

# %%
os.chdir(hd)

# Creating a new folder to store the dataframe and switching to it:
if not os.path.exists("dataframes"):
    os.mkdir("dataframes")
os.chdir(hd + "/dataframes")

# And fetching the files is done, saving the dataframe:
with open('cleaned_wiki_df.pkl', 'wb') as f:
    pickle.dump(df_wiki, f)

# %% [markdown]
# ---
