# %%
# Read in the dataframe
import pickle
import pandas as pd
import numpy as np

df = pd.read_pickle("script_df.pkl")
df.head()
# Out:
#   movie_nr sentence_number   character  \
# 0        1               1  Dumbledore
# 1        1               2  McGonagall
# 2        1               3  Dumbledore
# 3        1               4  McGonagall
# 4        1               5  Dumbledore
#
#                                             sentence  \
# 0  I should have known that you would be here...P...
# 1  Good evening, Professor Dumbledore. Are the ru...
# 2   I'm afraid so, Professor. The good, and the bad.
# 3                                       And the boy?
# 4                            Hagrid is bringing him.
#
#                                           scene_desc scene_id
# 0  A neighbourhood on a street called Privet Driv...        1
# 1  The cat meows, sniffs out and the camera pans ...        1
# 2  The cat meows, sniffs out and the camera pans ...        1
# 3  The cat meows, sniffs out and the camera pans ...        1
# 4  The cat meows, sniffs out and the camera pans ...        1

# %%
# All the movie titles in correct order
move_titles = ["Harry Potter and the Philosopher' Sstone","Harry Potter and the Chamber of Secrets",
              "Harry Potter and the Prisoner of Azkaban","Harry Potter and the Goblet of Fire",
              "Harry Potter and the Order of the Phoenix","Harry Potter and the Half-Blood Prince",
              "Harry Potter and the Deathly Hallows – Part 1","Harry Potter and the Deathly Hallows – Part 2"]

# %%
# Lets first fix the characters So they all have lower_case letters
df['character'] = df['character'].str.lower()

# %%
# df[df.sentence != ''].groupby('character').size()
sentence_count = df[df.sentence != ''].groupby('character').size()
sentence_count_limit = sentence_count[sentence_count > 2]

# %%
# some general last fixing 
mapping_voldemort = {'voldemort':['voldermort','tom riddle']}

# %%
sentence_count_limit
# Out:
# character
# (more )          3
# (more)           8
# (v.o. )          2
# (v.o.)           8
# aberforth       19
#                 ..
# yaxley           8
# young hagrid     3
# young snape      2
# young witch      2
# young wizard     2
# Length: 212, dtype: int64

# %% [markdown]
# ## General statistics about the script data set:

# %%
nr_lines = df.groupby(['movie_nr','character'])['sentence'].size()
nr_lines
# Out:
# movie_nr  character
# 1         all             4
#           boy             5
#           class           2
#           crowd           2
#           draco          14
#                          ..
# 8         warlock         1
#           wormtail        1
#           yaxley          2
#           young girl      1
#           young snape     2
# Name: sentence, Length: 612, dtype: int64

# %%
# Get how many sentences in movies
df.groupby('movie_nr')['sentence'].count()

#how many scenes in movie 
# df.groupby(['movie_nr','scene_id']).count()

#How long the text spoken is in each movie
# total_text = [df['sentence'][df.movie_nr == i].str()]
# Out:
# movie_nr
# 1     816
# 2     984
# 3     872
# 4     737
# 5    1623
# 6    1086
# 7     988
# 8     886
# Name: sentence, dtype: int64

# %%
# Lets create a dictionary with the total text by each character:
# df.character[(df.sentence != '')
# char = 'dobby'
# df.sentence[df.character.str.lower() == 'dobby'].str.cat(sep=' ')

# %%
# test = df[df.movie_nr == 1].groupby(['character'])['sentence']
# len(test[test.index == 'Harry'])

# %%
# lets create connection between characters 

# for movie in df.movie_nr:
# movie = 1
# df_names = df['character'].unique()
# df_store = df[df.movie_nr == movie].groupby(['scene_id','movie_nr'])['character'].unique()

con_str = dict()
for movie in df.movie_nr.unique():
    df_store = df[df.movie_nr == movie].groupby(['scene_id','movie_nr'])['character'].unique()
    for scene in df_store:
    #     print("Scene length:",len(scene))
        for idx in range(len(scene)-1):
            for idx2 in range(idx+1,len(scene)):
    #             print(scene[idx],scene[idx2])
                if (scene[idx],scene[idx2]) in con_str:
                    con_str[(scene[idx],scene[idx2])] += 1
                else:
                    con_str[(scene[idx],scene[idx2])] = 1
con_str
# Out:
# {('dumbledore', 'mcgonagall'): 3,
#  ('dumbledore', 'hagrid'): 6,
#  ('dumbledore', 'petunia'): 1,
#  ('dumbledore', 'dudley'): 1,
#  ('dumbledore', 'vernon'): 1,
#  ('dumbledore', 'harry'): 26,
#  ('mcgonagall', 'hagrid'): 1,
#  ('mcgonagall', 'petunia'): 1,
#  ('mcgonagall', 'dudley'): 1,
#  ('mcgonagall', 'vernon'): 1,
#  ('mcgonagall', 'harry'): 10,
#  ('hagrid', 'petunia'): 2,
#  ('hagrid', 'dudley'): 2,
#  ('hagrid', 'vernon'): 1,
#  ('hagrid', 'harry'): 19,
#  ('petunia', 'dudley'): 2,
#  ('petunia', 'vernon'): 4,
#  ('petunia', 'harry'): 2,
#  ('dudley', 'vernon'): 3,
#  ('dudley', 'harry'): 6,
#  ('vernon', 'harry'): 4,
#  ('dudley', 'snake'): 1,
#  ('dudley', 'man'): 1,
#  ('dudley', 'petunia'): 2,
#  ('vernon', 'snake'): 1,
#  ('vernon', 'man'): 1,
#  ('vernon', 'petunia'): 3,
#  ('harry', 'snake'): 1,
#  ('harry', 'man'): 5,
#  ('harry', 'petunia'): 3,
#  ('snake', 'man'): 1,
#  ('snake', 'petunia'): 1,
#  ('man', 'petunia'): 1,
#  ('harry', 'vernon'): 3,
#  ('vernon', 'dudley'): 3,
#  ('harry', 'dudley'): 3,
#  ('harry', 'hagrid'): 27,
#  ('harry', 'all'): 4,
#  ('vernon', 'hagrid'): 1,
#  ('vernon', 'all'): 1,
#  ('hagrid', 'all'): 2,
#  ('petunia', 'all'): 1,
#  ('all', 'dudley'): 1,
#  ('harry', 'tom'): 2,
#  ('harry', 'witch'): 1,
#  ('harry', 'quirrell'): 5,
#  ('harry', 'boy'): 3,
#  ('harry', 'goblin'): 1,
#  ('hagrid', 'tom'): 1,
#  ('hagrid', 'man'): 2,
#  ('hagrid', 'witch'): 1,
#  ('hagrid', 'quirrell'): 1,
#  ('hagrid', 'boy'): 1,
#  ('hagrid', 'goblin'): 1,
#  ('tom', 'man'): 1,
#  ('tom', 'witch'): 1,
#  ('tom', 'quirrell'): 1,
#  ('tom', 'boy'): 1,
#  ('tom', 'goblin'): 1,
#  ('man', 'witch'): 1,
#  ('man', 'quirrell'): 2,
#  ('man', 'boy'): 1,
#  ('man', 'goblin'): 1,
#  ('witch', 'quirrell'): 1,
#  ('witch', 'boy'): 1,
#  ('witch', 'goblin'): 1,
#  ('quirrell', 'boy'): 2,
#  ('quirrell', 'goblin'): 1,
#  ('boy', 'goblin'): 1,
#  ('griphook', 'hagrid'): 1,
#  ('griphook', 'harry'): 5,
#  ('harry', 'ollivander'): 2,
#  ('hagrid', 'ollivander'): 1,
#  ('man', 'harry'): 2,
#  ('man', 'trainmaster'): 1,
#  ('man', 'george'): 2,
#  ('man', 'fred'): 2,
#  ('harry', 'trainmaster'): 1,
#  ('harry', 'george'): 16,
#  ('harry', 'fred'): 15,
#  ('trainmaster', 'george'): 1,
#  ('trainmaster', 'fred'): 1,
#  ('george', 'fred'): 8,
#  ('ron', 'harry'): 111,
#  ('ron', 'woman'): 1,
#  ('harry', 'woman'): 3,
#  ('harry', 'ron'): 116,
#  ('harry', 'frog'): 1,
#  ('harry', 'hermione'): 107,
#  ('ron', 'frog'): 1,
#  ('ron', 'hermione'): 91,
#  ('frog', 'hermione'): 1,
#  ('hagrid', 'ron'): 15,
#  ('mcgonagall', 'neville'): 1,
#  ('mcgonagall', 'draco'): 2,
#  ('mcgonagall', 'hermione'): 2,
#  ('mcgonagall', 'dumbledore'): 2,
#  ('mcgonagall', 'ron'): 1,
#  ('mcgonagall', 'seamus'): 1,
#  ('mcgonagall', 'percy'): 1,
#  ('mcgonagall', 'nick'): 1,
#  ('mcgonagall', 'girl'): 1,
#  ('neville', 'draco'): 2,
#  ('neville', 'harry'): 13,
#  ('neville', 'hermione'): 10,
#  ('neville', 'dumbledore'): 3,
#  ('neville', 'ron'): 10,
#  ('neville', 'seamus'): 11,
#  ('neville', 'percy'): 1,
#  ('neville', 'nick'): 1,
#  ('neville', 'girl'): 4,
#  ('draco', 'harry'): 9,
#  ('draco', 'hermione'): 12,
#  ('draco', 'dumbledore'): 2,
#  ('draco', 'ron'): 10,
#  ('draco', 'seamus'): 4,
#  ('draco', 'percy'): 1,
#  ('draco', 'nick'): 1,
#  ('draco', 'girl'): 2,
#  ('harry', 'dumbledore'): 25,
#  ('harry', 'seamus'): 8,
#  ('harry', 'percy'): 3,
#  ('harry', 'nick'): 1,
#  ('harry', 'girl'): 5,
#  ('hermione', 'dumbledore'): 9,
#  ('hermione', 'ron'): 87,
#  ('hermione', 'seamus'): 6,
#  ('hermione', 'percy'): 1,
#  ('hermione', 'nick'): 1,
#  ('hermione', 'girl'): 2,
#  ('dumbledore', 'ron'): 8,
#  ('dumbledore', 'seamus'): 2,
#  ('dumbledore', 'percy'): 2,
#  ('dumbledore', 'nick'): 1,
#  ('dumbledore', 'girl'): 2,
#  ('ron', 'seamus'): 9,
#  ('ron', 'percy'): 4,
#  ('ron', 'nick'): 1,
#  ('ron', 'girl'): 3,
#  ('seamus', 'percy'): 1,
#  ('seamus', 'nick'): 1,
#  ('seamus', 'girl'): 1,
#  ('percy', 'nick'): 1,
#  ('percy', 'girl'): 3,
#  ('nick', 'girl'): 1,
#  ('percy', 'boy'): 1,
#  ('percy', 'neville'): 2,
#  ('percy', 'ron'): 3,
#  ('percy', 'harry'): 3,
#  ('boy', 'neville'): 1,
#  ('boy', 'ron'): 2,
#  ('boy', 'harry'): 2,
#  ('boy', 'girl'): 1,
#  ('woman', 'percy'): 1,
#  ('woman', 'girl'): 1,
#  ('ron', 'mcgonagall'): 9,
#  ('snape', 'harry'): 13,
#  ('seamus', 'harry'): 7,
#  ('seamus', 'ron'): 7,
#  ('seamus', 'hermione'): 7,
#  ('seamus', 'neville'): 9,
#  ('harry', 'neville'): 22,
#  ('ron', 'neville'): 19,
#  ('hermione', 'neville'): 17,
#  ('hooch', 'class'): 1,
#  ('hooch', 'harry'): 1,
#  ('hooch', 'draco'): 2,
#  ('hooch', 'hermione'): 2,
#  ('hooch', 'ron'): 2,
#  ('hooch', 'neville'): 1,
#  ('hooch', 'girl'): 1,
#  ('hooch', 'students'): 1,
#  ('hooch', 'boy'): 1,
#  ('hooch', 'mcgonagall'): 2,
#  ('class', 'harry'): 1,
#  ('class', 'draco'): 1,
#  ('class', 'hermione'): 1,
#  ('class', 'ron'): 1,
#  ('class', 'neville'): 1,
#  ('class', 'girl'): 1,
#  ('class', 'students'): 1,
#  ('class', 'boy'): 1,
#  ('class', 'mcgonagall'): 1,
#  ('harry', 'draco'): 14,
#  ('harry', 'students'): 1,
#  ('harry', 'mcgonagall'): 9,
#  ('draco', 'neville'): 4,
#  ('draco', 'students'): 1,
#  ('draco', 'boy'): 1,
#  ('draco', 'mcgonagall'): 4,
#  ('hermione', 'students'): 2,
#  ('hermione', 'boy'): 1,
#  ('hermione', 'mcgonagall'): 4,
#  ('ron', 'students'): 2,
#  ('ron', 'boy'): 1,
#  ('neville', 'students'): 1,
#  ('neville', 'boy'): 2,
#  ('neville', 'mcgonagall'): 1,
#  ('girl', 'students'): 1,
#  ('girl', 'boy'): 2,
#  ('girl', 'mcgonagall'): 1,
#  ('students', 'boy'): 1,
#  ('students', 'mcgonagall'): 1,
#  ('boy', 'mcgonagall'): 2,
#  ('quirrell', 'mcgonagall'): 1,
#  ('nick', 'ron'): 1,
#  ('nick', 'harry'): 1,
#  ('nick', 'fred'): 1,
#  ('nick', 'george'): 1,
#  ('nick', 'hermione'): 1,
#  ('ron', 'fred'): 14,
#  ('ron', 'george'): 13,
#  ('fred', 'george'): 18,
#  ('fred', 'hermione'): 8,
#  ('george', 'hermione'): 6,
#  ('ron', 'filch'): 3,
#  ('ron', 'all'): 3,
#  ('harry', 'filch'): 9,
#  ('hermione', 'filch'): 3,
#  ('hermione', 'all'): 3,
#  ('filch', 'all'): 1,
#  ('hermione', 'harry'): 103,
#  ('oliver', 'harry'): 1,
#  ('flitwick', 'draco'): 1,
#  ('flitwick', 'ron'): 2,
#  ('flitwick', 'hermione'): 2,
#  ('flitwick', 'seamus'): 1,
#  ('flitwick', 'harry'): 1,
#  ('neville', 'quirrell'): 1,
#  ('quirrell', 'dumbledore'): 1,
#  ('quirrell', 'girl'): 1,
#  ('dumbledore', 'boy'): 1,
#  ('hermione', 'quirrell'): 1,
#  ('ron', 'quirrell'): 1,
#  ('mcgonagall', 'quirrell'): 1,
#  ('ron', 'snape'): 6,
#  ('hermione', 'snape'): 6,
#  ('harry', 'snape'): 14,
#  ('oiiver', 'harry'): 1,
#  ('oiiver', 'oliver'): 1,
#  ('oiiver', 'lee'): 1,
#  ('oiiver', 'hooch'): 1,
#  ('oiiver', 'hagrid'): 1,
#  ('oiiver', 'gryffindors'): 1,
#  ('oiiver', 'flint'): 1,
#  ('oiiver', 'crowd'): 1,
#  ('oiiver', 'hermione'): 1,
#  ('oiiver', 'ron'): 1,
#  ('oiiver', 'man'): 1,
#  ('oiiver', 'snape'): 1,
#  ('oiiver', 'all'): 1,
#  ('oiiver', 'draco'): 1,
#  ('oiiver', 'mcgonagall'): 1,
#  ('harry', 'oliver'): 1,
#  ('harry', 'lee'): 2,
#  ('harry', 'hooch'): 2,
#  ('harry', 'gryffindors'): 1,
#  ('harry', 'flint'): 1,
#  ('harry', 'crowd'): 1,
#  ('oliver', 'lee'): 1,
#  ('oliver', 'hooch'): 1,
#  ('oliver', 'hagrid'): 1,
#  ('oliver', 'gryffindors'): 1,
#  ('oliver', 'flint'): 1,
#  ('oliver', 'crowd'): 1,
#  ('oliver', 'hermione'): 1,
#  ('oliver', 'ron'): 1,
#  ('oliver', 'man'): 1,
#  ('oliver', 'snape'): 1,
#  ('oliver', 'all'): 1,
#  ('oliver', 'draco'): 1,
#  ('oliver', 'mcgonagall'): 1,
#  ('lee', 'hooch'): 1,
#  ('lee', 'hagrid'): 1,
#  ('lee', 'gryffindors'): 1,
#  ('lee', 'flint'): 1,
#  ('lee', 'crowd'): 1,
#  ('lee', 'hermione'): 1,
#  ('lee', 'ron'): 1,
#  ('lee', 'man'): 1,
#  ('lee', 'snape'): 1,
#  ('lee', 'all'): 1,
#  ('lee', 'draco'): 1,
#  ('lee', 'mcgonagall'): 1,
#  ('hooch', 'hagrid'): 1,
#  ('hooch', 'gryffindors'): 1,
#  ('hooch', 'flint'): 1,
#  ('hooch', 'crowd'): 1,
#  ('hooch', 'man'): 1,
#  ('hooch', 'snape'): 1,
#  ('hooch', 'all'): 1,
#  ('hagrid', 'gryffindors'): 1,
#  ('hagrid', 'flint'): 1,
#  ('hagrid', 'crowd'): 1,
#  ('hagrid', 'hermione'): 13,
#  ('hagrid', 'snape'): 1,
#  ('hagrid', 'draco'): 5,
#  ('hagrid', 'mcgonagall'): 1,
#  ('gryffindors', 'flint'): 1,
#  ('gryffindors', 'crowd'): 1,
#  ('gryffindors', 'hermione'): 1,
#  ('gryffindors', 'ron'): 1,
#  ('gryffindors', 'man'): 1,
#  ('gryffindors', 'snape'): 1,
#  ('gryffindors', 'all'): 1,
#  ('gryffindors', 'draco'): 1,
#  ('gryffindors', 'mcgonagall'): 1,
#  ('flint', 'crowd'): 1,
#  ('flint', 'hermione'): 2,
#  ('flint', 'ron'): 1,
#  ('flint', 'man'): 1,
#  ('flint', 'snape'): 1,
#  ('flint', 'all'): 1,
#  ('flint', 'draco'): 2,
#  ('flint', 'mcgonagall'): 1,
#  ('crowd', 'hermione'): 2,
#  ('crowd', 'ron'): 1,
#  ('crowd', 'man'): 1,
#  ('crowd', 'snape'): 1,
#  ('crowd', 'all'): 1,
#  ('crowd', 'draco'): 1,
#  ('crowd', 'mcgonagall'): 1,
#  ('hermione', 'man'): 1,
#  ('hermione', 'draco'): 8,
#  ('ron', 'man'): 1,
#  ('ron', 'draco'): 12,
#  ('man', 'snape'): 2,
#  ('man', 'all'): 1,
#  ('man', 'draco'): 1,
#  ('man', 'mcgonagall'): 1,
#  ('snape', 'all'): 1,
#  ('snape', 'draco'): 3,
#  ('snape', 'mcgonagall'): 1,
#  ('all', 'draco'): 1,
#  ('all', 'mcgonagall'): 1,
#  ('man', 'filch'): 1,
#  ('quirrell', 'snape'): 1,
#  ('quirrell', 'filch'): 1,
#  ('snape', 'filch'): 3,
#  ('filch', 'hagrid'): 1,
#  ('filch', 'hermione'): 2,
#  ('filch', 'draco'): 1,
#  ('harry', 'firenze'): 1,
#  ('draco', 'firenze'): 1,
#  ('draco', 'hagrid'): 3,
#  ('firenze', 'hermione'): 1,
#  ('firenze', 'hagrid'): 1,
#  ('hermione', 'hagrid'): 12,
#  ('ron', 'hagrid'): 7,
#  ('harry', 'voldemort'): 7,
#  ('quirrell', 'voldemort'): 1,
#  ('dumbledore', 'students'): 1,
#  ('dumbledore', 'draco'): 1,
#  ('dumbledore', 'hermione'): 7,
#  ('dumbledore', 'lee'): 1,
#  ('students', 'draco'): 2,
#  ('students', 'harry'): 1,
#  ('students', 'hermione'): 1,
#  ('students', 'hagrid'): 1,
#  ('students', 'seamus'): 1,
#  ('students', 'lee'): 1,
#  ('draco', 'lee'): 1,
#  ('hermione', 'lee'): 1,
#  ('hagrid', 'seamus'): 1,
#  ('hagrid', 'lee'): 1,
#  ('seamus', 'lee'): 1,
#  ('harry', 'uncle vernon'): 5,
#  ('uncle vernon', 'harry'): 6,
#  ('uncle vernon', 'dudley'): 3,
#  ('uncle vernon', 'aunt petunia'): 2,
#  ('harry', 'aunt petunia'): 2,
#  ('dudley', 'aunt petunia'): 1,
#  ('dobby', 'harry'): 3,
#  ('harry', 'dobby'): 9,
#  ('uncle vernon', 'mr. mason'): 1,
#  ('uncle vernon', 'dobby'): 1,
#  ('dobby', 'uncle vernon'): 1,
#  ('dudley', 'same scene - later'): 1,
#  ('dudley', 'ron'): 1,
#  ('harry', 'same scene - later'): 2,
#  ('same scene - later', 'ron'): 1,
#  ('harry', "closeup - harry's trunk 13b"): 1,
#  ('harry', "insert - fred's foot 13c"): 1,
#  ('ron', "closeup - harry's trunk 13b"): 1,
#  ('ron', "insert - fred's foot 13c"): 1,
#  ("closeup - harry's trunk 13b", "insert - fred's foot 13c"): 1,
#  ('uncle vernon', 'ron'): 1,
#  ('ron', 'mrs. weasley'): 3,
#  ('ron', 'ginny'): 14,
#  ('ron', 'mr. weasley'): 2,
#  ('ron', 'harry /ron/fred/george'): 1,
#  ('harry', 'mrs. weasley'): 5,
#  ('harry', 'ginny'): 19,
#  ('harry', 'mr. weasley'): 5,
#  ('harry', 'harry /ron/fred/george'): 1,
#  ('mrs. weasley', 'ginny'): 7,
#  ('mrs. weasley', 'george'): 2,
#  ('mrs. weasley', 'mr. weasley'): 2,
#  ('mrs. weasley', 'fred'): 2,
#  ('mrs. weasley', 'harry /ron/fred/george'): 1,
#  ('ginny', 'george'): 4,
#  ('ginny', 'mr. weasley'): 2,
#  ('ginny', 'fred'): 4,
#  ('ginny', 'harry /ron/fred/george'): 1,
#  ('george', 'mr. weasley'): 1,
#  ('george', 'harry /ron/fred/george'): 1,
#  ('mr. weasley', 'fred'): 2,
#  ('mr. weasley', 'harry /ron/fred/george'): 1,
#  ('fred', 'harry /ron/fred/george'): 1,
#  ('mrs. weasley', 'ron'): 5,
#  ('mrs. weasley', 'harry'): 8,
#  ('mrs. weasley', 'percy'): 1,
#  ('mr. borgin', 'lucius malfoy'): 1,
#  ('mr. borgin', 'draco'): 1,
#  ('lucius malfoy', 'draco'): 2,
#  ('aged witch', 'harry'): 1,
#  ('aged witch', 'hagrid'): 1,
#  ('hagrid', 'mr. weasley'): 1,
#  ('hagrid', 'mrs. weasley'): 1,
#  ('hermione', 'mr. weasley'): 2,
#  ('hermione', 'mrs. weasley'): 2,
#  ('mr. weasley', 'mrs. weasley'): 2,
#  ('mrs. weasley', 'short man'): 1,
#  ('mrs. weasley', 'gilderoy lockhart'): 1,
#  ('mrs. weasley', 'draco'): 1,
#  ('mrs. weasley', 'lucius malfoy'): 2,
#  ('mrs. weasley', 'hermione'): 4,
#  ('mrs. weasley', 'hagrid'): 3,
#  ('ron', 'short man'): 1,
#  ('ron', 'gilderoy lockhart'): 6,
#  ('ron', 'lucius malfoy'): 3,
#  ('short man', 'gilderoy lockhart'): 1,
#  ('short man', 'harry'): 1,
#  ('short man', 'draco'): 1,
#  ('short man', 'ginny'): 1,
#  ('short man', 'lucius malfoy'): 1,
#  ('short man', 'hermione'): 1,
#  ('short man', 'mr. weasley'): 1,
#  ('short man', 'hagrid'): 1,
#  ('gilderoy lockhart', 'harry'): 5,
#  ('gilderoy lockhart', 'draco'): 2,
#  ('gilderoy lockhart', 'ginny'): 1,
#  ('gilderoy lockhart', 'lucius malfoy'): 1,
#  ('gilderoy lockhart', 'hermione'): 3,
#  ('gilderoy lockhart', 'mr. weasley'): 1,
#  ('gilderoy lockhart', 'hagrid'): 1,
#  ('harry', 'lucius malfoy'): 4,
#  ('draco', 'ginny'): 1,
#  ('draco', 'lucius malfoy'): 1,
#  ('draco', 'mr. weasley'): 1,
#  ('ginny', 'lucius malfoy'): 3,
#  ('ginny', 'hermione'): 7,
#  ('ginny', 'hagrid'): 2,
#  ('lucius malfoy', 'hermione'): 2,
#  ('lucius malfoy', 'mr. weasley'): 1,
#  ('lucius malfoy', 'hagrid'): 2,
#  ('mr. weasley', 'hagrid'): 1,
#  ('ron', 'guard'): 1,
#  ('guard', 'harry'): 1,
#  ('ron', 'harry /ron'): 5,
#  ('harry', 'harry /ron'): 5,
#  ('snape', 'ron'): 4,
#  ('snape', 'albus dumbledore'): 1,
#  ('snape', 'dumbledore'): 7,
#  ('ron', 'albus dumbledore'): 1,
#  ('ron', 'dumbledore'): 7,
#  ('albus dumbledore', 'harry'): 1,
#  ('albus dumbledore', 'dumbledore'): 1,
#  ('neville', 'professor sprout'): 1,
#  ('seamus', 'professor sprout'): 1,
#  ('hermione', 'professor sprout'): 1,
#  ('ron', 'professor sprout'): 1,
#  ('penelope clearwater', 'percy'): 1,
#  ('penelope clearwater', 'nearly headless nick'): 1,
#  ('penelope clearwater', 'ron'): 1,
#  ('penelope clearwater', 'harry'): 1,
#  ('penelope clearwater', 'colin'): 1,
#  ('penelope clearwater', 'dean thomas'): 1,
#  ('penelope clearwater', 'seamus'): 1,
#  ('penelope clearwater', 'neville'): 1,
#  ('penelope clearwater', "at work and it's entirely your"): 1,
#  ('penelope clearwater', "of line we'll bring you straight"): 1,
#  ('percy', 'nearly headless nick'): 1,
#  ('percy', 'colin'): 1,
#  ('percy', 'dean thomas'): 1,
#  ('percy', 'seamus'): 1,
#  ('percy', "at work and it's entirely your"): 1,
#  ('percy', "of line we'll bring you straight"): 1,
#  ('nearly headless nick', 'ron'): 1,
#  ('nearly headless nick', 'harry'): 1,
#  ('nearly headless nick', 'colin'): 1,
#  ('nearly headless nick', 'dean thomas'): 1,
#  ('nearly headless nick', 'seamus'): 1,
#  ('nearly headless nick', 'neville'): 1,
#  ('nearly headless nick', "at work and it's entirely your"): 1,
#  ('nearly headless nick', "of line we'll bring you straight"): 1,
#  ('ron', 'colin'): 2,
#  ('ron', 'dean thomas'): 3,
#  ('ron', "at work and it's entirely your"): 1,
#  ('ron', "of line we'll bring you straight"): 1,
#  ('harry', 'colin'): 2,
#  ('harry', 'dean thomas'): 1,
#  ('harry', "at work and it's entirely your"): 1,
#  ('harry', "of line we'll bring you straight"): 1,
#  ('colin', 'dean thomas'): 1,
#  ('colin', 'seamus'): 1,
#  ('colin', 'neville'): 1,
#  ('colin', "at work and it's entirely your"): 1,
#  ('colin', "of line we'll bring you straight"): 1,
#  ('dean thomas', 'seamus'): 1,
#  ('dean thomas', 'neville'): 2,
#  ('dean thomas', "at work and it's entirely your"): 1,
#  ('dean thomas', "of line we'll bring you straight"): 1,
#  ('seamus', "at work and it's entirely your"): 1,
#  ('seamus', "of line we'll bring you straight"): 1,
#  ('neville', "at work and it's entirely your"): 1,
#  ('neville', "of line we'll bring you straight"): 1,
#  ("at work and it's entirely your", "of line we'll bring you straight"): 1,
#  ('gilderoy lockhart', 'ron'): 3,
#  ('gilderoy lockhart', 'dissolve'): 1,
#  ('gilderoy lockhart', 'same scene - later'): 1,
#  ('gilderoy lockhart', 'seamus'): 1,
#  ('gilderoy lockhart', 'neville'): 1,
#  ('ron', 'dissolve'): 2,
#  ('ron', 'same scene - later'): 1,
#  ('harry', 'dissolve'): 4,
#  ('dissolve', 'same scene - later'): 1,
#  ('dissolve', 'seamus'): 1,
#  ('dissolve', 'hermione'): 1,
#  ('dissolve', 'neville'): 1,
#  ('same scene - later', 'seamus'): 1,
#  ('same scene - later', 'hermione'): 1,
#  ('same scene - later', 'neville'): 1,
#  ('wood', 'ron'): 1,
#  ('wood', 'flint'): 1,
#  ('wood', 'harry'): 1,
#  ('wood', 'draco'): 1,
#  ('wood', 'hermione'): 1,
#  ('wood', 'colin'): 1,
#  ('ron', 'flint'): 1,
#  ('flint', 'harry'): 1,
#  ('flint', 'colin'): 1,
#  ('draco', 'colin'): 1,
#  ('hermione', 'colin'): 2,
#  ('gilderoy lockhart', 'voice'): 1,
#  ('voice', 'harry'): 5,
#  ('voice', 'hermione'): 3,
#  ('voice', 'ron'): 1,
#  ('ron', 'the chamber of secrets has been opened'): 1,
#  ('the chamber of secrets has been opened', 'hermione'): 1,
#  ('the chamber of secrets has been opened', 'harry'): 1,
#  ('the chamber of secrets has been opened', 'draco'): 1,
#  ('the chamber of secrets has been opened', 'filch'): 1,
#  ('the chamber of secrets has been opened', 'dumbledore'): 1,
#  ('the chamber of secrets has been opened', 'gilderoy lockhart'): 1,
#  ('the chamber of secrets has been opened', 'snape'): 1,
#  ('hermione', 'gilderoy lockhart'): 2,
#  ('harry', 'gilderoy lockhart'): 5,
#  ('draco', 'filch'): 1,
#  ('draco', 'gilderoy lockhart'): 2,
#  ('draco', 'snape'): 1,
#  ('filch', 'dumbledore'): 2,
#  ('filch', 'gilderoy lockhart'): 1,
#  ('filch', 'snape'): 2,
#  ('dumbledore', 'gilderoy lockhart'): 1,
#  ('dumbledore', 'snape'): 4,
#  ('gilderoy lockhart', 'snape'): 3,
#  ('hagrid', 'george'): 1,
#  ('hagrid', 'gilderoy lockhart'): 1,
#  ('draco', 'george'): 2,
#  ('george', 'ron'): 6,
#  ('george', 'gilderoy lockhart'): 1,
#  ('george', 'harry'): 6,
#  ('madam pomfrey', 'hermione'): 1,
#  ('madam pomfrey', 'colin'): 1,
#  ('madam pomfrey', "harry's moving pov"): 1,
#  ('madam pomfrey', 'back to scene'): 1,
#  ('madam pomfrey', 'harry'): 2,
#  ('madam pomfrey', 'dobby'): 1,
#  ('madam pomfrey', 'dumbledore'): 1,
#  ('hermione', "harry's moving pov"): 1,
#  ('hermione', 'back to scene'): 2,
#  ('hermione', 'dobby'): 3,
#  ('colin', "harry's moving pov"): 1,
#  ('colin', 'back to scene'): 1,
#  ('colin', 'harry'): 1,
#  ('colin', 'dobby'): 1,
#  ('colin', 'dumbledore'): 1,
#  ("harry's moving pov", 'back to scene'): 1,
#  ("harry's moving pov", 'harry'): 1,
#  ("harry's moving pov", 'dobby'): 1,
#  ("harry's moving pov", 'dumbledore'): 1,
#  ('back to scene', 'harry'): 2,
#  ('back to scene', 'dobby'): 1,
#  ('back to scene', 'dumbledore'): 1,
#  ('dobby', 'dumbledore'): 2,
#  ('hermione', 'young girl comes racing out of the wall. face to face'): 1,
#  ('hermione', 'moaning myrtle'): 2,
#  ('ron', 'young girl comes racing out of the wall. face to face'): 1,
#  ('ron', 'moaning myrtle'): 2,
#  ('young girl comes racing out of the wall. face to face',
#   'moaning myrtle'): 1,
#  ('gilderoy lockhart', 'justin finch-fletchley'): 1,
#  ('gilderoy lockhart', 'harry /ron'): 1,
#  ('gilderoy lockhart', 'justin-finch-fletchley'): 1,
#  ('justin finch-fletchley', 'harry'): 1,
#  ('justin finch-fletchley', 'ron'): 1,
#  ('justin finch-fletchley', 'snape'): 1,
#  ('justin finch-fletchley', 'hermione'): 1,
#  ('justin finch-fletchley', 'harry /ron'): 1,
#  ('justin finch-fletchley', 'draco'): 1,
#  ('justin finch-fletchley', 'justin-finch-fletchley'): 1,
#  ('harry', 'justin-finch-fletchley'): 1,
#  ('ron', 'justin-finch-fletchley'): 1,
#  ('snape', 'hermione'): 4,
#  ('snape', 'harry /ron'): 1,
#  ('snape', 'justin-finch-fletchley'): 1,
#  ('hermione', 'harry /ron'): 3,
#  ('hermione', 'justin-finch-fletchley'): 1,
#  ('harry /ron', 'draco'): 1,
#  ('harry /ron', 'justin-finch-fletchley'): 1,
#  ('draco', 'justin-finch-fletchley'): 1,
#  ('ernie', 'hannah'): 1,
#  ('sorting hat', 'harry'): 1,
#  ('sorting hat', 'dumbledore'): 1,
#  ('sorting hat', 'hagrid'): 1,
#  ('fred', 'ron'): 8,
#  ('fred', 'harry'): 9,
#  ('hermione', 'closeup - the potion'): 1,
#  ('ron', 'closeup - the potion'): 1,
#  ('closeup - the potion', 'harry'): 1,
#  ('percy', 'draco'): 1,
#  ('harry', 'moaning myrtle'): 1,
#  ('moaning myrtle', 'harry'): 2,
#  ('moaning myrtle', 'ron'): 2,
#  ('harry', 'voice'): 2,
#  ('harry', 'tom riddle'): 2,
#  ('voice', 'tom riddle'): 2,
#  ('voice', 'dumbledore'): 1,
#  ('tom riddle', 'dumbledore'): 1,
#  ('voice', 'young hagrid'): 1,
#  ('voice', 'riddle'): 1,
#  ('tom riddle', 'young hagrid'): 1,
#  ('tom riddle', 'riddle'): 1,
#  ('young hagrid', 'riddle'): 1,
#  ('hermione', 'harry /ron/hermione'): 1,
#  ('ron', 'harry /ron/hermione'): 1,
#  ('harry', 'harry /ron/hermione'): 1,
#  ('hagrid', 'harry /ron/hermione'): 1,
#  ('hagrid', 'neville'): 1,
#  ('harry /ron/hermione', 'neville'): 1,
#  ('ron', 'voice'): 2,
#  ('ron', 'wood'): 1,
#  ('voice', 'wood'): 1,
#  ('voice', 'george'): 1,
#  ('hermione', 'wood'): 1,
#  ('hermione', 'george'): 9,
#  ('harry', 'wood'): 1,
#  ('wood', 'george'): 1,
#  ('neville', 'dean thomas'): 3,
#  ('seamus', 'dean thomas'): 4,
#  ('dean thomas', 'harry'): 1,
#  ('dean thomas', 'ron'): 2,
#  ('harry', 'fudge'): 5,
#  ('hagrid', 'dumbledore'): 2,
#  ('hagrid', 'fudge'): 1,
#  ('hagrid', 'lucius malfoy'): 1,
#  ('dumbledore', 'fudge'): 5,
#  ('dumbledore', 'lucius malfoy'): 2,
#  ('ron', 'fudge'): 1,
#  ('fudge', 'lucius malfoy'): 1,
#  ('ron', 'aragog'): 1,
#  ('harry', 'aragog'): 1,
#  ('madam pomfrey', 'ron'): 1,
#  ('gilderoy lockhart', 'professor sprout'): 1,
#  ('snape', 'professor sprout'): 1,
#  ('moaning myrtle', 'gilderoy lockhart'): 1,
#  ('tom riddle', 'ginny'): 1,
#  ('tom riddle', 'harry'): 1,
#  ('ginny', 'harry'): 10,
#  ('ginny', 'gilderoy lockhart'): 1,
#  ('dumbledore', 'ginny'): 4,
#  ('dumbledore', 'mrs. weasley'): 1,
#  ('dumbledore', 'harry /ron'): 1,
#  ('ginny', 'mrs. weasley'): 2,
#  ('ginny', 'harry /ron'): 1,
#  ('mrs. weasley', 'harry /ron'): 1,
#  ('harry /ron', 'harry'): 1,
#  ('harry /ron', 'lucius malfoy'): 1,
#  ('harry', 'lucious malfoy'): 1,
#  ('lucius malfoy', 'lucious malfoy'): 1,
#  ('lucius malfoy', 'dobby'): 1,
#  ('lucius malfoy', 'ron'): 1,
#  ('lucius malfoy', 'dumbledore'): 1,
#  ('lucious malfoy', 'dobby'): 1,
#  ('lucious malfoy', 'hermione'): 1,
#  ('lucious malfoy', 'ron'): 1,
#  ('lucious malfoy', 'dumbledore'): 1,
#  ('lucious malfoy', 'hagrid'): 1,
#  ('dobby', 'hermione'): 1,
#  ('dobby', 'ron'): 2,
#  ('dobby', 'hagrid'): 1,
#  ("harry's room -— same time - middle of the night 2", 'harry'): 1,
#  ('aunt petunia', 'aunt marge'): 1,
#  ('aunt petunia', 'harry'): 2,
#  ('aunt petunia', 'uncle vernon'): 1,
#  ('aunt marge', 'harry'): 2,
#  ('aunt marge', 'uncle vernon'): 1,
#  ('uncle vernon', 'aunt marge'): 2,
#  ('aunt marge', 'aunt petunia'): 1,
#  ('harry', 'stan shunpike'): 1,
#  ('disheveled wizard', 'stan shunpike'): 1,
#  ('disheveled wizard', 'shrunken head'): 1,
#  ('disheveled wizard', 'harry'): 1,
#  ('stan shunpike', 'shrunken head'): 1,
#  ('stan shunpike', 'harry'): 1,
#  ('shrunken head', 'harry'): 1,
#  ('harry', 'cornelius fudge'): 2,
#  ('tom', 'cornelius fudge'): 1,
#  ('ron', 'hermione/ron'): 2,
#  ('ron', 'closeup - a dog-eared clipping'): 1,
#  ('hermione', 'hermione/ron'): 3,
#  ('hermione', 'closeup - a dog-eared clipping'): 1,
#  ('hermione/ron', 'closeup - a dog-eared clipping'): 1,
#  ('harry', 'arthur weasley'): 3,
#  ('ron', 'arthur weasley'): 4,
#  ('hermione', 'fred'): 8,
#  ('hermione', 'arthur weasley'): 2,
#  ('hermione', 'ginny'): 9,
#  ('george', 'mrs. weasley'): 1,
#  ('george', 'arthur weasley'): 2,
#  ('george', 'ginny'): 3,
#  ('fred', 'mrs. weasley'): 1,
#  ('fred', 'arthur weasley'): 2,
#  ('fred', 'ginny'): 3,
#  ('mrs. weasley', 'arthur weasley'): 2,
#  ('arthur weasley', 'ginny'): 1,
#  ('harry', 'harry /hermione/ron'): 2,
#  ('ron', 'harry /hermione/ron'): 2,
#  ('hermione', 'harry /hermione/ron'): 2,
#  ('neville', 'harry /hermione/ron'): 1,
#  ('ron', 'professor lupin'): 3,
#  ('harry', 'professor lupin'): 6,
#  ('hermione', 'professor lupin'): 3,
#  ('professor trelawney', 'hermione'): 2,
#  ('professor trelawney', 'ron'): 1,
#  ('professor trelawney', 'neville'): 1,
#  ('professor trelawney', 'teacup - detail - later'): 1,
#  ('professor trelawney', 'parvati'): 1,
#  ('professor trelawney', 'seamus'): 1,
#  ('professor trelawney', 'dean thomas'): 1,
#  ('professor trelawney', 'lavender'): 2,
#  ('hermione', 'teacup - detail - later'): 1,
#  ('hermione', 'parvati'): 2,
#  ('hermione', 'dean thomas'): 2,
#  ('hermione', 'lavender'): 3,
#  ('ron', 'teacup - detail - later'): 1,
#  ('ron', 'parvati'): 3,
#  ('ron', 'lavender'): 2,
#  ('neville', 'teacup - detail - later'): 1,
#  ('neville', 'parvati'): 2,
#  ('neville', 'lavender'): 2,
#  ('teacup - detail - later', 'parvati'): 1,
#  ('teacup - detail - later', 'seamus'): 1,
#  ('teacup - detail - later', 'dean thomas'): 1,
#  ('teacup - detail - later', 'lavender'): 1,
#  ('parvati', 'seamus'): 1,
#  ('parvati', 'dean thomas'): 2,
#  ('parvati', 'lavender'): 1,
#  ('seamus', 'lavender'): 2,
#  ('dean thomas', 'lavender'): 1,
#  ('pansy', 'draco'): 1,
#  ('pansy', 'ron'): 1,
#  ('pansy', 'harry'): 1,
#  ('pansy', 'hermione'): 1,
#  ('pansy', 'seamus'): 1,
#  ('pansy', 'neville'): 1,
#  ('pansy', 'lavender'): 1,
#  ('pansy', 'lavendar'): 1,
#  ('pansy', 'bem'): 1,
#  ('draco', 'lavender'): 1,
#  ('draco', 'lavendar'): 1,
#  ('draco', 'bem'): 1,
#  ('ron', 'lavendar'): 1,
#  ('ron', 'bem'): 1,
#  ('harry', 'lavender'): 1,
#  ('harry', 'lavendar'): 1,
#  ('harry', 'bem'): 1,
#  ('hermione', 'lavendar'): 1,
#  ('hermione', 'bem'): 1,
#  ('seamus', 'lavendar'): 1,
#  ('seamus', 'bem'): 1,
#  ('neville', 'lavendar'): 1,
#  ('neville', 'bem'): 1,
#  ('lavender', 'lavendar'): 1,
#  ('lavender', 'bem'): 1,
#  ('lavendar', 'bem'): 1,
#  ('bem,', 'professor lupin'): 1,
#  ('bem,', 'seamus'): 1,
#  ('bem,', 'hermione'): 1,
#  ('bem,', 'ron'): 1,
#  ('bem,', 'students'): 1,
#  ('bem,', 'draco'): 1,
#  ('bem,', 'neville'): 1,
#  ('bem,', 'parvati'): 1,
#  ('bem,', 'dean thomas'): 1,
#  ('professor lupin', 'seamus'): 1,
#  ('professor lupin', 'hermione'): 1,
#  ('professor lupin', 'ron'): 1,
#  ('professor lupin', 'students'): 1,
#  ('professor lupin', 'draco'): 1,
#  ('professor lupin', 'neville'): 1,
#  ('professor lupin', 'parvati'): 1,
#  ('professor lupin', 'dean thomas'): 1,
#  ('seamus', 'students'): 1,
#  ('seamus', 'draco'): 2,
#  ('seamus', 'parvati'): 1,
#  ('students', 'neville'): 1,
#  ('students', 'parvati'): 1,
#  ('students', 'dean thomas'): 1,
#  ('draco', 'parvati'): 1,
#  ('draco', 'dean thomas'): 1,
#  ('professor lupin', 'harry'): 3,
#  ('ron', 'fat lady'): 1,
#  ('ron', 'montage - securing the castle - night 58'): 1,
#  ('percy', 'ginny'): 1,
#  ('percy', 'dumbledore'): 1,
#  ('percy', 'filch'): 1,
#  ('percy', 'fat lady'): 1,
#  ('percy', 'montage - securing the castle - night 58'): 1,
#  ('ginny', 'dumbledore'): 2,
#  ('ginny', 'filch'): 1,
#  ('ginny', 'fat lady'): 1,
#  ('ginny', 'montage - securing the castle - night 58'): 1,
#  ('dumbledore', 'filch'): 1,
#  ('dumbledore', 'fat lady'): 1,
#  ('dumbledore', 'montage - securing the castle - night 58'): 1,
#  ('filch', 'fat lady'): 1,
#  ('filch', 'montage - securing the castle - night 58'): 1,
#  ('fat lady', 'montage - securing the castle - night 58'): 1,
#  ('snape', 'sir cadogan'): 1,
#  ('dumbledore', 'sir cadogan'): 2,
#  ('sir cadogan', 'seamus'): 1,
#  ('sir cadogan', 'dean thomas'): 1,
#  ('sir cadogan', 'neville'): 2,
#  ('sir cadogan', 'ron'): 1,
#  ("intercut harry's pov", 'in the stands'): 1,
#  ("intercut harry's pov", 'harry'): 1,
#  ("intercut harry's pov", 'hermione'): 1,
#  ("intercut harry's pov", 'ron'): 1,
#  ("intercut harry's pov", 'fred'): 1,
#  ("intercut harry's pov", 'george'): 1,
#  ('in the stands', 'harry'): 1,
#  ('in the stands', 'hermione'): 1,
#  ('in the stands', 'ron'): 1,
#  ('in the stands', 'fred'): 1,
#  ('in the stands', 'george'): 1,
#  ('fred', 'professor lupin'): 1,
#  ('harry', 'fred/george'): 3,
#  ('fred', 'fred/george'): 3,
#  ('george', 'fred/george'): 3,
#  ('harry', 'crates. huge rolling bins. a wood staircase. a'): 1,
#  ('crates. huge rolling bins. a wood staircase. a', 'woman'): 1,
#  ('ron', 'cornelius fudge'): 1,
#  ('ron', 'madam rosmerta'): 1,
#  ('hermione', 'cornelius fudge'): 2,
#  ('hermione', 'madam rosmerta'): 1,
#  ('cornelius fudge', 'harry'): 1,
#  ('cornelius fudge', 'madam rosmerta'): 1,
#  ('harry', 'madam rosmerta'): 1,
#  ('madam rosmerta', 'cornelius fudge'): 1,
#  ('ron', 'sir cadogan'): 1,
#  ('hermione', 'sir cadogan'): 1,
#  ('dumbledore', 'neville'): 1,
#  ('sir cadogan', 'harry'): 1,
#  ("insert - marauder's map", 'back to scene'): 1,
#  ("insert - marauder's map", 'himself'): 1,
#  ("insert - marauder's map", 'voice'): 1,
#  ("insert - marauder's map", 'harry'): 1,
#  ("insert - marauder's map", 'snape'): 1,
#  ("insert - marauder's map", 'professor lupin'): 1,
#  ("insert - marauder's map", 'closeup - crystal ball'): 1,
#  ('back to scene', 'himself'): 1,
#  ('back to scene', 'voice'): 1,
#  ('back to scene', 'snape'): 1,
#  ('back to scene', 'professor lupin'): 1,
#  ('back to scene', 'closeup - crystal ball'): 1,
#  ('himself', 'voice'): 1,
#  ('himself', 'harry'): 1,
#  ('himself', 'snape'): 1,
#  ('himself', 'professor lupin'): 1,
#  ('himself', 'closeup - crystal ball'): 1,
#  ('voice', 'snape'): 2,
#  ('voice', 'professor lupin'): 1,
#  ('voice', 'closeup - crystal ball'): 1,
#  ('harry', 'closeup - crystal ball'): 1,
#  ('snape', 'professor lupin'): 1,
#  ('snape', 'closeup - crystal ball'): 1,
#  ('professor lupin', 'closeup - crystal ball'): 1,
#  ('harry', 'professor trelawney'): 1,
#  ('afternoon', 'draco'): 1,
#  ('afternoon', 'hermione'): 3,
#  ('afternoon', 'ron'): 2,
#  ('hagrid', 'hermione/ron'): 1,
#  ('harry', 'hermione/ron'): 2,
#  ('hermione/ron', 'ron'): 1,
#  ('hermione', "harry and hermione's pov - the branches overhead"): 1,
#  ('ron', "harry and hermione's pov - the branches overhead"): 1,
#  ('ron', 'back to scene'): 1,
#  ('harry', "harry and hermione's pov - the branches overhead"): 1,
#  ('harry', 'back to scene'): 1,
#  ("harry and hermione's pov - the branches overhead", 'back to scene'): 1,
#  ('hermione', 'sirius black'): 2,
#  ('hermione', 'pettigrew'): 1,
#  ('harry', 'sirius black'): 2,
#  ('harry', 'pettigrew'): 1,
#  ('ron', 'sirius black'): 1,
#  ('ron', 'pettigrew'): 1,
#  ('sirius black', 'harry /hermione/ron'): 1,
#  ('sirius black', 'professor lupin'): 1,
#  ('sirius black', 'snape'): 1,
#  ('sirius black', 'pettigrew'): 1,
#  ('harry /hermione/ron', 'professor lupin'): 1,
#  ('harry /hermione/ron', 'snape'): 1,
#  ('harry /hermione/ron', 'pettigrew'): 1,
#  ('professor lupin', 'snape'): 1,
#  ('professor lupin', 'pettigrew'): 1,
#  ('snape', 'pettigrew'): 1,
#  ('afternoon', 'harry'): 2,
#  ('cornelius fudge', 'dumbledore'): 1,
#  ('cornelius fudge', 'hagrid'): 1,
#  ('hermione', 'moving pov'): 1,
#  ('harry', 'moving pov'): 1,
#  ('sirius black', 'harry'): 1,
#  ('sirius black', 'hermione'): 1,
#  ('seamus', 'fred/george'): 1,
#  ('seamus', 'hagrid'): 1,
#  ('neville', 'fred/george'): 1,
#  ('neville', 'hagrid'): 1,
#  ('fred/george', 'harry'): 1,
#  ('fred/george', 'hagrid'): 2,
#  ('wormtail', 'voldemort'): 1,
#  ('wormtail', 'unknown man'): 1,
#  ('voldemort', 'unknown man'): 1,
#  ('hermione', 'arthur'): 1,
#  ('hermione', 'amos'): 1,
#  ('hermione', 'cedric'): 2,
#  ('harry', 'arthur'): 2,
#  ('harry', 'amos'): 2,
#  ('harry', 'cedric'): 4,
#  ('ron', 'arthur'): 3,
#  ('ron', 'amos'): 1,
#  ('ron', 'cedric'): 1,
#  ('arthur', 'amos'): 1,
#  ('arthur', 'cedric'): 1,
#  ('arthur', 'fred'): 3,
#  ('arthur', 'george'): 3,
#  ('amos', 'cedric'): 1,
#  ('amos', 'fred'): 1,
#  ('amos', 'george'): 1,
#  ('cedric', 'fred'): 1,
#  ('cedric', 'george'): 1,
#  ('arthur', 'twins'): 1,
#  ('arthur', 'harry'): 2,
#  ('twins', 'harry'): 1,
#  ('ron', 'lucius'): 2,
#  ('ron', 'weasleys'): 1,
#  ('lucius', 'draco'): 1,
#  ('lucius', 'arthur'): 1,
#  ('lucius', 'george'): 1,
#  ('lucius', 'fred'): 1,
#  ('lucius', 'weasleys'): 1,
#  ('draco', 'arthur'): 1,
#  ('draco', 'fred'): 1,
#  ('draco', 'weasleys'): 1,
#  ('arthur', 'weasleys'): 1,
#  ('george', 'weasleys'): 1,
#  ('fred', 'weasleys'): 1,
#  ('announcer', 'ron'): 1,
#  ('announcer', 'ginny'): 1,
#  ('announcer', 'twins'): 1,
#  ('announcer', 'boys'): 1,
#  ('announcer', 'fred'): 1,
#  ('ron', 'twins'): 2,
#  ('ron', 'boys'): 1,
#  ('ginny', 'twins'): 1,
#  ('ginny', 'boys'): 1,
#  ('twins', 'boys'): 1,
#  ('twins', 'fred'): 1,
#  ('boys', 'fred'): 1,
#  ('ron', 'barty'): 2,
#  ('harry', 'barty'): 4,
#  ('arthur', 'barty'): 1,
#  ('arthur', 'hermione'): 1,
#  ('barty', 'hermione'): 2,
#  ('lady offscreen', 'lady'): 1,
#  ('lady offscreen', 'ron'): 1,
#  ('lady offscreen', 'harry'): 1,
#  ('lady offscreen', 'cho'): 1,
#  ('lady offscreen', 'hermione'): 1,
#  ('lady', 'ron'): 1,
#  ...}

# %%
dict(sorted(con_str.items(), key=lambda x: x[1]['score'], reverse=True)[:2])
# Out:
# scene_id  movie_nr
# 1         8                            [harry, hermione, bellatrix]
# 2         8                                     [bellatrix, lucius]
# 3         8           [bellatrix, scabior, draco, lucius, snatcher]
# 4         8                                      [ron, luna, harry]
# 5         8                                   [bellatrix, hermione]
#                                           ...
# 93        8                                            [trelawne y]
# 94        8                                                 [harry]
# 95        8                                  [ron, hermione, harry]
# 96        8                                           [older harry]
# 97        8                    [older hermione, albus, older harry]
# Name: character, Length: 97, dtype: object

# %%
df_store
# Out:
# scene_id  movie_nr
# 1         1           [dumbledore, mcgonagall, hagrid, petunia, dudl...
# 2         1                                           [petunia, vernon]
# 3         1                [dudley, vernon, harry, snake, man, petunia]
# 4         1                                    [petunia, harry, vernon]
# 5         1                                     [vernon, dudley, harry]
#                                             ...
# 65        1                                [harry, quirrell, voldemort]
# 66        1                                         [dumbledore, harry]
# 67        1                                      [harry, ron, hermione]
# 68        1           [dumbledore, students, draco, harry, hermione,...
# 69        1                                   [hagrid, hermione, harry]
# Name: character, Length: 66, dtype: object

# %%
# con_scene_desc = dict()
# for movie in df.movie_nr:
movie = 1
# df_names = df['character'].unique()
df_store = df[df.movie_nr == movie].groupby(['scene_desc','movie_nr'])['character'].unique()

con_scene = dict()
for scene in df_store:
    for idx in range(len(scene)-1):
        for idx2 in range(idx+1,len(scene)):
            if (scene[idx],scene[idx2]) in con_scene:
                con_scene[(scene[idx],scene[idx2])] += 1
            else:
                con_scene[(scene[idx],scene[idx2])] = 1
con_scene
# Out:
# {('hermione', 'ron'): 20,
#  ('quirrell', 'hagrid'): 1,
#  ('quirrell', 'harry'): 4,
#  ('hagrid', 'harry'): 10,
#  ('ron', 'mcgonagall'): 3,
#  ('harry', 'ron'): 23,
#  ('man', 'snape'): 1,
#  ('man', 'ron'): 1,
#  ('man', 'hagrid'): 1,
#  ('snape', 'ron'): 2,
#  ('snape', 'hagrid'): 1,
#  ('ron', 'hagrid'): 4,
#  ('woman', 'ron'): 2,
#  ('woman', 'harry'): 1,
#  ('ron', 'harry'): 25,
#  ('harry', 'hermione'): 14,
#  ('dumbledore', 'harry'): 3,
#  ('woman', 'percy'): 1,
#  ('woman', 'girl'): 1,
#  ('percy', 'girl'): 2,
#  ('percy', 'ron'): 4,
#  ('girl', 'ron'): 2,
#  ('flitwick', 'harry'): 1,
#  ('flitwick', 'ron'): 1,
#  ('ron', 'hermione'): 15,
#  ('hermione', 'harry'): 20,
#  ('mcgonagall', 'quirrell'): 2,
#  ('mcgonagall', 'nick'): 1,
#  ('mcgonagall', 'ron'): 3,
#  ('mcgonagall', 'harry'): 4,
#  ('quirrell', 'nick'): 1,
#  ('quirrell', 'ron'): 2,
#  ('nick', 'ron'): 2,
#  ('nick', 'harry'): 1,
#  ('draco', 'harry'): 5,
#  ('snake', 'harry'): 1,
#  ('dudley', 'harry'): 4,
#  ('dumbledore', 'mcgonagall'): 1,
#  ('dumbledore', 'hermione'): 2,
#  ('dumbledore', 'ron'): 1,
#  ('mcgonagall', 'hermione'): 1,
#  ('filch', 'hermione'): 2,
#  ('filch', 'ron'): 2,
#  ('filch', 'harry'): 2,
#  ('filch', 'all'): 1,
#  ('hermione', 'all'): 1,
#  ('ron', 'all'): 1,
#  ('harry', 'all'): 1,
#  ('harry', 'lee'): 1,
#  ('harry', 'gryffindors'): 1,
#  ('lee', 'gryffindors'): 1,
#  ('fred', 'ron'): 1,
#  ('fred', 'george'): 1,
#  ('fred', 'harry'): 1,
#  ('fred', 'hermione'): 1,
#  ('ron', 'george'): 1,
#  ('george', 'harry'): 1,
#  ('george', 'hermione'): 1,
#  ('hagrid', 'all'): 1,
#  ('hagrid', 'dudley'): 2,
#  ('all', 'dudley'): 1,
#  ('harry', 'vernon'): 3,
#  ('harry', 'petunia'): 1,
#  ('harry', 'hagrid'): 15,
#  ('vernon', 'petunia'): 3,
#  ('vernon', 'hagrid'): 2,
#  ('petunia', 'hagrid'): 1,
#  ('mcgonagall', 'dumbledore'): 4,
#  ('dudley', 'all'): 1,
#  ('dudley', 'hagrid'): 1,
#  ('all', 'harry'): 1,
#  ('all', 'hagrid'): 2,
#  ('harry', 'dudley'): 2,
#  ('hagrid', 'ron'): 4,
#  ('hermione', 'hagrid'): 5,
#  ('boy', 'harry'): 2,
#  ('boy', 'hagrid'): 1,
#  ('firenze', 'harry'): 1,
#  ('harry', 'draco'): 3,
#  ('harry', 'man'): 1,
#  ('lee', 'hooch'): 2,
#  ('lee', 'all'): 1,
#  ('lee', 'draco'): 1,
#  ('lee', 'hagrid'): 1,
#  ('lee', 'hermione'): 1,
#  ('lee', 'mcgonagall'): 1,
#  ('hooch', 'all'): 1,
#  ('hooch', 'draco'): 2,
#  ('hooch', 'hagrid'): 1,
#  ('hooch', 'hermione'): 2,
#  ('hooch', 'mcgonagall'): 1,
#  ('all', 'draco'): 1,
#  ('all', 'hermione'): 1,
#  ('all', 'mcgonagall'): 1,
#  ('draco', 'hagrid'): 1,
#  ('draco', 'hermione'): 3,
#  ('draco', 'mcgonagall'): 2,
#  ('hagrid', 'hermione'): 4,
#  ('hagrid', 'mcgonagall'): 1,
#  ('hermione', 'mcgonagall'): 3,
#  ('harry', 'quirrell'): 1,
#  ('harry', 'oliver'): 2,
#  ('hagrid', 'oliver'): 1,
#  ('harry', 'frog'): 1,
#  ('ron', 'frog'): 1,
#  ('harry', 'trainmaster'): 1,
#  ('quirrell', 'snape'): 1,
#  ('voldemort', 'harry'): 2,
#  ('harry', 'hooch'): 2,
#  ('draco', 'hooch'): 1,
#  ('draco', 'ron'): 2,
#  ('hooch', 'ron'): 1,
#  ('filch', 'hagrid'): 1,
#  ('filch', 'draco'): 1,
#  ('hagrid', 'draco'): 1,
#  ('hermione', 'draco'): 1,
#  ('vernon', 'dudley'): 3,
#  ('petunia', 'vernon'): 2,
#  ('petunia', 'harry'): 3,
#  ('vernon', 'harry'): 2,
#  ('neville', 'hooch'): 3,
#  ('neville', 'girl'): 3,
#  ('neville', 'draco'): 1,
#  ('neville', 'harry'): 4,
#  ('hooch', 'girl'): 2,
#  ('hooch', 'harry'): 2,
#  ('girl', 'draco'): 1,
#  ('girl', 'harry'): 2,
#  ('harry', 'neville'): 2,
#  ('snape', 'harry'): 3,
#  ('hermione', 'flitwick'): 1,
#  ('hagrid', 'lee'): 1,
#  ('harry', 'mcgonagall'): 1,
#  ('george', 'fred'): 1,
#  ('neville', 'mcgonagall'): 1,
#  ('neville', 'students'): 1,
#  ('neville', 'boy'): 1,
#  ('hooch', 'students'): 1,
#  ('hooch', 'boy'): 1,
#  ('girl', 'students'): 1,
#  ('girl', 'boy'): 2,
#  ('students', 'boy'): 1,
#  ('students', 'harry'): 2,
#  ('seamus', 'hermione'): 1,
#  ('seamus', 'neville'): 1,
#  ('seamus', 'harry'): 2,
#  ('seamus', 'hooch'): 1,
#  ('seamus', 'class'): 1,
#  ('hermione', 'neville'): 2,
#  ('hermione', 'hooch'): 1,
#  ('hermione', 'class'): 1,
#  ('neville', 'class'): 1,
#  ('harry', 'class'): 1,
#  ('hooch', 'class'): 1,
#  ('harry', 'percy'): 1,
#  ('girl', 'percy'): 1,
#  ('girl', 'nick'): 1,
#  ('girl', 'hermione'): 1,
#  ('percy', 'nick'): 1,
#  ('percy', 'hermione'): 1,
#  ('nick', 'hermione'): 1,
#  ('percy', 'boy'): 1,
#  ('dudley', 'vernon'): 1,
#  ('dudley', 'petunia'): 2,
#  ('quirrell', 'voldemort'): 1,
#  ('hermione', 'quirrell'): 1,
#  ('ron', 'nick'): 1,
#  ('seamus', 'ron'): 1,
#  ('snape', 'hermione'): 2,
#  ('percy', 'harry'): 2,
#  ('hermione', 'firenze'): 1,
#  ('hagrid', 'firenze'): 1,
#  ('hagrid', 'petunia'): 1,
#  ('flint', 'crowd'): 1,
#  ('percy', 'neville'): 1,
#  ('neville', 'ron'): 1,
#  ('ron', 'girl'): 1,
#  ('harry', 'girl'): 1,
#  ('ron', 'snape'): 1,
#  ('mcgonagall', 'snape'): 1,
#  ('harry', 'snape'): 1,
#  ('goblin', 'hagrid'): 1,
#  ('dumbledore', 'girl'): 1,
#  ('dumbledore', 'boy'): 1,
#  ('hagrid', 'dumbledore'): 1,
#  ('ollivander', 'harry'): 1,
#  ('students', 'draco'): 1,
#  ('students', 'dumbledore'): 1,
#  ('students', 'hermione'): 1,
#  ('draco', 'dumbledore'): 1,
#  ('griphook', 'harry'): 1,
#  ('griphook', 'hagrid'): 1,
#  ('hagrid', 'tom'): 1,
#  ('harry', 'voldemort'): 1,
#  ('oiiver', 'harry'): 1,
#  ('oiiver', 'oliver'): 1,
#  ('snape', 'neville'): 1,
#  ('ron', 'neville'): 1,
#  ('harry', 'flitwick'): 1,
#  ('flitwick', 'draco'): 1}

# %%
df[df.sentence != ''].character.unique()
# Out:
# array(['dumbledore', 'mcgonagall', 'hagrid', 'petunia', 'dudley',
#        'vernon', 'harry', 'snake', 'man', 'all', 'tom', 'witch',
#        'quirrell', 'boy', 'goblin', 'griphook', 'ollivander',
#        'trainmaster', 'george', 'fred', 'ron', 'woman', 'frog',
#        'hermione', 'neville', 'draco', 'seamus', 'percy', 'nick', 'girl',
#        'snape', 'hooch', 'class', 'students', 'filch', 'oliver',
#        'flitwick', 'oiiver', 'lee', 'gryffindors', 'flint', 'crowd',
#        'firenze', 'voldemort', 'uncle vernon', 'aunt petunia', 'dobby',
#        'mr. mason', 'same scene - later', "closeup - harry's trunk 13b",
#        "insert - fred's foot 13c", 'mrs. weasley', 'ginny', 'mr. weasley',
#        'harry /ron/fred/george', 'mr. borgin', 'lucius malfoy',
#        'aged witch', 'short man', 'gilderoy lockhart', 'guard',
#        'harry /ron', 'albus dumbledore', 'professor sprout',
#        'penelope clearwater', 'nearly headless nick', 'colin',
#        'dean thomas', "at work and it's entirely your",
#        "of line we'll bring you straight", 'dissolve', 'wood', 'voice',
#        'the chamber of secrets has been opened', 'madam pomfrey',
#        "harry's moving pov", 'back to scene',
#        'young girl comes racing out of the wall. face to face',
#        'moaning myrtle', 'justin finch-fletchley',
#        'justin-finch-fletchley', 'ernie', 'hannah', 'sorting hat',
#        'closeup - the potion', 'tom riddle', 'young hagrid', 'riddle',
#        'harry /ron/hermione', 'fudge', 'aragog', 'lucious malfoy',
#        "harry's room -— same time - middle of the night 2",
#        'harry potter', 'aunt marge', 'stan shunpike', 'disheveled wizard',
#        'shrunken head', 'cornelius fudge', 'young witch', 'hermione/ron',
#        'closeup - a dog-eared clipping', 'arthur weasley',
#        'harry /hermione/ron', 'professor lupin', 'professor trelawney',
#        'teacup - detail - later', 'parvati', 'lavender', 'pansy',
#        'lavendar', 'bem', 'bem,', 'fat lady',
#        'montage - securing the castle - night 58', 'sir cadogan',
#        "intercut harry's pov", 'in the stands', "harry's pov",
#        'fred/george', 'crates. huge rolling bins. a wood staircase. a',
#        'action — day', 'madam rosmerta', 'shrunken head #1', 'day',
#        "insert - marauder's map", 'himself', 'closeup - crystal ball',
#        'harry, ron and hermione', 'afternoon',
#        "harry and hermione's pov - the branches overhead", 'sirius black',
#        'pettigrew', 'moving pov', 'old man', 'wormtail', 'unknown man',
#        'arthur', 'amos', 'cedric', 'twins', 'lucius', 'weasleys',
#        'announcer', 'boys', 'barty', 'lady offscreen', 'lady', 'cho',
#        'student', 'igor', 'madame maxime', 'mad-eye', 'pupil', 'rita',
#        'sir', 'viktor', 'nigel', 'patils', 'padma', 'voldermort',
#        'myrtle', 'voice singing', 'friend', 'merperson', 'fleur',
#        'barty jr', "harry's dad", "harry's mother", 'alastor',
#        'gang thug #1', 'mrs. figg', 'gang member #3',
#        'i said, do you understand? !', '(v.o.)', 'lily potter', 'moody',
#        'lupin', 'tonks', 'kingsley', 'mrs. black', 'sirius', 'mrs black',
#        'mrs weasley', 'hermione!', '(more )', 'mr weasley', 'phonebooth.',
#        'female volce', 'female voice', 'perkins', 'susan bones', 'figg',
#        'umbridge', 'fred, george, and ginny', '(more)', 'kreacher',
#        'luna lovegood', 'luna', 'dumbledore (cont’d)', 'dean',
#        'mcgonogall', 'angelina', 'gryffindor common room.',
#        'int, gryffindor common room - day', '(v.o. )', 'malfoy', 'so...',
#        'trelawney', 'trelawne y',
#        'macmillan, justin finch-fletchely, hannah abbott, anthony',
#        'zachartias', 'justin finch-fletchly', 'michael corner',
#        'lee jordan', 'd.a.?', 'slytherins', 'madam hooch', '(v.o0.)',
#        'rom', 'zachartas', 'peril.”', 'everard', 'dilys', 'phineas',
#        'lockhart', 'healer', 'mrs. longbottom', 'sirus', 'no!', 'grawp',
#        'bane', 'james', 'lily evens', 'professor tofty', 'hawlish',
#        'cowards !', 'professor marchbanks', 'golden orbs.',
#        'fred and george', 'itn. umbridge’s office - day', 'crucio!',
#        'magorian', 'centaur', 'centaur #2', 'grawp want haggar!',
#        'fountain.', 'candles.', 'bellatrix', 'now!', 'run!',
#        'death eater', 'liar!', 'i’ll kill you!!', 'harry /voldemort',
#        'nearly-headless nick', 'narcissa', 'new angle —- moments later',
#        'waitress', 'armchatr', 'slughorn', 'ron/hermione/mrs. weasley',
#        'shopping bag —- day', 'fred / george', 'lavender brown',
#        'new angle —- shop front —- moments later',
#        'new angle —- another alley —- dusk',
#        'new angle - other alleys - dusk',
#        'new angle -—- borgin & burkes - back courtyard - dusk', 'blaise',
#        '... strange moving pov - half red/half blue', 'o.w.l. -',
#        'katie bell', 'montage begins',
#        'the light shifts one last time. the vial glimmers like',
#        'another angle', 'wool’ §s orphanage', 'mrs. cole',
#        'new angle -—- corridor outside tom riddle’s room', 'cormac',
#        'begin montage', 'skinny kid', 'leanne', 'marcus belby',
#        'close on the hourglass', 'closeup - quaffle', 'night',
#        'new angle —- behind large rectangular mass', 'eldred worple',
#        'waiter', 'walter', 'new angle —- party —- same time',
#        'wider angle', 'arthur’s pov - lupin’s hand', 'new angle',
#        'new angles', 'greyback', 'new angle —- seconds later',
#        'ginny /harry', 'new angle —- behind vanishing cabinet',
#        'hermione /ron', 'hagrid/slughorn',
#        'new angle (small island ) —- moments later',
#        'new angle - underwater', 'new angle - the surface',
#        'new angle —- underwater', 'new angle —- harry', '+ + + + hf',
#        'the end', 'mrs. granger', 'mr. granger', 'television', 'radio',
#        'narcissa malfoy', 'yaxley', 'squat man', 'thicknesse', 'charity',
#        'shacklebolt', 'bill', 'mundungus', 'voldemont', 'scrimgeour',
#        'xenophilius lovegood', 'elphias doge', 'muriel', 'patronus',
#        'waltress', 'death eater #2',
#        'young hogwarts students -- james potter, sirius black,',
#        'letter (lily)', 'reg cattermole/ron', 'mafalda hopkirk/hermione',
#        'albert runcorn/harry', 'skinny wizard', 'balding wizard',
#        'female', 'young wizard', 'percy weasley', 'red-haired witch',
#        'bespectacled wizard',
#        'head of the muggle-born registration commission', 'morning',
#        'wakinda', 'scared man', 'mary cattermole', 'muttering wizard',
#        'reg cattermole', 'gregorovitch', 'scabior',
#        'new angle —- graveyard', 'new angle —- tombstones',
#        'james potter lily potter', 'same time - night',
#        'bathilda bagshot', 'action - night', 'riddle-harry',
#        'riddle-hermione', 'riddle-—harry', 'harry / hermione',
#        'dozens die as death eaters attack, harry in hiding, where',
#        'harry/ron/hermione', 'hermione/ron harry', 'ron hermione',
#        'grindelwald', 'snatcher', 'fenrir greyback', 'brown',
#        'closeup - linked hands - moments later', 'warlock', 'aged goblin',
#        'tall goblin', 'bogrod',
#        'into camera, eyes dark, the surface of his skin trembling',
#        'death eater #1', 'aberforth', '+ + + hf', 'alecto carrow',
#        'pansy parkinson', 'madam sprout', 'teachers',
#        'kingsley shacklebolt', 'the grey lady',
#        'their pov — an empty corridor', 'goyle', 'new angle - high',
#        'new angle —- ground level', 'if we die for them, i’ll kill you,',
#        'their pov', 'petunia evans', 'young snape', 'lily evans',
#        'oliver wood', 'young girl', 'james potter',
#        'new angle - harry and dumbledore', 'new angle —- neville - night',
#        'close on the peak of a hat', 'harry’s pov of neville',
#        'new angle - nagini - moving', 'new angle - lower stair',
#        'blurry pov', 'new angle —- harry and voldemort', 'older harry',
#        'older hermione', 'albus'], dtype=object)

# %%
df[['sentence','movie_nr']][df.character == 'RON/HERMIONE/MRS. WEASLEY']

# %%
# Skoða sentiment á setningum komið

# SKoða sentiment á scenes komið 

# SKoða sentiment sérstakra karaktera  komið

# Skoða tengst karaktera m.v. scene eða röðun (fyrir og eftir), ef character kemur fyrir og eftir þá tala þeir sama t.d.

# Create wordclous out of sentences with the outlines of the characters

# Create a quiz where you get a sentence from character and guess who it was.

# %%
import random
import nltk, re, pprint
from nltk import word_tokenize
from nltk.corpus import stopwords
import pandas as pd
import matplotlib.pyplot as plt
import copy
import numpy as np
import seaborn as sns
import itertools
import pickle
import math
from wordcloud import WordCloud, ImageColorGenerator
sns.set()

# %%
# Lets combine all sentences of characters into a dictionary
stopwords = nltk.corpus.stopwords.words('english')
wnl = nltk.WordNetLemmatizer()
char_sentences = dict()
for character in df.character.unique():
    text = df.sentence[df.character == character].str.cat(sep=' ')
    tokens = nltk.word_tokenize(text)
    words = [w.lower() for w in tokens if w.isalpha()]
    lem_words = [wnl.lemmatize(w) for w in words if w not in stopwords]
    #     harry_freq = nltk.FreqDist(lem_words)
    char_sentences[character] = lem_words

# %%
df[(df.movie_nr == 1) & (df.character == 'harry')]['sentence']
# Out:
# 21                                    Yes, Aunt Petunia.
# 24                                    Yes, Uncle Vernon.
# 36                                          He's asleep!
# 38     Sorry about him. He doesn't understand what it...
# 39     Can you...hear me? {The snake nods} It's just....
#                              ...
# 798                                     {Pats} Good job.
# 808               One minute. {He walks over to Hagrid.}
# 810    Thanks, Hagrid. {Shakes Hagrid's hand, then hu...
# 812    But Hagrid, we're not allowed to do magic away...
# 815                      I'm not going home. Not really.
# Name: sentence, Length: 227, dtype: object

# %%
char_sentences
# Out:
# {'dumbledore': ['known',
#   'would',
#   'professor',
#   'mcgonagall',
#   'afraid',
#   'professor',
#   'good',
#   'bad',
#   'hagrid',
#   'bringing',
#   'ah',
#   'professor',
#   'would',
#   'trust',
#   'hagrid',
#   'life',
#   'problem',
#   'trust',
#   'hagrid',
#   'family',
#   'exactly',
#   'better',
#   'growing',
#   'away',
#   'ready',
#   'hagrid',
#   'really',
#   'good',
#   'luck',
#   'harry',
#   'potter',
#   'start',
#   'term',
#   'notice',
#   'wish',
#   'announce',
#   'first',
#   'year',
#   'please',
#   'note',
#   'dark',
#   'forest',
#   'strictly',
#   'forbidden',
#   'student',
#   'also',
#   'caretaker',
#   'filch',
#   'signal',
#   'ragged',
#   'old',
#   'man',
#   'cat',
#   'red',
#   'eye',
#   'asked',
#   'remind',
#   'floor',
#   'corridor',
#   'right',
#   'hand',
#   'side',
#   'bound',
#   'everyone',
#   'wish',
#   'die',
#   'painful',
#   'death',
#   'thank',
#   'let',
#   'feast',
#   'begin',
#   'sillllleeennnnceeeee',
#   'everyone',
#   'stop',
#   'everyone',
#   'please',
#   'panic',
#   'prefect',
#   'lead',
#   'house',
#   'back',
#   'dormitory',
#   'teacher',
#   'follow',
#   'dungeon',
#   'back',
#   'harry',
#   'harry',
#   'turn',
#   'around',
#   'stand',
#   'see',
#   'like',
#   'many',
#   'discovered',
#   'delight',
#   'mirror',
#   'erised',
#   'trust',
#   'realize',
#   'let',
#   'give',
#   'clue',
#   'happiest',
#   'man',
#   'earth',
#   'would',
#   'look',
#   'mirror',
#   'see',
#   'exactly',
#   'yes',
#   'show',
#   'u',
#   'nothing',
#   'le',
#   'deepest',
#   'desperate',
#   'desire',
#   'heart',
#   'never',
#   'known',
#   'family',
#   'see',
#   'standing',
#   'beside',
#   'remember',
#   'harry',
#   'mirror',
#   'give',
#   'u',
#   'neither',
#   'knowledge',
#   'truth',
#   'men',
#   'wasted',
#   'away',
#   'front',
#   'even',
#   'gone',
#   'mad',
#   'tomorrow',
#   'moved',
#   'new',
#   'home',
#   'must',
#   'ask',
#   'go',
#   'looking',
#   'dwell',
#   'dream',
#   'harry',
#   'forget',
#   'live',
#   'harry',
#   'look',
#   'back',
#   'mirror',
#   'good',
#   'afternoon',
#   'harry',
#   'ah',
#   'token',
#   'admirer',
#   'happened',
#   'dungeon',
#   'professor',
#   'quirrell',
#   'complete',
#   'secret',
#   'naturally',
#   'whole',
#   'school',
#   'know',
#   'smile',
#   'ah',
#   'see',
#   'friend',
#   'ronald',
#   'saved',
#   'trouble',
#   'opening',
#   'chocolate',
#   'frog',
#   'fine',
#   'fine',
#   'relax',
#   'dear',
#   'boy',
#   'stone',
#   'destroyed',
#   'friend',
#   'nicholas',
#   'little',
#   'chat',
#   'agreed',
#   'best',
#   'around',
#   'sits',
#   'bed',
#   'enough',
#   'elixir',
#   'set',
#   'affair',
#   'order',
#   'yes',
#   'die',
#   'ah',
#   'see',
#   'person',
#   'wanted',
#   'find',
#   'stone',
#   'find',
#   'use',
#   'would',
#   'able',
#   'get',
#   'one',
#   'brilliant',
#   'idea',
#   'thats',
#   'saying',
#   'something',
#   'smile',
#   'ah',
#   'afraid',
#   'way',
#   'return',
#   'harry',
#   'know',
#   'professor',
#   'quirrell',
#   'could',
#   'bear',
#   'touch',
#   'harry',
#   'shake',
#   'head',
#   'mother',
#   'sacrificed',
#   'kind',
#   'act',
#   'leaf',
#   'mark',
#   'harry',
#   'touch',
#   'scar',
#   'kind',
#   'mark',
#   'seen',
#   'life',
#   'skin',
#   'love',
#   'harry',
#   'love',
#   'pat',
#   'harry',
#   'head',
#   'stand',
#   'ah',
#   'bertie',
#   'bott',
#   'every',
#   'flavour',
#   'bean',
#   'unfortunate',
#   'youth',
#   'come',
#   'across',
#   'vomit',
#   'flavoured',
#   'one',
#   'since',
#   'lost',
#   'liking',
#   'think',
#   'could',
#   'safe',
#   'nice',
#   'toffee',
#   'take',
#   'brown',
#   'bean',
#   'eats',
#   'mm',
#   'ala',
#   'earwax',
#   'another',
#   'year',
#   'gone',
#   'understand',
#   'house',
#   'cup',
#   'need',
#   'awarding',
#   'point',
#   'stand',
#   'thus',
#   'fourth',
#   'place',
#   'gryffindor',
#   'point',
#   'clapping',
#   'harry',
#   'hermione',
#   'hide',
#   'head',
#   'third',
#   'place',
#   'hufflepuff',
#   'point',
#   'clapping',
#   'second',
#   'place',
#   'ravenclaw',
#   'point',
#   'clapping',
#   'first',
#   'place',
#   'point',
#   'slytherin',
#   'house',
#   'yes',
#   'yes',
#   'well',
#   'done',
#   'slytherin',
#   'well',
#   'done',
#   'slytherin',
#   'however',
#   'recent',
#   'event',
#   'must',
#   'taken',
#   'account',
#   'last',
#   'minute',
#   'point',
#   'award',
#   'gryffindor',
#   'student',
#   'look',
#   'miss',
#   'hermione',
#   'granger',
#   'use',
#   'cool',
#   'intellect',
#   'others',
#   'great',
#   'peril',
#   'point',
#   'applause',
#   'second',
#   'ronald',
#   'weasley',
#   'best',
#   'played',
#   'game',
#   'chess',
#   'ron',
#   'look',
#   'harry',
#   'mouth',
#   'harry',
#   'nod',
#   'mouth',
#   'hogwarts',
#   'seen',
#   'many',
#   'year',
#   'point',
#   'applause',
#   'third',
#   'harry',
#   'potter',
#   'pure',
#   'nerve',
#   'outstanding',
#   'courage',
#   'award',
#   'gryffindor',
#   'house',
#   'point',
#   'immense',
#   'cheering',
#   'finally',
#   'take',
#   'great',
#   'deal',
#   'bravery',
#   'stand',
#   'enemy',
#   'great',
#   'deal',
#   'stand',
#   'friend',
#   'award',
#   'point',
#   'neville',
#   'longbottom',
#   'assuming',
#   'calculation',
#   'correct',
#   'believe',
#   'change',
#   'direction',
#   'order',
#   'clap',
#   'green',
#   'banner',
#   'change',
#   'gryffindor',
#   'red',
#   'yellow',
#   'gryffindor',
#   'win',
#   'house',
#   'cup',
#   'splendid',
#   'suggest',
#   'return',
#   'feast',
#   'custard',
#   'tart',
#   'want',
#   'sample',
#   'argus',
#   'everyone',
#   'proceed',
#   'dormitory',
#   'immediately',
#   'harry',
#   'ron',
#   'hermione',
#   'everyone',
#   'except',
#   'three',
#   'dead',
#   'argus',
#   'petrified',
#   'petrified',
#   'say',
#   'innocent',
#   'proven',
#   'guilty',
#   'able',
#   'cure',
#   'argus',
#   'understand',
#   'madam',
#   'sprout',
#   'healthy',
#   'growth',
#   'mandrake',
#   'matured',
#   'potion',
#   'made',
#   'another',
#   'attack',
#   'mean',
#   'student',
#   'great',
#   'danger',
#   'minerva',
#   'creevey',
#   'fortunate',
#   'holding',
#   'camera',
#   'would',
#   'surely',
#   'dead',
#   'tell',
#   'truth',
#   'tell',
#   'hogwarts',
#   'longer',
#   'safe',
#   'tell',
#   'feared',
#   'chamber',
#   'secret',
#   'indeed',
#   'open',
#   'time',
#   'looking',
#   'dreadful',
#   'day',
#   'pity',
#   'see',
#   'burning',
#   'day',
#   'really',
#   'handsome',
#   'time',
#   'fascinating',
#   'creature',
#   'phoenix',
#   'carry',
#   'immensely',
#   'heavy',
#   'load',
#   'tear',
#   'healing',
#   'power',
#   'make',
#   'highly',
#   'faithful',
#   'pet',
#   'hagrid',
#   'hagrid',
#   'hagrid',
#   'think',
#   'harry',
#   'attacked',
#   'anyone',
#   'harry',
#   'must',
#   'ask',
#   'anything',
#   'like',
#   'tell',
#   'anything',
#   'wise',
#   'wandering',
#   'around',
#   'late',
#   'tom',
#   'afraid',
#   'tom',
#   'headmaster',
#   'dippet',
#   'may',
#   'choice',
#   'afraid',
#   'something',
#   'wish',
#   'tell',
#   'tom',
#   'well',
#   'hurry',
#   'along',
#   'good',
#   'evening',
#   'hagrid',
#   'want',
#   'understood',
#   'cornelius',
#   'hagrid',
#   'full',
#   'confidence',
#   'exactly',
#   'want',
#   'lucius',
#   'calm',
#   'hagrid',
#   'ingenious',
#   'simply',
#   'ingenious',
#   'looking',
#   'wiser',
#   'wizard',
#   'hoodwinked',
#   'lord',
#   'voldemort',
#   'miss',
#   'weasley',
#   'think',
#   'endured',
#   'enough',
#   'would',
#   'suggest',
#   'bit',
#   'bed',
#   'rest',
#   'however',
#   'perhaps',
#   'large',
#   'mug',
#   'hot',
#   'chocolate',
#   'always',
#   'find',
#   'cheer',
#   'minerva',
#   'show',
#   'arthur',
#   'molly',
#   'hospital',
#   'wing',
#   'two',
#   'realize',
#   'course',
#   'last',
#   'hour',
#   'broken',
#   'perhaps',
#   'dozen',
#   'school',
#   'rule',
#   'sufficient',
#   'evidence',
#   'expel',
#   'therefore',
#   'seems',
#   'fitting',
#   'weasley',
#   'would',
#   'owl',
#   'deliver',
#   'release',
#   'paper',
#   'azkaban',
#   'need',
#   'gamekeeper',
#   'back',
#   'first',
#   'harry',
#   'want',
#   'thank',
#   'must',
#   'shown',
#   'real',
#   'loyalty',
#   'chamber',
#   'nothing',
#   'could',
#   'called',
#   'fawkes',
#   'secondly',
#   'sense',
#   'troubled',
#   'something',
#   'right',
#   'speak',
#   'parseltongue',
#   'harry',
#   'lord',
#   'voldemort',
#   'speak',
#   'parseltongue',
#   'unless',
#   'much',
#   'mistaken',
#   'transformed',
#   'power',
#   'night',
#   'gave',
#   'scar',
#   'intentionally',
#   'yes',
#   'true',
#   'harry',
#   'posse',
#   'many',
#   'gualities',
#   'voldemort',
#   'prize',
#   'resourcefulness',
#   'determination',
#   'certain',
#   'disregard',
#   'rule',
#   'yet',
#   'sorting',
#   'hat',
#   'placed',
#   'gryffindor',
#   'exactly',
#   'make',
#   'different',
#   'voldemort',
#   'ability',
#   'show',
#   'truly',
#   'harry',
#   'choice',
#   'true',
#   'gryffindor',
#   'could',
#   'pulled',
#   'hat',
#   'yes',
#   'governor',
#   'heard',
#   'arthur',
#   'weasley',
#   'daughter',
#   'taken',
#   'chamber',
#   'saw',
#   'fit',
#   'summon',
#   'back',
#   'oh',
#   'yes',
#   'voldemort',
#   'time',
#   'chose',
#   'act',
#   'someone',
#   'else',
#   'mean',
#   'fortunately',
#   'young',
#   'potter',
#   'discovered',
#   'begin',
#   'feast',
#   'let',
#   'give',
#   'round',
#   'applause',
#   'professor',
#   'sprout',
#   'madame',
#   'pomfrey',
#   'whose',
#   'mandrake',
#   'juice',
#   'successfully',
#   'administered',
#   'petrified',
#   'also',
#   'wake',
#   'recent',
#   'event',
#   'school',
#   'treat',
#   'exam',
#   'cancelled',
#   'welcome',
#   'welcome',
#   'another',
#   'year',
#   'hogwarts',
#   'thing',
#   'mm',
#   'yes',
#   'first',
#   'pleased',
#   'welcome',
#   'professor',
#   'lupin',
#   'kindly',
#   'consented',
#   'fill',
#   'post',
#   'defense',
#   'dark',
#   'art',
#   'good',
#   'luck',
#   'professor',
#   'may',
#   'know',
#   'professor',
#   'kettleburn',
#   'care',
#   'magical',
#   'creature',
#   'teacher',
#   'many',
#   'year',
#   'decided',
#   'retire',
#   'order',
#   'spend',
#   'time',
#   'remaining',
#   'limb',
#   'fortunately',
#   'delighted',
#   'announce',
#   'place',
#   'filled',
#   'none',
#   'rubeus',
#   'hagrid',
#   'turning',
#   'grave',
#   'finally',
#   'disquieting',
#   'note',
#   'hogwarts',
#   'request',
#   'ministry',
#   'magic',
#   'notice',
#   'play',
#   'host',
#   'dementors',
#   'azkaban',
#   'dementors',
#   'stationed',
#   'entrance',
#   'ground',
#   'strict',
#   'order',
#   'enter',
#   'castle',
#   'occasion',
#   'see',
#   'go',
#   'daily',
#   'activity',
#   'circumstance',
#   'approach',
#   'nature',
#   'dementor',
#   'forgiving',
#   'filch',
#   'round',
#   'ghost',
#   'tell',
#   'search',
#   'every',
#   'painting',
#   'castle',
#   'fat',
#   'lady',
#   'dear',
#   'lady',
#   'secure',
#   'castle',
#   'filch',
#   'rest',
#   'great',
#   'hall',
#   'nodding',
#   'really',
#   'expect',
#   'linger',
#   'believe',
#   'single',
#   'professor',
#   'inside',
#   'castle',
#   'would',
#   'helped',
#   'sirius',
#   'black',
#   'enter',
#   'severus',
#   'feel',
#   'quite',
#   'confident',
#   'castle',
#   'safe',
#   'willing',
#   'let',
#   'student',
#   'return',
#   'house',
#   'tomorrow',
#   'let',
#   'sleep',
#   'astonishing',
#   'body',
#   'endure',
#   'mind',
#   'allows',
#   'rest',
#   'sir',
#   'cadogan',
#   'possible',
#   'let',
#   'mysterious',
#   'man',
#   'enter',
#   'gryffindor',
#   'tower',
#   'tonight',
#   'scabbers',
#   'miss',
#   'granger',
#   'sorry',
#   'say',
#   'word',
#   'three',
#   'wizard',
#   'convince',
#   'others',
#   'child',
#   'voice',
#   'however',
#   'honest',
#   'true',
#   'meaningless',
#   'forgotten',
#   'listen',
#   'ah',
#   'shooting',
#   'star',
#   'ever',
#   'one',
#   'make',
#   'wish',
#   'would',
#   'time',
#   'time',
#   'afraid',
#   'precisely',
#   'problem',
#   'mysterious',
#   'thing',
#   'time',
#   'powerful',
#   'meddled',
#   'dangerous',
#   'sirius',
#   'black',
#   'topmost',
#   'cell',
#   'dark',
#   'tower',
#   'way',
#   'doubt',
#   'find',
#   'retracing',
#   'step',
#   'wise',
#   'place',
#   'begin',
#   'good',
#   'luck',
#   'excuse',
#   'minister',
#   'believe',
#   'must',
#   'sign',
#   'well',
#   'professor',
#   'dippet',
#   'blackberry',
#   'planted',
#   'headmaster',
#   'hint',
#   'amusement',
#   'extraordinary',
#   'quite',
#   'sure',
#   'minister',
#   'suggesting',
#   'anything',
#   'hagrid',
#   'could',
#   'u',
#   'along',
#   'search',
#   'sky',
#   'must',
#   'minister',
#   'meantime',
#   'would',
#   'say',
#   'cup',
#   'tea',
#   'hagrid',
#   'large',
#   'brandy',
#   'way',
#   'doubt',
#   'always',
#   'find',
#   'retracing',
#   'step',
#   'wise',
#   'place',
#   'begin',
#   'good',
#   'luck',
#   'well',
#   'settled',
#   'sorted',
#   'like',
#   'make',
#   'announcement',
#   'castle',
#   'home',
#   'year',
#   'home',
#   'special',
#   'guest',
#   'well',
#   'see',
#   'hogwarts',
#   'choosen',
#   'hogwarts',
#   'choosen',
#   'host',
#   'legendary',
#   'event',
#   'tournament',
#   'know',
#   'tournament',
#   'brings',
#   ...],
#  'mcgonagall': ['good',
#   'evening',
#   'professor',
#   'dumbledore',
#   'rumour',
#   'true',
#   'albus',
#   'boy',
#   'think',
#   'wise',
#   'trust',
#   'hagrid',
#   'something',
#   'important',
#   'albus',
#   'really',
#   'think',
#   'safe',
#   'leaving',
#   'people',
#   'watching',
#   'day',
#   'worst',
#   'sort',
#   'muggles',
#   'imaginable',
#   'really',
#   'boy',
#   'famous',
#   'wont',
#   'child',
#   'world',
#   'know',
#   'name',
#   'welcome',
#   'hogwarts',
#   'moment',
#   'pas',
#   'door',
#   'join',
#   'classmate',
#   'take',
#   'seat',
#   'must',
#   'sorted',
#   'house',
#   'gryffindor',
#   'ravenclaw',
#   'hufflepuff',
#   'slytherin',
#   'house',
#   'like',
#   'family',
#   'triumph',
#   'earn',
#   'house',
#   'point',
#   'rule',
#   'breaking',
#   'lose',
#   'point',
#   'end',
#   'year',
#   'house',
#   'point',
#   'awarded',
#   'house',
#   'cup',
#   'sorting',
#   'ceremony',
#   'begin',
#   'momentarily',
#   'leaf',
#   'ready',
#   'right',
#   'wait',
#   'along',
#   'please',
#   'begin',
#   'professor',
#   'dumbldedore',
#   'would',
#   'like',
#   'say',
#   'word',
#   'call',
#   'name',
#   'come',
#   'forth',
#   'shall',
#   'place',
#   'sorting',
#   'hat',
#   'head',
#   'sorted',
#   'house',
#   'hermione',
#   'granger',
#   'draco',
#   'malfoy',
#   'susan',
#   'bone',
#   'ronald',
#   'weasley',
#   'harry',
#   'potter',
#   'ding',
#   'cup',
#   'attention',
#   'please',
#   'thank',
#   'assessment',
#   'weasley',
#   'maybe',
#   'transfigure',
#   'potter',
#   'pocketwatch',
#   'maybe',
#   'one',
#   'would',
#   'time',
#   'perhaps',
#   'map',
#   'trust',
#   'need',
#   'one',
#   'find',
#   'seat',
#   'appears',
#   'quickly',
#   'harry',
#   'potter',
#   'follow',
#   'harry',
#   'sullenly',
#   'follows',
#   'draco',
#   'goon',
#   'laugh',
#   'excuse',
#   'excuse',
#   'professor',
#   'quirrell',
#   'could',
#   'borrow',
#   'wood',
#   'moment',
#   'potter',
#   'oliver',
#   'wood',
#   'wood',
#   'found',
#   'seeker',
#   'oh',
#   'oh',
#   'goodness',
#   'granger',
#   'may',
#   'extremely',
#   'foolish',
#   'thing',
#   'harry',
#   'look',
#   'snape',
#   'leg',
#   'large',
#   'cut',
#   'snape',
#   'notice',
#   'cover',
#   'glaring',
#   'harry',
#   'would',
#   'expected',
#   'rational',
#   'behaviour',
#   'part',
#   'granger',
#   'point',
#   'taken',
#   'gryffindor',
#   'serious',
#   'lack',
#   'judgment',
#   'two',
#   'gentleman',
#   'hope',
#   'realize',
#   'fortunate',
#   'many',
#   'student',
#   'could',
#   'take',
#   'full',
#   'grown',
#   'mountain',
#   'troll',
#   'live',
#   'tell',
#   'tale',
#   'point',
#   'awarded',
#   'sheer',
#   'dumb',
#   'luck',
#   'snape',
#   'mcgonagall',
#   'exit',
#   'giggle',
#   'happily',
#   'good',
#   'evening',
#   'nothing',
#   'repeat',
#   'nothing',
#   'give',
#   'student',
#   'right',
#   'walk',
#   'school',
#   'night',
#   'therefore',
#   'punishment',
#   'action',
#   'point',
#   'taken',
#   'ensure',
#   'happen',
#   'four',
#   'receive',
#   'detention',
#   'heard',
#   'correctly',
#   'malfoy',
#   'see',
#   'honorable',
#   'intention',
#   'bed',
#   'hour',
#   'serve',
#   'detention',
#   'classmate',
#   'afraid',
#   'professor',
#   'dumbledore',
#   'received',
#   'urgent',
#   'owl',
#   'ministry',
#   'magic',
#   'left',
#   'immediately',
#   'london',
#   'shocked',
#   'know',
#   'know',
#   'three',
#   'found',
#   'stone',
#   'assure',
#   'perfectly',
#   'would',
#   'go',
#   'back',
#   'dormitory',
#   'quietly',
#   'leave',
#   'ca',
#   'go',
#   'albus',
#   'first',
#   'dark',
#   'mark',
#   'put',
#   'end',
#   'let',
#   'potter',
#   'compete',
#   'well',
#   'devil',
#   'barty',
#   'rule',
#   'since',
#   'accomodate',
#   'nothing',
#   'offer',
#   'bait',
#   'potter',
#   'boy',
#   'piece',
#   'meat',
#   'professor',
#   'moody',
#   'student',
#   'never',
#   'use',
#   'transfigration',
#   'punishment',
#   'surely',
#   'dumbledore',
#   'told',
#   'well',
#   'well',
#   'remember',
#   'yule',
#   'ball',
#   'tradition',
#   'tournament',
#   'since',
#   'inception',
#   'christmas',
#   'eve',
#   'night',
#   'guest',
#   'gather',
#   'great',
#   'hall',
#   'well',
#   'mannered',
#   'frivolity',
#   'representitives',
#   'host',
#   'school',
#   'expect',
#   'every',
#   'one',
#   'put',
#   'best',
#   'foot',
#   'forward',
#   'mean',
#   'literally',
#   'yule',
#   'ball',
#   'first',
#   'foremost',
#   'dance',
#   'silence',
#   'house',
#   'godrick',
#   'griffindore',
#   'commanded',
#   'respect',
#   'wizard',
#   'world',
#   'nearly',
#   'ten',
#   'century',
#   'course',
#   'single',
#   'evening',
#   'besmirching',
#   'name',
#   'behaving',
#   'like',
#   'babbling',
#   'bumbling',
#   'band',
#   'baboon',
#   'continued',
#   'dance',
#   'let',
#   'body',
#   'breathe',
#   'inside',
#   'every',
#   'girl',
#   'secret',
#   'swan',
#   'slumber',
#   'longing',
#   'burst',
#   'forth',
#   'take',
#   'flight',
#   'inside',
#   'every',
#   'boy',
#   'lordly',
#   'lion',
#   'prepared',
#   'prance',
#   'mr',
#   'weasly',
#   'join',
#   'place',
#   'right',
#   'hand',
#   'waist',
#   'waist',
#   'bend',
#   'arm',
#   'mr',
#   'filch',
#   'one',
#   'two',
#   'three',
#   'one',
#   'two',
#   'three',
#   'one',
#   'two',
#   'three',
#   'everybody',
#   'come',
#   'together',
#   'boy',
#   'foot',
#   'potter',
#   'miss',
#   'patil',
#   'ready',
#   'dance',
#   'traditional',
#   'three',
#   'champion',
#   'case',
#   'four',
#   'first',
#   'dance',
#   'surely',
#   'told',
#   'oh',
#   'well',
#   'know',
#   'oh',
#   'mr',
#   'weasly',
#   'may',
#   'proceed',
#   'great',
#   'hall',
#   'miss',
#   'patil',
#   'potter',
#   'earth',
#   'going',
#   'time',
#   'night',
#   'yes',
#   'think',
#   'might',
#   'right',
#   'potter',
#   'look',
#   'harry',
#   'coming',
#   'well',
#   'give',
#   'run',
#   'bear',
#   'mind',
#   'potter',
#   'channel',
#   'communication',
#   'hogwarts',
#   'watched',
#   'good',
#   'bed',
#   'shouting',
#   'earth',
#   'two',
#   'think',
#   'office',
#   'year',
#   'school',
#   'never',
#   'seen',
#   'disgusting',
#   'display',
#   'course',
#   'wanted',
#   'provoke',
#   'lost',
#   'express',
#   'word',
#   'disappointment',
#   'feel',
#   'right',
#   'dolores',
#   'thought',
#   'wrong',
#   'kindly',
#   'remove',
#   'office',
#   'care',
#   'malfoy',
#   'said',
#   'performance',
#   'shameful',
#   'fifty',
#   'point',
#   'gryffindor',
#   'giving',
#   'week',
#   'worth',
#   'detention',
#   'hand',
#   'tied',
#   'potter',
#   'potter',
#   'wake',
#   'potter',
#   'wake',
#   'please',
#   'dreamed',
#   'potter',
#   'sure',
#   'happened',
#   'potter',
#   'going',
#   'see',
#   'headmaster',
#   'potter',
#   'pause',
#   'weasley',
#   'best',
#   'come',
#   'well',
#   'potter',
#   'kind',
#   'nightmare',
#   'usually',
#   'mean',
#   'dolores',
#   'umbridge',
#   'grab',
#   'marietta',
#   'cloak',
#   'shake',
#   'roughly',
#   'yes',
#   'fine',
#   'pause',
#   'oh',
#   'go',
#   'albus',
#   'please',
#   'sit',
#   'potter',
#   'talk',
#   'career',
#   'thought',
#   'potter',
#   'begin',
#   'aim',
#   'course',
#   'next',
#   'two',
#   'year',
#   'prepare',
#   'career',
#   'auror',
#   'interesting',
#   'potter',
#   'need',
#   'top',
#   'grade',
#   'challenging',
#   'career',
#   'path',
#   'potter',
#   'need',
#   'concentrate',
#   'defense',
#   'dark',
#   'art',
#   'potion',
#   'transfiguration',
#   'charm',
#   'adequately',
#   'prepare',
#   'general',
#   'auror',
#   'requirement',
#   'may',
#   'offer',
#   'cough',
#   'drop',
#   'professor',
#   'umbridge',
#   'indeed',
#   'serious',
#   'ambition',
#   'potter',
#   'would',
#   'recommend',
#   'concentrating',
#   'bringing',
#   'potion',
#   'charm',
#   'grade',
#   'daresay',
#   'got',
#   'enough',
#   'time',
#   'apply',
#   'lord',
#   'know',
#   'consistently',
#   'done',
#   'well',
#   'defense',
#   'dark',
#   'art',
#   'professor',
#   'yes',
#   'indeed',
#   'apparently',
#   'misunderstand',
#   'meant',
#   'potter',
#   'done',
#   'well',
#   'every',
#   'defense',
#   'dark',
#   'art',
#   'class',
#   'taught',
#   'competent',
#   'teacher',
#   'assuming',
#   'passed',
#   'necessary',
#   'class',
#   'ministry',
#   'put',
#   'number',
#   'character',
#   'aptitude',
#   'test',
#   'stand',
#   'pressure',
#   'perseverance',
#   'dedication',
#   'thing',
#   'nature',
#   'assist',
#   'becoming',
#   'auror',
#   'last',
#   'thing',
#   'potter',
#   'coach',
#   'concludes',
#   'meeting',
#   'potter',
#   'welcome',
#   'potter',
#   'hurry',
#   'late',
#   'occlumency',
#   'today',
#   'begin',
#   'exam',
#   'number',
#   'ministry',
#   'instructor',
#   'give',
#   'exam',
#   'take',
#   'place',
#   'next',
#   'two',
#   'week',
#   'exam',
#   'split',
#   'two',
#   'part',
#   'theory',
#   'practical',
#   'application',
#   'shouting',
#   'rage',
#   'dare',
#   'dare',
#   'stop',
#   'immediately',
#   'enough'],
#  'hagrid': ['professor',
#   'dumbledore',
#   'sir',
#   'professor',
#   'mcgonagall',
#   'sir',
#   'little',
#   'tyke',
#   'fell',
#   'asleep',
#   'flying',
#   'bristol',
#   'heh',
#   'try',
#   'wake',
#   'go',
#   'sorry',
#   'put',
#   'door',
#   'back',
#   'dry',
#   'dursley',
#   'great',
#   'prune',
#   'gun',
#   'fire',
#   'see',
#   'dudley',
#   'mind',
#   'seen',
#   'since',
#   'baby',
#   'harry',
#   'bit',
#   'along',
#   'would',
#   'expected',
#   'particularly',
#   'middle',
#   'oh',
#   'well',
#   'course',
#   'got',
#   'something',
#   'ya',
#   'might',
#   'sat',
#   'point',
#   'imagine',
#   'taste',
#   'fine',
#   'ahh',
#   'baked',
#   'hand',
#   'harry',
#   'cake',
#   'word',
#   'heh',
#   'every',
#   'day',
#   'young',
#   'man',
#   'turn',
#   'eleven',
#   'rubeus',
#   'hagrid',
#   'keeper',
#   'key',
#   'ground',
#   'hogwarts',
#   'course',
#   'know',
#   'hogwarts',
#   'blimey',
#   'harry',
#   'ever',
#   'wonder',
#   'mum',
#   'dad',
#   'learned',
#   'wizard',
#   'harry',
#   'well',
#   'harry',
#   'ever',
#   'make',
#   'anything',
#   'happen',
#   'anything',
#   'could',
#   'explain',
#   'angry',
#   'scared',
#   'harry',
#   'softens',
#   'expression',
#   'ah',
#   'car',
#   'crash',
#   'car',
#   'crash',
#   'kill',
#   'james',
#   'lily',
#   'potter',
#   'outrage',
#   'scandal',
#   'oh',
#   'suppose',
#   'great',
#   'muggle',
#   'like',
#   'going',
#   'stop',
#   'non',
#   'magic',
#   'folk',
#   'boy',
#   'name',
#   'ever',
#   'since',
#   'born',
#   'going',
#   'finest',
#   'school',
#   'witchcraft',
#   'wizardry',
#   'world',
#   'greatest',
#   'headmaster',
#   'hogwarts',
#   'ever',
#   'seen',
#   'albus',
#   'dumbledore',
#   'whip',
#   'umbrella',
#   'point',
#   'vernon',
#   'never',
#   'insult',
#   'albus',
#   'dumbledore',
#   'front',
#   'oh',
#   'um',
#   'appreciate',
#   'tell',
#   'anyone',
#   'hogwarts',
#   'strictly',
#   'speaking',
#   'allowed',
#   'magic',
#   'check',
#   'clock',
#   'ooh',
#   'bit',
#   'behind',
#   'schedule',
#   'best',
#   'unless',
#   'rather',
#   'stay',
#   'course',
#   'hmm',
#   'leaf',
#   'know',
#   'go',
#   'thanks',
#   'tom',
#   'official',
#   'hogwarts',
#   'business',
#   'today',
#   'helping',
#   'young',
#   'harry',
#   'buy',
#   'school',
#   'supply',
#   'hello',
#   'professor',
#   'see',
#   'harry',
#   'professor',
#   'quirrell',
#   'defense',
#   'dark',
#   'art',
#   'teacher',
#   'hogwarts',
#   'yes',
#   'well',
#   'must',
#   'going',
#   'lot',
#   'buy',
#   'heh',
#   'see',
#   'harry',
#   'famous',
#   'exactly',
#   'sure',
#   'right',
#   'person',
#   'tell',
#   'harry',
#   'tap',
#   'brick',
#   'wall',
#   'clockwise',
#   'umbrella',
#   'block',
#   'shift',
#   'open',
#   'reveal',
#   'hidden',
#   'busy',
#   'street',
#   'get',
#   'quill',
#   'ink',
#   'bit',
#   'bob',
#   'wizardry',
#   'well',
#   'money',
#   'harry',
#   'gringotts',
#   'wizard',
#   'bank',
#   'place',
#   'safer',
#   'perhaps',
#   'hogwarts',
#   'goblin',
#   'harry',
#   'clever',
#   'come',
#   'goblin',
#   'friendly',
#   'beast',
#   'best',
#   'stick',
#   'close',
#   'harry',
#   'stick',
#   'hagrid',
#   'clear',
#   'throat',
#   'approach',
#   'counter',
#   'goblin',
#   'harry',
#   'potter',
#   'wish',
#   'make',
#   'withdrawal',
#   'oh',
#   'wait',
#   'minute',
#   'got',
#   'somewhere',
#   'hah',
#   'little',
#   'devil',
#   'oh',
#   'something',
#   'else',
#   'well',
#   'professor',
#   'dumbledore',
#   'gave',
#   'vault',
#   'hand',
#   'goblin',
#   'letter',
#   'wrapped',
#   'string',
#   'think',
#   'mum',
#   'dad',
#   'would',
#   'leave',
#   'nothing',
#   'didja',
#   'ca',
#   'tell',
#   'harry',
#   'hogwarts',
#   'business',
#   'secret',
#   'best',
#   'mention',
#   'anyone',
#   'harry',
#   'wand',
#   'well',
#   'want',
#   'ollivanders',
#   'place',
#   'better',
#   'run',
#   'along',
#   'wait',
#   'got',
#   'one',
#   'thing',
#   'got',
#   'wo',
#   'long',
#   'harry',
#   'harry',
#   'happy',
#   'birthday',
#   'snowy',
#   'owl',
#   'cage',
#   'hoot',
#   'right',
#   'harry',
#   'seem',
#   'quiet',
#   'sigh',
#   'push',
#   'bowl',
#   'away',
#   'first',
#   'understand',
#   'harry',
#   'important',
#   'wizard',
#   'good',
#   'go',
#   'bad',
#   'year',
#   'ago',
#   'one',
#   'wizard',
#   'went',
#   'bad',
#   'go',
#   'name',
#   'name',
#   'ca',
#   'spell',
#   'right',
#   'name',
#   'voldemort',
#   'shh',
#   'dark',
#   'time',
#   'harry',
#   'dark',
#   'time',
#   'voldemort',
#   'started',
#   'gather',
#   'follower',
#   'brought',
#   'dark',
#   'side',
#   'anyone',
#   'stood',
#   'ended',
#   'dead',
#   'parent',
#   'fought',
#   'nobody',
#   'lived',
#   'decided',
#   'kill',
#   'harrys',
#   'mother',
#   'lily',
#   'scream',
#   'killed',
#   'voldemorts',
#   'wand',
#   'nobody',
#   'one',
#   'except',
#   'baby',
#   'harry',
#   'yes',
#   'ai',
#   'ordinary',
#   'cut',
#   'forehead',
#   'harry',
#   'mark',
#   'like',
#   'come',
#   'touched',
#   'curse',
#   'evil',
#   'curse',
#   'say',
#   'died',
#   'codswallop',
#   'opinion',
#   'nope',
#   'reckon',
#   'still',
#   'tired',
#   'go',
#   'one',
#   'thing',
#   'absolutely',
#   'certain',
#   'something',
#   'stumped',
#   'night',
#   'famous',
#   'harry',
#   'everbody',
#   'know',
#   'name',
#   'boy',
#   'lived',
#   'looking',
#   'look',
#   'watch',
#   'blimey',
#   'time',
#   'sorry',
#   'harry',
#   'gon',
#   'na',
#   'leave',
#   'dumbledore',
#   'wanting',
#   'well',
#   'wanting',
#   'see',
#   'uh',
#   'train',
#   'leaf',
#   'minute',
#   'ticket',
#   'stick',
#   'harry',
#   'important',
#   'stick',
#   'ticket',
#   'right',
#   'first',
#   'year',
#   'way',
#   'please',
#   'come',
#   'shy',
#   'come',
#   'hurry',
#   'hello',
#   'harry',
#   'right',
#   'way',
#   'boat',
#   'come',
#   'follow',
#   'well',
#   'done',
#   'going',
#   'harry',
#   'broomstick',
#   'go',
#   'go',
#   'go',
#   'look',
#   'like',
#   'gon',
#   'na',
#   'sick',
#   'yes',
#   'nonsense',
#   'would',
#   'snape',
#   'put',
#   'curse',
#   'harry',
#   'broom',
#   'told',
#   'fluffy',
#   'well',
#   'course',
#   'got',
#   'name',
#   'mine',
#   'bought',
#   'irish',
#   'feller',
#   'met',
#   'pub',
#   'last',
#   'year',
#   'lent',
#   'dumbledore',
#   'guard',
#   'said',
#   'ask',
#   'question',
#   'top',
#   'secret',
#   'codswallop',
#   'professor',
#   'snape',
#   'hogwarts',
#   'teacher',
#   'sigh',
#   'listen',
#   'three',
#   'meddlin',
#   'thing',
#   'ought',
#   'meddled',
#   'dangerous',
#   'dog',
#   'guarding',
#   'strictly',
#   'professor',
#   'dumbledore',
#   'nicholas',
#   'flamel',
#   'said',
#   'said',
#   'said',
#   'exit',
#   'clad',
#   'oven',
#   'mitt',
#   'apron',
#   'oh',
#   'hello',
#   'sorry',
#   'wish',
#   'rude',
#   'fit',
#   'state',
#   'entertain',
#   'today',
#   'close',
#   'door',
#   'oh',
#   'snape',
#   'blimey',
#   'harry',
#   'still',
#   'snape',
#   'one',
#   'teacher',
#   'protecting',
#   'stone',
#   'steal',
#   'heard',
#   'right',
#   'come',
#   'bit',
#   'preoccupied',
#   'today',
#   'right',
#   'waste',
#   'bloody',
#   'time',
#   'ask',
#   'um',
#   'stranger',
#   'met',
#   'pub',
#   'seemed',
#   'quite',
#   'glad',
#   'rid',
#   'matter',
#   'fact',
#   'beautiful',
#   'oh',
#   'bless',
#   'look',
#   'know',
#   'mummy',
#   'hehe',
#   'hallo',
#   'norbert',
#   'dragon',
#   'squeak',
#   'look',
#   'hagrid',
#   'yeah',
#   'well',
#   'got',
#   'name',
#   'norbert',
#   'raise',
#   'finger',
#   'back',
#   'forth',
#   'across',
#   'norberts',
#   'chin',
#   'dededede',
#   'ohh',
#   'oooh',
#   'ooh',
#   'ooh',
#   'well',
#   'trained',
#   'bit',
#   'course',
#   'norbert',
#   'hiccup',
#   'hagrid',
#   'see',
#   'someone',
#   'looking',
#   'window',
#   'person',
#   'scamper',
#   'away',
#   'oh',
#   'dear',
#   'sniff',
#   'sigh',
#   'norbert',
#   'gone',
#   'dumbledore',
#   'sent',
#   'romania',
#   'live',
#   'colony',
#   'yeah',
#   'like',
#   'romania',
#   'filch',
#   'roll',
#   'eye',
#   'dragon',
#   'mean',
#   'baby',
#   'right',
#   'let',
#   'go',
#   'see',
#   'unicorn',
#   'blood',
#   'found',
#   'one',
#   'dead',
#   'week',
#   'ago',
#   'one',
#   'injured',
#   'bad',
#   'something',
#   'harry',
#   'suddenly',
#   'see',
#   'large',
#   'cloaked',
#   'figure',
#   'walking',
#   'tree',
#   'look',
#   'hagrid',
#   'job',
#   'find',
#   'poor',
#   'beast',
#   'ron',
#   'hermione',
#   'come',
#   'harry',
#   'go',
#   'malfoy',
#   'draco',
#   'grimace',
#   'harry',
#   'nod',
#   'fine',
#   'know',
#   'bloody',
#   'coward',
#   'fang',
#   'whine',
#   'hello',
#   'firenze',
#   'see',
#   'met',
#   'young',
#   'potter',
#   'right',
#   'harry',
#   'harry',
#   'nod',
#   'know',
#   'never',
#   'saw',
#   'face',
#   'kept',
#   'hood',
#   'well',
#   'wanted',
#   'know',
#   'sort',
#   'creature',
#   'looked',
#   'told',
#   'said',
#   'fluffy',
#   'dragon',
#   'gon',
#   'na',
#   'problem',
#   'well',
#   'course',
#   'interested',
#   'fluffy',
#   'often',
#   'come',
#   'across',
#   'three',
#   'headed',
#   'dog',
#   'even',
#   'trade',
#   'told',
#   'said',
#   'trick',
#   'beast',
#   'know',
#   'calm',
#   'take',
#   'fluffy',
#   'example',
#   'play',
#   'bit',
#   'music',
#   'fall',
#   'straight',
#   'sleep',
#   'told',
#   'three',
#   'take',
#   'going',
#   'wait',
#   'yes',
#   'grin',
#   'come',
#   'hurry',
#   'late',
#   'train',
#   'leaving',
#   'go',
#   'go',
#   'come',
#   'hurry',
#   'thought',
#   'leaving',
#   'without',
#   'saying',
#   'didja',
#   'hagrid',
#   'take',
#   'red',
#   'album',
#   'coat',
#   'pocket',
#   'hand',
#   'harry',
#   'oh',
#   'go',
#   'harry',
#   'let',
#   'go',
#   'oh',
#   'listen',
#   'harry',
#   'dolt',
#   'cousin',
#   'dudley',
#   'give',
#   'grief',
#   'could',
#   'always',
#   'um',
#   'threaten',
#   'nice',
#   'pair',
#   'ear',
#   'go',
#   'tail',
#   'cousin',
#   'eh',
#   'chuckle',
#   'go',
#   'harry',
#   'think',
#   'yer',
#   'doin',
#   'ere',
#   'yer',
#   'mess',
#   'skulkin',
#   'round',
#   'knockturn',
#   'alley',
#   'dodgy',
#   'place',
#   'harry',
#   'want',
#   'one',
#   'ter',
#   'see',
#   'yeh',
#   'people',
#   'thinkin',
#   'yer',
#   'ter',
#   'good',
#   'lookin',
#   'fer',
#   'flesh',
#   'eatin',
#   'slug',
#   'repellent',
#   'ruinin',
#   'school',
#   'cabbage',
#   'ignore',
#   'im',
#   'arthur',
#   'malfoy',
#   'worth',
#   'listenin',
#   'ter',
#   'rotten',
#   'ter',
#   'core',
#   'whole',
#   'family',
#   'got',
#   'jus',
#   'thing',
#   'set',
#   'im',
#   'chair',
#   'ron',
#   'sits',
#   'hagrid',
#   'pitch',
#   'bucket',
#   'knee',
#   'better',
#   'tryin',
#   'ter',
#   'curse',
#   'anyway',
#   'yeh',
#   'see',
#   'harry',
#   'wizard',
#   'like',
#   'malfoy',
#   'family',
#   'think',
#   'better',
#   'everyone',
#   'else',
#   'cause',
#   'people',
#   'call',
#   'pureblood',
#   'codswallop',
#   'ter',
#   'boot',
#   'dirty',
#   'blood',
#   'ardly',
#   'wizard',
#   'today',
#   'le',
#   'ad',
#   'married',
#   'muggles',
#   'died',
#   'long',
#   'ago',
#   'besides',
#   'invented',
#   'spell',
#   'hermione',
#   'ca',
#   'gallopin',
#   'gorgon',
#   'slytherin',
#   'flyin',
#   'like',
#   'got',
#   'dragon',
#   'fire',
#   'broom',
#   'stand',
#   'blimey',
#   'harry',
#   'got',
#   'rogue',
#   'bludger',
#   'look',
#   'fer',
#   'yerself',
#   'bin',
#   'tampered',
#   'brok',
#   'n',
#   'ave',
#   'bone',
#   'righ',
#   'harry',
#   'holding',
#   'harry',
#   'professor',
#   'talkin',
#   'ter',
#   'jus',
#   'kid',
#   'found',
#   'bin',
#   'im',
#   'swear',
#   'ter',
#   'front',
#   'ministry',
#   'magic',
#   'oh',
#   'right',
#   'wait',
#   'outside',
#   'mad',
#   'hairy',
#   'talkin',
#   'bou',
#   'would',
#   'yeh',
#   'slug',
#   'repellent',
#   'fer',
#   'mandrake',
#   'yeh',
#   'know',
#   'accordin',
#   'ter',
#   'professor',
#   'sprout',
#   'still',
#   'got',
#   'bit',
#   'growin',
#   'ter',
#   'acne',
#   'clear',
#   'able',
#   'chop',
#   'em',
#   'stew',
#   'get',
#   'people',
#   'hospital',
#   'til',
#   'three',
#   'best',
#   'watch',
#   'yerselves',
#   'righ',
#   'nothin',
#   'nothin',
#   'expectin',
#   'matter',
#   'sit',
#   'make',
#   'tea',
#   'oh',
#   'yea',
#   'heard',
#   'righ',
#   'never',
#   'know',
#   'never',
#   'professor',
#   'dumbledore',
#   'sir',
#   'take',
#   'azkaban',
#   'prison',
#   'doin',
#   'get',
#   'outta',
#   'house',
#   'many',
#   'yeh',
#   ...],
#  'petunia': ['get',
#   'knock',
#   'sigh',
#   'smack',
#   'door',
#   'closet',
#   'boy',
#   'bedroom',
#   'oh',
#   'come',
#   'birthday',
#   'boy',
#   'cook',
#   'breakfast',
#   'try',
#   'burn',
#   'anything',
#   'want',
#   'everything',
#   'perfect',
#   'dudley',
#   'special',
#   'day',
#   'oh',
#   'going',
#   'go',
#   'going',
#   'buy',
#   'two',
#   'new',
#   'present',
#   'pumpkin',
#   'lovely',
#   'day',
#   'zoo',
#   'really',
#   'looking',
#   'forward',
#   'see',
#   'ahh',
#   'darling',
#   'boy',
#   'get',
#   'right',
#   'right',
#   'lovely',
#   'day',
#   'office',
#   'dear',
#   'ooh',
#   'course',
#   'knew',
#   'could',
#   'perfect',
#   'sister',
#   'oh',
#   'mother',
#   'father',
#   'proud',
#   'day',
#   'got',
#   'letter',
#   'witch',
#   'family',
#   'wonderful',
#   'one',
#   'see',
#   'freak',
#   'met',
#   'potter',
#   'knew',
#   'strange',
#   'abnormal',
#   'please',
#   'went',
#   'got',
#   'blown',
#   'got',
#   'landed',
#   'tell',
#   'something',
#   'happened',
#   'duddikins',
#   'guard',
#   'wizard',
#   'prison',
#   'azkaban'],
#  'dudley': ['wake',
#   'cousin',
#   'going',
#   'zoo',
#   'many',
#   'last',
#   'year',
#   'last',
#   'year',
#   'got',
#   'care',
#   'big',
#   'make',
#   'move',
#   'move',
#   'boring',
#   'mummy',
#   'dad',
#   'come',
#   'wo',
#   'believe',
#   'snake',
#   'whoa',
#   'ahh',
#   'ahh',
#   'mum',
#   'mummy',
#   'mum',
#   'help',
#   'help',
#   'see',
#   'harrys',
#   'letter',
#   'run',
#   'grab',
#   'dad',
#   'look',
#   'harry',
#   'got',
#   'letter',
#   'ahh',
#   'make',
#   'stop',
#   'please',
#   'make',
#   'stop',
#   'jump',
#   'petunia',
#   'lap',
#   'please',
#   'tell',
#   'happening',
#   'daddy',
#   'gone',
#   'mad',
#   'hasnt',
#   'harry',
#   'whimper',
#   'ahh',
#   'want',
#   'friend',
#   'thought',
#   'got',
#   'second',
#   'bedroom',
#   'mum',
#   'afraid',
#   'turn',
#   'u',
#   'dung',
#   'beetle',
#   'put',
#   'back',
#   'cupboard',
#   'stair',
#   'waiting',
#   'open',
#   'door',
#   'cat',
#   'cat',
#   'know',
#   'day',
#   'today',
#   'birthday',
#   'nobody',
#   'care',
#   'oh',
#   'shut',
#   'ooo',
#   'tough',
#   'guy',
#   'tough',
#   'bed',
#   'heard',
#   'talking',
#   'sleep',
#   'last',
#   'night',
#   'cry',
#   'kill',
#   'cedric',
#   'kill',
#   'cedric',
#   'dad',
#   'help',
#   'heeelp',
#   'going',
#   'kill',
#   'terrified',
#   'point',
#   'thing',
#   'home',
#   'get',
#   'point',
#   'thing',
#   'happening',
#   'understand',
#   'coming',
#   'u',
#   'harry',
#   'think',
#   'waste',
#   'space'],
#  'vernon': ['happy',
#   'birthday',
#   'son',
#   'hurry',
#   'bring',
#   'coffee',
#   'boy',
#   'counted',
#   'yes',
#   'well',
#   'quite',
#   'bit',
#   'bigger',
#   'last',
#   'year',
#   'warning',
#   'boy',
#   'funny',
#   'business',
#   'wo',
#   'meal',
#   'week',
#   'get',
#   'move',
#   'happened',
#   'scoff',
#   'shove',
#   'harry',
#   'closet',
#   'thing',
#   'magic',
#   'ah',
#   'marge',
#   'ill',
#   'ate',
#   'funny',
#   'whelk',
#   'laugh',
#   'writing',
#   'mail',
#   'letterbox',
#   'shoo',
#   'go',
#   'fine',
#   'day',
#   'sunday',
#   'opinion',
#   'best',
#   'day',
#   'week',
#   'dudley',
#   'go',
#   'away',
#   'ahh',
#   'give',
#   'give',
#   'letter',
#   'ahh',
#   'going',
#   'away',
#   'far',
#   'away',
#   'ca',
#   'find',
#   'u',
#   'ahh',
#   'demand',
#   'leave',
#   'sir',
#   'breaking',
#   'entering',
#   'hell',
#   'going',
#   'swore',
#   'took',
#   'wed',
#   'put',
#   'end',
#   'rubbish',
#   'going',
#   'pay',
#   'crackpot',
#   'old',
#   'fool',
#   'teach',
#   'magic',
#   'trick',
#   'hell',
#   'hell',
#   'dementoid',
#   'want',
#   'answer',
#   'thing',
#   'know',
#   'fought',
#   'eh',
#   'dud',
#   'gave',
#   'em',
#   'ol',
#   'right',
#   'lot'],
#  'harry': ['yes',
#   'aunt',
#   'petunia',
#   'yes',
#   'uncle',
#   'vernon',
#   'asleep',
#   'sorry',
#   'understand',
#   'like',
#   'lying',
#   'day',
#   'day',
#   'people',
#   'press',
#   'ugly',
#   'face',
#   'hear',
#   'snake',
#   'nod',
#   'never',
#   'talked',
#   'snake',
#   'mean',
#   'talk',
#   'people',
#   'often',
#   'snake',
#   'shake',
#   'head',
#   'burma',
#   'nice',
#   'miss',
#   'family',
#   'snake',
#   'turn',
#   'head',
#   'direction',
#   'sign',
#   'say',
#   'bred',
#   'captivity',
#   'see',
#   'well',
#   'never',
#   'knew',
#   'parent',
#   'either',
#   'anytime',
#   'grin',
#   'giggle',
#   'ow',
#   'swear',
#   'know',
#   'one',
#   'minute',
#   'glass',
#   'gone',
#   'like',
#   'magic',
#   'hey',
#   'give',
#   'back',
#   'mine',
#   'hand',
#   'cookie',
#   'vernon',
#   'post',
#   'sunday',
#   'ah',
#   'right',
#   'harry',
#   'post',
#   'sunday',
#   'hah',
#   'blasted',
#   'letter',
#   'today',
#   'sir',
#   'harry',
#   'see',
#   'shadow',
#   'outside',
#   'window',
#   'outside',
#   'million',
#   'owl',
#   'perched',
#   'sir',
#   'one',
#   'blasted',
#   'miserable',
#   'get',
#   'ahh',
#   'letter',
#   'let',
#   'go',
#   'make',
#   'wish',
#   'harry',
#   'blow',
#   'thank',
#   'open',
#   'cake',
#   'read',
#   'happee',
#   'birdae',
#   'harry',
#   'put',
#   'cake',
#   'excuse',
#   'sorry',
#   'learnt',
#   'wizard',
#   'thumping',
#   'good',
#   'one',
#   'wager',
#   'train',
#   'little',
#   'made',
#   'mistake',
#   'ca',
#   'wizard',
#   'mean',
#   'harry',
#   'harry',
#   'dear',
#   'potter',
#   'pleased',
#   'inform',
#   'accepted',
#   'hogwarts',
#   'school',
#   'witchcraft',
#   'wizardry',
#   'knew',
#   'knew',
#   'along',
#   'never',
#   'told',
#   'blown',
#   'told',
#   'parent',
#   'died',
#   'car',
#   'crash',
#   'muggle',
#   'laugh',
#   'nod',
#   'okay',
#   'student',
#   'must',
#   'equipped',
#   'one',
#   'standard',
#   'size',
#   'two',
#   'pewter',
#   'cauldron',
#   'may',
#   'bring',
#   'desire',
#   'either',
#   'owl',
#   'cat',
#   'toad',
#   'find',
#   'london',
#   'oh',
#   'nice',
#   'meet',
#   'put',
#   'hand',
#   'quirrell',
#   'refuse',
#   'famous',
#   'hagrid',
#   'people',
#   'back',
#   'know',
#   'hagrid',
#   'pay',
#   'money',
#   'uh',
#   'hagrid',
#   'exactly',
#   'thing',
#   'hagrid',
#   'still',
#   'need',
#   'wand',
#   'softly',
#   'hello',
#   'hello',
#   'oh',
#   'wave',
#   'shelf',
#   'come',
#   'crashing',
#   'harry',
#   'jump',
#   'hurriedly',
#   'put',
#   'wand',
#   'back',
#   'counter',
#   'sorry',
#   'curious',
#   'owned',
#   'wand',
#   'wow',
#   'killed',
#   'parent',
#   'one',
#   'gave',
#   'know',
#   'hagrid',
#   'know',
#   'maybe',
#   'wrote',
#   'voldemort',
#   'voldemort',
#   'tried',
#   'kill',
#   'happened',
#   'platform',
#   'hagrid',
#   'must',
#   'mistake',
#   'say',
#   'platform',
#   'thing',
#   'harry',
#   'look',
#   'hagrid',
#   'vanished',
#   'excuse',
#   'excuse',
#   'excuse',
#   'sir',
#   'tell',
#   'might',
#   'find',
#   'platform',
#   'muggles',
#   'excuse',
#   'tell',
#   'harry',
#   'harry',
#   'potter',
#   'oh',
#   'yeah',
#   'lift',
#   'hair',
#   'pull',
#   'coin',
#   'take',
#   'lot',
#   'bertie',
#   'bott',
#   'every',
#   'flavour',
#   'bean',
#   'pick',
#   'blue',
#   'gold',
#   'package',
#   'real',
#   'chocolate',
#   'frog',
#   'hey',
#   'got',
#   'dumbledore',
#   'hey',
#   'gone',
#   'little',
#   'bit',
#   'yeah',
#   'hey',
#   'hagrid',
#   'think',
#   'tell',
#   'wrong',
#   'sort',
#   'thanks',
#   'ahh',
#   'put',
#   'hand',
#   'forehead',
#   'nothing',
#   'nothing',
#   'fine',
#   'whisper',
#   'slytherin',
#   'slytherin',
#   'wow',
#   'say',
#   'percy',
#   'teacher',
#   'talking',
#   'professor',
#   'quirrell',
#   'teach',
#   'think',
#   'fancy',
#   'got',
#   'lost',
#   'know',
#   'sir',
#   'know',
#   'sir',
#   'seamus',
#   'trying',
#   'glass',
#   'water',
#   'borrow',
#   'ron',
#   'nod',
#   'thanks',
#   'hey',
#   'ron',
#   'somebody',
#   'broke',
#   'gringotts',
#   'listen',
#   'believed',
#   'work',
#   'dark',
#   'witch',
#   'wizard',
#   'unknown',
#   'gringotts',
#   'goblin',
#   'acknowledging',
#   'breach',
#   'insist',
#   'nothing',
#   'taken',
#   'vault',
#   'question',
#   'number',
#   'fact',
#   'emptied',
#   'earlier',
#   'day',
#   'odd',
#   'vault',
#   'hagrid',
#   'went',
#   'whoa',
#   'hermione',
#   'stare',
#   'class',
#   'continues',
#   'neville',
#   'shouting',
#   'give',
#   'malfoy',
#   'give',
#   'malfoy',
#   'knock',
#   'broom',
#   'century',
#   'according',
#   'mcgonagall',
#   'never',
#   'even',
#   'played',
#   'quidditch',
#   'make',
#   'fool',
#   'know',
#   'happening',
#   'tap',
#   'ron',
#   'let',
#   'go',
#   'way',
#   'anyone',
#   'feel',
#   'like',
#   'let',
#   'go',
#   'run',
#   'locked',
#   'good',
#   'reason',
#   'ron',
#   'hermione',
#   'turn',
#   'stand',
#   'harry',
#   'massively',
#   'huge',
#   'three',
#   'headed',
#   'dog',
#   'sleeping',
#   'front',
#   'dog',
#   'fluffy',
#   'begin',
#   'wake',
#   'growl',
#   'yawn',
#   'growl',
#   'noticing',
#   'intruder',
#   'guarding',
#   'something',
#   'throw',
#   'back',
#   'think',
#   'point',
#   'two',
#   'squirming',
#   'chained',
#   'ball',
#   'like',
#   'ball',
#   'whoa',
#   'think',
#   'going',
#   'need',
#   'another',
#   'feather',
#   'professor',
#   'think',
#   'heard',
#   'hermione',
#   'could',
#   'troll',
#   'get',
#   'hermione',
#   'know',
#   'going',
#   'girl',
#   'bathroom',
#   'hermione',
#   'move',
#   'whooa',
#   'whoa',
#   'whoa',
#   'land',
#   'troll',
#   'head',
#   'hurled',
#   'forward',
#   'back',
#   'wand',
#   'go',
#   'troll',
#   'nose',
#   'whoa',
#   'whoa',
#   'whoa',
#   'something',
#   'swipe',
#   'anything',
#   'hurry',
#   'think',
#   'knocked',
#   'grab',
#   'wand',
#   'covered',
#   'goo',
#   'ew',
#   'troll',
#   'bogy',
#   'hungry',
#   'explains',
#   'blood',
#   'listen',
#   'last',
#   'night',
#   'guessing',
#   'snape',
#   'let',
#   'troll',
#   'diversion',
#   'could',
#   'try',
#   'get',
#   'past',
#   'headed',
#   'dog',
#   'got',
#   'bitten',
#   'limping',
#   'day',
#   'gringotts',
#   'hagrid',
#   'took',
#   'something',
#   'one',
#   'vault',
#   'said',
#   'hogwarts',
#   'business',
#   'secret',
#   'dog',
#   'guarding',
#   'snape',
#   'want',
#   'never',
#   'get',
#   'mail',
#   'broomstick',
#   'little',
#   'bit',
#   'happened',
#   'yes',
#   'bludger',
#   'zoom',
#   'whoa',
#   'yes',
#   'whoa',
#   'whooa',
#   'know',
#   'trying',
#   'get',
#   'past',
#   'headed',
#   'dog',
#   'halloween',
#   'yes',
#   'hagrid',
#   'whatever',
#   'fluffy',
#   'guarding',
#   'snape',
#   'trying',
#   'steal',
#   'exactly',
#   'nicholas',
#   'flamel',
#   'nicholas',
#   'flamel',
#   'nicholas',
#   'flamel',
#   'knight',
#   'happy',
#   'christmas',
#   'ron',
#   'wearing',
#   'got',
#   'present',
#   'oh',
#   'harry',
#   'run',
#   'stair',
#   'father',
#   'left',
#   'possession',
#   'died',
#   'time',
#   'returned',
#   'use',
#   'well',
#   'kind',
#   'cloak',
#   'body',
#   'gone',
#   'invisible',
#   'come',
#   'name',
#   'said',
#   'use',
#   'well',
#   'reading',
#   'book',
#   'famous',
#   'fire',
#   'eater',
#   'century',
#   'fiend',
#   'flamel',
#   'nicholas',
#   'flamel',
#   'mum',
#   'woman',
#   'nod',
#   'smile',
#   'dad',
#   'nod',
#   'smile',
#   'harry',
#   'reach',
#   'touch',
#   'get',
#   'mirror',
#   'mother',
#   'put',
#   'hand',
#   'shoulder',
#   'put',
#   'hand',
#   'shoulder',
#   'trying',
#   'feel',
#   'ron',
#   'really',
#   'got',
#   'see',
#   'ron',
#   'got',
#   'see',
#   'pull',
#   'back',
#   'cover',
#   'ron',
#   'wake',
#   'ron',
#   'ron',
#   'come',
#   'get',
#   'bed',
#   'something',
#   'got',
#   'see',
#   'come',
#   'come',
#   'come',
#   'come',
#   'look',
#   'parent',
#   'move',
#   'look',
#   'properly',
#   'go',
#   'stand',
#   'see',
#   'thats',
#   'dad',
#   'parent',
#   'dead',
#   'harry',
#   'smile',
#   'sadly',
#   'show',
#   'u',
#   'want',
#   'whatever',
#   'want',
#   'shh',
#   'hagrid',
#   'think',
#   'snape',
#   'trying',
#   'steal',
#   'hagrid',
#   'know',
#   'stone',
#   'know',
#   'wait',
#   'minute',
#   'ron',
#   'big',
#   'black',
#   'boarhound',
#   'fang',
#   'meet',
#   'fang',
#   'sniff',
#   'ron',
#   'one',
#   'teacher',
#   'uh',
#   'hagrid',
#   'exactly',
#   'norbert',
#   'malfoy',
#   'hagrid',
#   'always',
#   'wanted',
#   'dragon',
#   'told',
#   'first',
#   'time',
#   'met',
#   'understand',
#   'bad',
#   'hagrid',
#   'know',
#   'better',
#   'draco',
#   'say',
#   'scared',
#   'fang',
#   'rise',
#   'thing',
#   'saved',
#   'would',
#   'choose',
#   'life',
#   'mean',
#   'say',
#   'thing',
#   'killed',
#   'unicorn',
#   'drinking',
#   'blood',
#   'voldemort',
#   'philosopher',
#   'stone',
#   'weak',
#   'living',
#   'unicorn',
#   'see',
#   'wrong',
#   'snape',
#   'want',
#   'stone',
#   'want',
#   'stone',
#   'voldemort',
#   'elixir',
#   'life',
#   'voldemort',
#   'strong',
#   'come',
#   'back',
#   'sits',
#   'think',
#   'chance',
#   'might',
#   'tried',
#   'kill',
#   'tonight',
#   'scar',
#   'keep',
#   'burning',
#   'like',
#   'think',
#   'warning',
#   'mean',
#   'danger',
#   'coming',
#   'uhh',
#   'rub',
#   'scar',
#   'see',
#   'hagrid',
#   'across',
#   'field',
#   'hut',
#   'oh',
#   'course',
#   'run',
#   'hut',
#   'think',
#   'bit',
#   'odd',
#   'hagrid',
#   'want',
#   'anything',
#   'dragon',
#   'stranger',
#   'show',
#   'happens',
#   'one',
#   'approach',
#   'hagrid',
#   'playing',
#   'harry',
#   'potter',
#   'theme',
#   'flute',
#   'mean',
#   'many',
#   'people',
#   'wander',
#   'around',
#   'dragon',
#   'egg',
#   'pocket',
#   'see',
#   'hagrid',
#   'gave',
#   'dragon',
#   'egg',
#   'hagrid',
#   'stop',
#   'playing',
#   'look',
#   'like',
#   'stranger',
#   'though',
#   'must',
#   'talked',
#   'seem',
#   'interested',
#   'fluffy',
#   'see',
#   'professor',
#   'dumbledore',
#   'immediately',
#   'gone',
#   'important',
#   'philosopher',
#   'stone',
#   'someone',
#   'going',
#   'try',
#   'steal',
#   'stranger',
#   'hagrid',
#   'met',
#   'village',
#   'snape',
#   'mean',
#   'know',
#   'get',
#   'past',
#   'fluffy',
#   'go',
#   'trapdoor',
#   'tonight',
#   'trevor',
#   'neville',
#   'listen',
#   'let',
#   'go',
#   'walk',
#   'neville',
#   'sorry',
#   'snape',
#   'already',
#   'put',
#   'spell',
#   'harp',
#   'approach',
#   'sleeping',
#   'dog',
#   'move',
#   'paw',
#   'come',
#   'grab',
#   'paw',
#   'blocking',
#   'door',
#   'okay',
#   'push',
#   'strain',
#   'move',
#   'open',
#   'door',
#   'go',
#   'first',
#   'follow',
#   'give',
#   'sign',
#   'fluffy',
#   'eye',
#   'open',
#   'something',
#   'bad',
#   'happens',
#   'get',
#   'seem',
#   'bit',
#   'quiet',
#   'jump',
#   'go',
#   'jump',
#   'trapdoor',
#   'whoa',
#   'plant',
#   'begin',
#   'move',
#   'towards',
#   'oh',
#   'ahh',
#   'plant',
#   'tie',
#   'hermione',
#   'yeah',
#   'yeah',
#   'fine',
#   'apparently',
#   'ron',
#   'okay',
#   'okay',
#   'lucky',
#   'hermione',
#   'pay',
#   'attention',
#   'herbology',
#   'know',
#   'sound',
#   'like',
#   'wing',
#   'bird',
#   'key',
#   'bet',
#   'one',
#   'fit',
#   'door',
#   'come',
#   'upon',
#   'broomstick',
#   'suspended',
#   'air',
#   'know',
#   'strange',
#   'see',
#   'point',
#   'one',
#   'broken',
#   'wing',
#   'look',
#   'broom',
#   'simple',
#   'catch',
#   'key',
#   'graveyard',
#   'door',
#   'wait',
#   'minute',
#   'ron',
#   'going',
#   'sacrifice',
#   'ron',
#   'hermione',
#   'start',
#   'walking',
#   'move',
#   'dont',
#   'forget',
#   'still',
#   'playing',
#   'hermione',
#   'move',
#   'back',
#   'harry',
#   'walk',
#   'diagonal',
#   'front',
#   'king',
#   'checkmate',
#   'king',
#   'sword',
#   'fall',
#   'onto',
#   'ground',
#   'victory',
#   'harry',
#   'breathes',
#   'two',
#   'run',
#   'ron',
#   'bend',
#   'beside',
#   'take',
#   'care',
#   'ron',
#   'go',
#   'owlery',
#   'send',
#   'message',
#   'dumbledore',
#   'ron',
#   'right',
#   'go',
#   'good',
#   'quirrell',
#   'turn',
#   'around',
#   'ca',
#   'snape',
#   'one',
#   'day',
#   'quidditch',
#   'match',
#   'snape',
#   'tried',
#   'kill',
#   'snape',
#   'trying',
#   'save',
#   'let',
#   'troll',
#   'shaking',
#   'hand',
#   'dumbledore',
#   'house',
#   'cup',
#   'voldemort',
#   'shake',
#   'head',
#   'never',
#   'liar',
#   'ahhhhhhhhh',
#   'voldemort',
#   'fly',
#   'away',
#   'harry',
#   'fall',
#   'ground',
#   ...],
#  'snake': ['thanks'],
#  'man': ['snake',
#   'welcome',
#   'back',
#   'potter',
#   'welcome',
#   'back',
#   'sorry',
#   'fire',
#   'fire',
#   'ahhhhhhhhhhhhhhhh',
#   'idiot',
#   'professor'],
#  'all': ['ahh',
#   'ahh',
#   'family',
#   'chase',
#   'dudley',
#   'ahhhhhhh',
#   'three',
#   'bolt',
#   'running',
#   'door',
#   'turn',
#   'quickly',
#   'shut',
#   'door',
#   'battle',
#   'dog',
#   'get',
#   'door',
#   'shut',
#   'run',
#   'yay',
#   'yes'],
#  'tom': ['bless',
#   'soul',
#   'harry',
#   'potter',
#   'potter',
#   'last',
#   'right',
#   'smart',
#   'bird',
#   'got',
#   'potter',
#   'arrived',
#   'minute'],
#  'witch': ['doris', 'crockford', 'potter', 'ca', 'believe', 'meeting', 'last'],
#  'quirrell': ['harry',
#   'tell',
#   'pleased',
#   'meet',
#   'fascinating',
#   'subject',
#   'need',
#   'potter',
#   'heheh',
#   'iguana',
#   'mcgonagall',
#   'approach',
#   'class',
#   'stop',
#   'harry',
#   'wait',
#   'essential',
#   'oh',
#   'course',
#   'boy',
#   'oliver',
#   'wood',
#   'get',
#   'leave',
#   'quirrell',
#   'continues',
#   'vampire',
#   'eerie',
#   'roar',
#   'troll',
#   'dungeon',
#   'dungeon',
#   'stop',
#   'utter',
#   'silence',
#   'thought',
#   'ought',
#   'know',
#   'fall',
#   'dead',
#   'faint',
#   'perhaps',
#   'ought',
#   'go',
#   'wake',
#   'heh',
#   'exit',
#   'ron',
#   'harry',
#   'hermione',
#   'troll',
#   'roar',
#   'ahh',
#   'hehe',
#   'severus',
#   'thought',
#   'yes',
#   'seem',
#   'type',
#   'next',
#   'would',
#   'suspect',
#   'professor',
#   'quirrell',
#   'dear',
#   'boy',
#   'tried',
#   'kill',
#   'trust',
#   'snape',
#   'cloak',
#   'caught',
#   'fire',
#   'broken',
#   'eye',
#   'contact',
#   'would',
#   'succeeded',
#   'even',
#   'snape',
#   'muttering',
#   'little',
#   'knew',
#   'danger',
#   'right',
#   'especially',
#   'halloween',
#   'good',
#   'potter',
#   'yes',
#   'snape',
#   'unfortunately',
#   'fooled',
#   'everyone',
#   'else',
#   'running',
#   'dungeon',
#   'went',
#   'floor',
#   'head',
#   'course',
#   'never',
#   'trusted',
#   'rarely',
#   'left',
#   'alone',
#   'quirrell',
#   'turn',
#   'back',
#   'mirror',
#   'harry',
#   'scar',
#   'hurt',
#   'understand',
#   'never',
#   'alone',
#   'never',
#   'mirror',
#   'see',
#   'desire',
#   'see',
#   'holding',
#   'stone',
#   'get',
#   'come',
#   'potter',
#   'tell',
#   'see',
#   'see',
#   'tell',
#   'truth',
#   'see',
#   'master',
#   'strong',
#   'enough',
#   'ahh',
#   'ahh',
#   'back',
#   'hand',
#   'crumbling',
#   'mountain',
#   'black',
#   'ash',
#   'magic',
#   'hand',
#   'dissipates',
#   'walk',
#   'forward',
#   'harry',
#   'put',
#   'hand',
#   'face',
#   'ahhhhhhhhhh'],
#  'boy': ['world',
#   'class',
#   'racing',
#   'broom',
#   'look',
#   'new',
#   'nimbus',
#   'fastest',
#   'model',
#   'yet',
#   'ravenclaw',
#   'follow',
#   'way',
#   'supposed',
#   'take',
#   'yet',
#   'good',
#   'job',
#   'harry',
#   'stay',
#   'together',
#   'cedric',
#   'rule',
#   'like',
#   'badge'],
#  'goblin': ['harry', 'potter', 'key', 'well'],
#  'griphook': ['vault',
#   'lamp',
#   'please',
# ...
#  'young hogwarts students -- james potter, sirius black,': ['peter',
#   'pettigrew',
#   'lupin',
#   'stand',
#   'grinning',
#   'whomping',
#   'willow',
#   'harry',
#   'trace',
#   'thin',
#   'cone',
#   'light',
#   'wand',
#   'across',
#   'face'],
#  'letter (lily)': ['dear',
#   'sirius',
#   'thank',
#   'harry',
#   'birthday',
#   'present',
#   'james',
#   'say',
#   'got',
#   'look',
#   'seeker',
#   'james',
#   'would',
#   'guiet',
#   'birthday',
#   'tea',
#   'u',
#   'old',
#   'bathilda',
#   'dotes',
#   'harry',
#   'wormy',
#   'dropped',
#   'late',
#   'day',
#   'seemed',
#   'stay',
#   'long',
#   'james',
#   'frustrated',
#   'shut',
#   'dumbledore',
#   'still',
#   'got',
#   'invisibility',
#   'cloak',
#   'much',
#   'choice',
#   'way',
#   'bathilda',
#   'tell',
#   'amazing',
#   'story',
#   'old',
#   'headmaster',
#   'know',
#   'much',
#   'believe',
#   'really',
#   'true',
#   'dumbledore',
#   'harry',
#   'turn',
#   'letter'],
#  'reg cattermole/ron': ['case',
#   'interested',
#   'reg',
#   'cattermole',
#   'magical',
#   'maintenance',
#   'department',
#   'oh',
#   'yeah',
#   'thanks',
#   'reckon',
#   'meant',
#   'good',
#   'flush',
#   'bloody',
#   'disgusting',
#   'got',
#   'ta',
#   'tell',
#   'starting',
#   'freak',
#   'bit',
#   'ministry',
#   'snatcher',
#   'hunt',
#   'price',
#   'really',
#   'tried',
#   'umbrella',
#   'downstairs',
#   'oh',
#   'god',
#   'going',
#   'oh',
#   'right',
#   'mad',
#   'two',
#   'find',
#   'umbridge',
#   'fine',
#   'stop',
#   'raining',
#   'finite',
#   'incantatem',
#   'okay',
#   'work',
#   'harry',
#   'blimey',
#   'forgot',
#   'looked',
#   'like',
#   'hermione',
#   'bloody',
#   'cold',
#   'ti',
#   'one',
#   'tell',
#   'kid',
#   'mary',
#   'go',
#   'home',
#   'get',
#   'kid',
#   'mary',
#   'say',
#   'sorry',
#   'mary',
#   'cattermole',
#   'take',
#   'collar',
#   'pull'],
#  'mafalda hopkirk/hermione': ['mafalda',
#   'hopkirk',
#   'assistant',
#   'improper',
#   'use',
#   'magic',
#   'office',
#   'somebody',
#   'careful',
#   'nodding',
#   'disgust',
#   'muggles',
#   'rightful',
#   'place',
#   'appear',
#   'quite',
#   'popular',
#   'try',
#   'finite',
#   'incantatem',
#   'course',
#   'something',
#   'gone',
#   'wrong',
#   'atmospheric',
#   'charm',
#   'like',
#   'really',
#   'horrible',
#   'teeth',
#   'know'],
#  'albert runcorn/harry': ['patting',
#   'pocket',
#   'nobody',
#   'apparently',
#   'ministry',
#   'must',
#   'hiring',
#   'young',
#   'day',
#   'long',
#   'say',
#   'batch',
#   'polyjuice',
#   'potion',
#   'would',
#   'last',
#   'hermione',
#   'ron',
#   'wife',
#   'look',
#   'go',
#   'ron',
#   'coming',
#   'since',
#   'two',
#   'year',
#   'old',
#   'u',
#   'worrying',
#   'whispering',
#   'guickly',
#   'say',
#   'locate',
#   'umbridge',
#   'within',
#   'hour',
#   'go',
#   'find',
#   'ron',
#   'come',
#   'back',
#   'another',
#   'day',
#   'deal',
#   'accio',
#   'locket',
#   'ron',
#   'went',
#   'courtroom',
#   'umbridge',
#   'grille',
#   'open',
#   'reveal',
#   'arthur',
#   'weasley',
#   'company',
#   'elderly',
#   'witch',
#   'wakinda',
#   'arthur',
#   'know',
#   'tracked',
#   'arthur',
#   'fact',
#   'watching',
#   'tell',
#   'later',
#   'let',
#   'find',
#   'hermione',
#   'lying',
#   'one',
#   'tell',
#   'lie',
#   'dolores',
#   'stupefy',
#   'expeto',
#   'patronum'],
#  'skinny wizard': ['morning', 'reg', 'good', 'luck', 'today'],
#  'balding wizard': ['move',
#   'oh',
#   'runcorn',
#   'forgive',
#   'right',
#   'right',
#   'let',
#   'calm',
#   'shall',
#   'probably',
#   'snuck',
#   'experimental',
#   'charm',
#   'think',
#   'none',
#   'u',
#   'soon',
#   'forget',
#   'last',
#   'month',
#   'poisonous',
#   'duck'],
#  'female': ['level',
#   'two',
#   'department',
#   'magical',
#   'law',
#   'enforcement',
#   'including',
#   'wizengamot',
#   'administration',
#   'service',
#   'auror',
#   'headquarters',
#   'improper',
#   'use',
#   'magic',
#   'department',
#   'level',
#   'one',
#   'minister',
#   'magic',
#   'support',
#   'staff'],
#  'young wizard': ['weasley', 'waiting', 'report', 'downstairs'],
#  'percy weasley': ['oh', 'yes', 'course'],
#  'red-haired witch': ['reckon',
#   'old',
#   'hag',
#   'interrogating',
#   'mudbloods',
#   'day'],
#  'bespectacled wizard': ['sh', 'careful'],
#  'head of the muggle-born registration commission': ['harry',
#   'jaw',
#   'tightens',
#   'anger',
#   'glance',
#   'shoulder',
#   'see',
#   'witch',
#   'watching',
#   'glance',
#   'away',
#   'guickly',
#   'harry',
#   'reach',
#   'inner',
#   'pocket',
#   'remove',
#   'decoy',
#   'detonator',
#   'odd',
#   'object',
#   'little',
#   'weaving',
#   'leg',
#   'horn',
#   'body',
#   'release'],
#  'morning': ['turn',
#   'witch',
#   'watching',
#   'put',
#   'finger',
#   'lip',
#   'eye',
#   'go',
#   'wide',
#   'saucer'],
#  'wakinda': ['let', 'guess', 'raining', 'yaxley', 'office'],
#  'scared man': ['tell',
#   'father',
#   'wizard',
#   'look',
#   'william',
#   'alderton',
#   'worked',
#   'thirty',
#   'year'],
#  'mary cattermole': ['reg',
#   'eo',
#   'yes',
#   'yes',
#   'take',
#   'got',
#   'diagon',
#   'alley',
#   'ollivander',
#   'eleven',
#   'chose',
#   'tell',
#   'reg',
#   'tell',
#   'reg',
#   'harry',
#   'potter'],
#  'muttering wizard': ['harry', 'potter', 'louder', 'harry', 'potter'],
#  'reg cattermole': ['mary'],
#  'gregorovitch': ['told',
#   'longer',
#   'stolen',
#   'many',
#   'year',
#   'ago',
#   'speak',
#   'truth',
#   'remember',
#   'like',
#   'yesterday',
#   'boy',
#   'village',
#   'took',
#   'never',
#   'saw',
#   'swear',
#   'life'],
#  'scabior': ['smell',
#   'hello',
#   'beautiful',
#   'boyfriend',
#   'get',
#   'worse',
#   'behave',
#   'lovely',
#   'happened',
#   'ugly',
#   'name',
#   'check',
#   'list',
#   'ginger',
#   'like',
#   'ell',
#   'know',
#   'skinny',
#   'stan',
#   'try',
#   'weasley',
#   'eh',
#   'related',
#   'blood',
#   'traitor',
#   'arthur',
#   'weasley',
#   'would',
#   'worth',
#   'ten',
#   'time',
#   'find',
#   'tipped',
#   'bout',
#   'lovely',
#   'call',
#   'smell',
#   'like',
#   'vanilla',
#   'penelope',
#   'think',
#   'going',
#   'favorite',
#   'change',
#   'plan',
#   'boy',
#   'taking',
#   'lot',
#   'ministry',
#   'north',
#   'forest',
#   'mine',
#   'quietly',
#   'menacing',
#   'forgetting',
#   'actually',
#   'caught',
#   'hope',
#   'malfoy',
#   'came',
#   'u',
#   'way',
#   'reckon',
#   'picked',
#   'forest',
#   'mad',
#   'dare',
#   'release',
#   'woman'],
#  'new angle —- graveyard': ['hermione',
#   'pause',
#   'large',
#   'tombstone',
#   'freckled',
#   'lichen'],
#  'new angle —- tombstones': ['hermione',
#   'walk',
#   'amid',
#   'stone',
#   'studying',
#   'name',
#   'stop',
#   'extremely',
#   'old',
#   'grave',
#   'crouch'],
#  'james potter lily potter': ['born',
#   'march',
#   'born',
#   'january',
#   'died',
#   'october',
#   'died',
#   'october'],
#  'same time - night': ['life',
#   'lie',
#   'albus',
#   'dumbledore',
#   'hand',
#   'reach',
#   'take',
#   'hermione',
#   'hand',
#   'note',
#   'attached',
#   'dear',
#   'batty',
#   'thanks',
#   'help',
#   'said',
#   'everything',
#   'even',
#   'remember',
#   'rita'],
#  'bathilda bagshot': ['parseltongue', 'potter', 'parseltongue', 'something'],
#  'action - night': ['screaming',
#   'dark',
#   'silence',
#   'chill',
#   'water',
#   'kick',
#   'glimmering',
#   'sword',
#   'grab',
#   'hilt',
#   'kick',
#   'surface'],
#  'riddle-harry': ['better', 'without', 'happier', 'without'],
#  'riddle-hermione': ['could',
#   'look',
#   'beside',
#   'harry',
#   'potter',
#   'compared',
#   'chosen',
#   'one',
#   'prefer',
#   'woman',
#   'would',
#   'take',
#   'nothing',
#   'nothing',
#   'nothing'],
#  'riddle-—harry': ['mother', 'confessed', 'would', 'preferred'],
#  'harry / hermione': ['luna'],
#  'dozens die as death eaters attack, harry in hiding, where': ['chosen',
#   'one',
#   'claim',
#   'another',
#   'victim',
#   'quidditch',
#   'world',
#   'cup',
#   'cancelled',
#   'amid',
#   'death',
#   'threat',
#   'abruptly',
#   'press',
#   'go',
#   'silent',
#   'lovegood',
#   'turn'],
#  'harry/ron/hermione': [],
#  'hermione/ron harry': ['yes'],
#  'ron hermione': ['wand', 'cloak'],
#  'grindelwald': ['ah',
#   'tom',
#   'thought',
#   'would',
#   'come',
#   'one',
#   'day',
#   'surely',
#   'must',
#   'know',
#   'longer',
#   'seek',
#   'innocent',
#   'tom',
#   'like',
#   'schoolboy',
#   'much',
#   'understand',
#   'guess',
#   'tom',
#   'lie',
#   'course',
#   'buried',
#   'within',
#   'earth',
#   'posse',
#   'even',
#   'death',
#   'old',
#   'friend',
#   'mine',
#   'dumbledore'],
#  'snatcher': ['vernon', 'dudley', 'ere', 'bag', 'searched', 'reckon', 'mine'],
#  'fenrir greyback': ['hear',
#   'ugly',
#   'list',
#   'say',
#   'lying',
#   'come',
#   'want',
#   'u',
#   'know',
#   'hm'],
#  'brown': ['ron', 'study', 'mirror', 'harry', 'turn'],
#  'closeup - linked hands - moments later': ['harry',
#   'ron',
#   'hermione',
#   'griphook',
#   'stand',
#   'tight',
#   'circle',
#   'griphook',
#   'hand',
#   'join',
#   'others',
#   'whoosh',
#   'vanish'],
#  'warlock': ['madam', 'lestrange'],
#  'aged goblin': ['identification',
#   'looking',
#   'madam',
#   'lestrange',
#   'dear',
#   'may',
#   'help',
#   'today',
#   'see',
#   'well',
#   'excuse',
#   'bogrod',
#   'special',
#   'instruction',
#   'regarding',
#   'lestrange',
#   'vault',
#   'yes',
#   'sir',
#   'instruction',
#   'specific'],
#  'tall goblin': ['next'],
#  'bogrod': ['madam',
#   'lestrange',
#   'would',
#   'mind',
#   'presenting',
#   'wand',
#   'bank',
#   'policy',
#   'sure',
#   'understand',
#   'given',
#   'current',
#   'climate',
#   'bellatrix',
#   'hermione',
#   'certainly',
#   'understand',
#   'sensing',
#   'harry',
#   'presence',
#   'falter',
#   'voice',
#   'emerging',
#   'bellatrix',
#   'bogrod',
#   'eye',
#   'intensely',
#   'afraid',
#   'must',
#   'insist',
#   'well',
#   'madam',
#   'lestrange',
#   'follow',
#   'fully',
#   'aware',
#   'also',
#   'aware',
#   'lestranges',
#   'one',
#   'oldest',
#   'respected',
#   'family',
#   'let',
#   'specific',
#   'ricbert',
#   'run',
#   'bank',
#   'year',
#   'long',
#   'anyone',
#   'even',
#   'heard',
#   'death',
#   'eater',
#   'day',
#   'may',
#   'come',
#   'feel',
#   'run',
#   'place',
#   'better',
#   'day',
#   'yet',
#   'arrived',
#   'understood',
#   'madam',
#   'escort',
#   'guard',
#   'teffington',
#   'see',
#   'door',
#   'devil',
#   'griphook',
#   'right',
#   'anymore',
#   'gave',
#   'key',
#   'hermione',
#   'harry',
#   'raise',
#   'wand',
#   'late',
#   'hm',
#   'oh',
#   'yes',
#   'course'],
#  'into camera, eyes dark, the surface of his skin trembling': ['like',
#   'water',
#   'nagini',
#   'fang',
#   'flashing'],
#  'death eater #1': ['right',
#   'got',
#   'know',
#   'potter',
#   'getting',
#   'away',
#   'perhaps',
#   'need',
#   'convincing'],
#  'aberforth': ['potter',
#   'bloody',
#   'fool',
#   'thinking',
#   'coming',
#   'idea',
#   'dangerous',
#   'left',
#   'sorry',
#   'hear',
#   'liked',
#   'elf',
#   'mundungus',
#   'fletcher',
#   'bout',
#   'year',
#   'ago',
#   'sirius',
#   'albus',
#   'told',
#   'also',
#   'told',
#   'likely',
#   'hacked',
#   'ever',
#   'found',
#   'ask',
#   'right',
#   'reckon',
#   'hungry',
#   'let',
#   'get',
#   'fed',
#   'think',
#   'best',
#   'way',
#   'get',
#   'order',
#   'finished',
#   'anyone',
#   'say',
#   'otherwise',
#   'kidding',
#   'nice',
#   'job',
#   'easy',
#   'job',
#   'brother',
#   'given',
#   'suicide',
#   'mission',
#   'favor',
#   'boy',
#   'go',
#   'home',
#   'live',
#   'little',
#   'longer',
#   'make',
#   'think',
#   'trust',
#   'make',
#   'think',
#   'believe',
#   'anything',
#   'brother',
#   'told',
#   'time',
#   'knew',
#   'ever',
#   'mention',
#   'name',
#   'ever',
#   'mention',
#   'keep',
#   'secret',
#   'tell',
#   'boy',
#   'answer',
#   'boy',
#   'go',
#   'chasing',
#   'horcruxes',
#   'word',
#   'man',
#   'even',
#   'tell',
#   'start',
#   'lying',
#   'matter',
#   'well',
#   'fool',
#   'strike',
#   'fool',
#   'potter',
#   'ask',
#   'must',
#   'reason',
#   'trust',
#   'anything',
#   'brother',
#   'ever',
#   'said',
#   'know',
#   'see',
#   'soon',
#   'enough',
#   'always',
#   'beautiful',
#   'brother',
#   'sacrificed',
#   'many',
#   'thing',
#   'potter',
#   'journey',
#   'find',
#   'power',
#   'including',
#   'devoted',
#   'gave',
#   'everything',
#   'time'],
#  '+ + + hf': [],
#  'alecto carrow': ['put',
#   'smile',
#   'miss',
#   'reynolds',
#   'want',
#   'pay',
#   'visit',
#   'daddy',
#   'would'],
#  'pansy parkinson': ['potter',
#   'someone',
#   'grab',
#   'let',
#   'u',
#   'filthy',
#   'squib'],
#  'madam sprout': ['mean', 'hold'],
#  'teachers': ['protego', 'maximum', 'finato', 'duril', 'repello', 'inimicum'],
#  'kingsley shacklebolt': ['tell',
#   'professor',
#   'mcgonagall',
#   'remus',
#   'handle',
#   'side',
#   'castle',
#   'dean',
#   'dean',
#   'stop',
#   'second',
#   'thought',
#   'tell',
#   'professor',
#   'mcgonagall',
#   'might',
#   'need',
#   'one',
#   'two',
#   'wand',
#   'side',
#   'said'],
#  'the grey lady': ['answer',
#   'name',
#   'friend',
#   'luna',
#   'seek',
#   'mother',
#   'diadem',
#   'luna',
#   'kind',
#   'unlike',
#   'many',
#   'others',
#   'wrong',
#   'help',
#   'many',
#   'sought',
#   'mother',
#   'diadem',
#   'power',
#   'vague',
#   'drifting',
#   'thought',
#   'took',
#   'hurt',
#   'wanted',
#   'like',
#   'clever',
#   'wise',
#   'wore',
#   'beautifully',
#   'grew',
#   'hate',
#   'pain',
#   'felt',
#   'pain',
#   'feel',
#   'even',
#   'another',
#   'swore',
#   'destroy',
#   'many',
#   'year',
#   'ago',
#   'strange',
#   'boy',
#   'strange',
#   'name',
#   'lied',
#   'know',
#   'done',
#   'know',
#   'defiled',
#   'dark',
#   'magic',
#   'strange',
#   'remind',
#   'hima',
#   'bit',
#   'ee',
#   'castle',
#   'place',
#   'everything',
#   'hidden',
#   'ask',
#   'never',
#   'know',
#   'know',
#   'need',
#   'ask',
#   'x'],
#  'their pov — an empty corridor': ['swirling', 'smoke'],
#  'goyle': ['c', 'mon', 'draco', 'prat', 'avada', 'kedavra'],
#  'new angle - high': ['one',
#   'another',
#   'towering',
#   'wall',
#   'spill',
#   'like',
#   'domino'],
#  'new angle —- ground level': ['harry',
#   'hermione',
#   'run',
#   'side',
#   'side',
#   'world',
#   'come',
#   'crashing'],
#  'if we die for them, i’ll kill you,': ['harry'],
#  'their pov': ['triage',
#   'house',
#   'table',
#   'pushed',
#   'wall',
#   'injured',
#   'stand',
#   'group',
#   'arm',
#   'slung',
#   'one',
#   'another',
#   'waiting',
#   'treated',
#   'madam',
#   'pomfrey',
#   'filch',
#   'arm',
#   'gush',
#   'blood',
#   'flitwick',
#   'face',
#   'laced',
#   'gash'],
#  'petunia evans': ['lily', 'come', 'fade', 'going', 'home'],
#  'young snape': ['jealous', 'ordinary', 'special', 'true', 'know'],
#  'lily evans': ['mean'],
#  'oliver wood': ['take'],
#  'young girl': ['kept', 'calling', 'one', 'came'],
#  'james potter': ['nearly', 'son', 'end'],
#  'new angle - harry and dumbledore': ['walking'],
#  'new angle —- neville - night': ['neville',
#   'kick',
#   'rubble',
#   'one',
#   'could',
#   'reconstruct',
#   'history',
#   'hogwarts',
#   'detritus',
#   'spell',
#   'book',
#   'trophy',
#   'potion',
#   'box',
#   'neville',
#   'expression',
#   'remains',
#   'stoic',
#   'unsentimental',
#   'seen',
#   'much',
#   'last',
#   'hour'],
#  'close on the peak of a hat': ['neville',
#   'crouch',
#   'study',
#   'reaching',
#   'wiggle',
#   'free',
#   'slap',
#   'thigh',
#   'chase',
#   'dust'],
#  'harry’s pov of neville': ['study',
#   'face',
#   'curious',
#   'reflection',
#   'quiver',
#   'harry',
#   'watch',
#   'dance',
#   'briefly',
#   'across',
#   'neville',
#   'cheek',
#   'vanishing',
#   'harry',
#   'gaze',
#   'shift',
#   'sorting',
#   'hat',
#   'neville',
#   'hand',
#   'shift',
#   'nagini'],
#  'new angle - nagini - moving': ['flowing',
#   'like',
#   'water',
#   'ever',
#   'downward',
#   'thwack',
#   'bit',
#   'rubble',
#   'bounce',
#   'slithering',
#   'tail',
#   'hiss',
#   'coiling',
#   'blunt',
#   'head',
#   'darting',
#   'warily'],
#  'new angle - lower stair': ['hermione',
#   'stand',
#   'watching',
#   'rearing',
#   'back',
#   'hurl',
#   'another',
#   'sharp',
#   'fragment'],
#  '346bb': [],
#  'blurry pov': ['shadow',
#   'streak',
#   'across',
#   'plane',
#   'view',
#   'like',
#   'warrior',
#   'ancient',
#   'shadow',
#   'play',
#   'sound',
#   'surface',
#   'slowly',
#   'oddly',
#   'ear',
#   'drum',
#   'numb',
#   'swollen',
#   'gradually',
#   'returning',
#   'normal'],
#  'new angle —- harry and voldemort': ['entwined',
#   'morphing',
#   'monstrously',
#   'one',
#   'another',
#   'single',
#   'screaming',
#   'beast',
#   'one',
#   'minute',
#   'adversary',
#   'next',
#   'hurtling',
#   'downward',
#   'toward',
#   'courtyard'],
#  'older harry': ['together',
#   'nothing',
#   'scary',
#   'thestrals',
#   'gentle',
#   'thing',
#   'anyway',
#   'going',
#   'school',
#   'carriage',
#   'going',
#   'boat',
#   'remember',
#   'yes',
#   'albus',
#   'severus',
#   'potter',
#   'named',
#   'two',
#   'headmaster',
#   'hogwarts',
#   'one',
#   'slytherin',
#   'probably',
#   'bravest',
#   'man',
#   'ever',
#   'knew',
#   'slytherin',
#   'house',
#   'gained',
#   'wonderful',
#   'wizard',
#   'listen',
#   'mean',
#   'much',
#   'choose',
#   'gryffindor',
#   'sorting',
#   'hat',
#   'take',
#   'choice',
#   'account',
#   'really',
#   'ready'],
#  'older hermione': ['forget', 'give', 'professor', 'longbottom', 'best'],
#  'albus': ['really',
#   'thestrals',
#   'pulling',
#   'carriage',
#   'dad',
#   'put',
#   'slytherin',
#   'say',
#   'really',
#   'ready']}

# %%
# Lets combine all sentences of each movie
movie_sentences = dict()
for movie in df.movie_nr.unique():
    for character in df.character.unique():
        text = df.sentence[df.character == character].str.cat(sep=' ')
        tokens = nltk.word_tokenize(text)
        words = [w.lower() for w in tokens if w.isalpha()]
        lem_words = [wnl.lemmatize(w) for w in words if w not in stopwords]
        harry_freq = nltk.FreqDist(lem_words)
    movie_sentences[movie] = lem_words

# %%
# Lets calculate the sentiment for each characters based on all their sentences 
import csv
sentiments = {}
with open('data/Data_Set_S1.txt', 'r') as f:
    reader = csv.reader(f, dialect='excel-tab')
    for row in reader:
        if len(row) == 8 and row[0] != "word": # skipping the first lines
            sentiments[row[0].lower()] = float(row[2]) # storing the average sentiment

# %%
# Calculate the average sentiment for each characters 
def sentiment(freqdist,cut_off=False):
    sentim_words = [w for w in freqdist.keys() if sentiments.get(w)] # get all word that are in sentiment list
    sentim_values = [sentiments[val]*freqdist[val] for val in sentim_words] # get the value and multiplay by frequency
    sentim_words_freq = sum([freqdist[w] for w in sentim_words]) # total occurances of all valid sentim words
    if cut_off:
        if sentim_words_freq > cut_off: # only take in words that have certin frequency of sentimental words
            return sum(sentim_values) / sentim_words_freq
        else: 
            return None
    else:
        if len(sentim_words) > 0:
            return sum(sentim_values) / sentim_words_freq
        else: 
            return None

# %%
# Get average sentiment for all sentences of character
char_sentiment = {}
for char in char_sentences:
    sentiment_for_char = sentiment(nltk.FreqDist(char_sentences[char]))
    if sentiment_for_char:
        char_sentiment[char] = sentiment_for_char

# %%
np.mean(list(char_sentiment.values()))
# Out:
# 5.494063650888373

# %%
#Create a histogram of all character's associated page-sentiments.
import numpy as np 

plt.figure(figsize=(16,9))
plt.hist(char_sentiment.values(),bins=200)
sent_mean = np.mean((list(char_sentiment.values())))
plt.axvline(x=sent_mean, label=f'Mean={sent_mean}', c='red')
plt.legend()
plt.title('Sentiment distribution for all pages')
plt.ylabel('count')
plt.xlabel('Sentimental Score')

plt.show()

# %%
df[df.character == 'snake']['sentence']
# Out:
# 42    Thankssssssss.
# Name: sentence, dtype: object

# %%
sentiments['thank']
# Out:
# 7.4

# %%
#Todo: 
# Make worlcloud for 5 most occuring characters from each house and plot there figure and worldcloud.

# %%
from os import path
from PIL import Image
import os

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
hp_mask = np.array(Image.open(path.join(d, "data/char_images/dobby.jpg")))

# Define the settings and input to the wordclouds - DC
wordcloud_all_books = WordCloud(background_color='white',   
                         width=1000,
                         max_words=2000,
                         height=1000, 
                         colormap="viridis",
                         mask = hp_mask,
                         random_state = 42
                         #contour_width=1, 
                         #contour_color='steelblue'
                        ).generate_from_frequencies(harry_freq)

plt.figure(figsize=(10,10))

plt.imshow(wordcloud_all_books, interpolation='bilinear')
plt.title("Wordcloud for all lines from Dobby", fontsize=18)
plt.axis("off")
plt.tight_layout()

# %%
# Lets see how the sentiment changes over time, this is done by creating a moving average of the sentiments for all characters
def token_getsent(text):
    #lets toxenize the text 
    tokens = nltk.word_tokenize(text)
    words = [w.lower() for w in tokens if w.isalpha()]
    lem_words = [wnl.lemmatize(w) for w in words if w not in stopwords]
    
    # Get the sentiment score
    return(sentiment(nltk.FreqDist(lem_words)))
    

# df['sent_sentence'] = [x for x in ] 

df['sentence_sent'] = df.apply(lambda x: token_getsent(x['sentence']),axis=1)
df['scene_desc_sent'] = df.apply(lambda x: token_getsent(x['sentence']),axis=1)

# lets add the average sentence sentiment for each scene_id
df['avg_scene_sent'] = df.groupby(['scene_id'])['sentence_sent'].transform('mean')
df['avg_scene_desc_sent'] = df.groupby(['scene_id'])['scene_desc_sent'].transform('mean')

# %%
df.head()
# Out:
#   movie_nr sentence_number   character  \
# 0        1               1  dumbledore
# 1        1               2  mcgonagall
# 2        1               3  dumbledore
# 3        1               4  mcgonagall
# 4        1               5  dumbledore
#
#                                             sentence  \
# 0  I should have known that you would be here...P...
# 1  Good evening, Professor Dumbledore. Are the ru...
# 2   I'm afraid so, Professor. The good, and the bad.
# 3                                       And the boy?
# 4                            Hagrid is bringing him.
#
#                                           scene_desc scene_id  sentence_sent  \
# 0  A neighbourhood on a street called Privet Driv...        1          5.740
# 1  The cat meows, sniffs out and the camera pans ...        1          6.685
# 2  The cat meows, sniffs out and the camera pans ...        1          4.635
# 3  The cat meows, sniffs out and the camera pans ...        1          6.240
# 4  The cat meows, sniffs out and the camera pans ...        1          6.040
#
#    scene_desc_sent  avg_scene_sent  avg_scene_desc_sent
# 0            5.740        5.506538             5.506538
# 1            6.685        5.506538             5.506538
# 2            4.635        5.506538             5.506538
# 3            6.240        5.506538             5.506538
# 4            6.040        5.506538             5.506538

# %%
# function to plot moving average 

def m_avg(values,N): # takes in the values and the N of average (how many values to use)
    size = len(values)
    if size-N < 2:
        return(f'Short list or N too big.')
    else:
        cumsum, moving_aves = [0], []

        for i, x in enumerate(values, 1):
            cumsum.append(cumsum[i-1] + x)
            if i>=N:
                moving_ave = (cumsum[i] - cumsum[i-N])/N
                
                # add the the average vector
                moving_aves.append(moving_ave)
    return(moving_aves)

# %%
# m_avg(df.sent_sentence.dropna(),10)
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
plt.plot(m_avg(df.sentence_sent.dropna(),150))

# %%
df[df.character == 'harry']['sentence']
# Out:
# 21                                     Yes, Aunt Petunia.
# 24                                     Yes, Uncle Vernon.
# 36                                           He's asleep!
# 38      Sorry about him. He doesn't understand what it...
# 39      Can you...hear me? {The snake nods} It's just....
#                               ...
# 7969                       Because it answers to another.
# 7970    When he killed Snape, he thought the wand woul...
# 7971    It was Draco who disarmed Dumbledore that nigh...
# 7973                                    It answers to me.
# 7977                      Well, it wasn’t boring, was it?
# Name: sentence, Length: 1995, dtype: object

# %%
df['character'][df.movie_nr == 2].value_counts()[:50].index.tolist() # get 20 most occuring characters
# Out:
# ['harry',
#  'ron',
#  'hermione',
#  'gilderoy lockhart',
#  'tom riddle',
#  'dumbledore',
#  'hagrid',
#  'lucius malfoy',
#  'dobby',
#  'draco',
#  'uncle vernon',
#  'mrs. weasley',
#  'snape',
#  'moaning myrtle',
#  'mr. weasley',
#  'filch',
#  'wood',
#  'aragog',
#  'harry /ron',
#  'voice',
#  'madam pomfrey',
#  'ginny',
#  'percy',
#  'dudley',
#  'professor sprout',
#  'neville',
#  'seamus',
#  'colin',
#  'mr. borgin',
#  'fudge',
#  'george',
#  'ernie',
#  'young hagrid',
#  'hannah',
#  'fred',
#  'aunt petunia',
#  'justin finch-fletchley',
#  'same scene - later',
#  'dean thomas',
#  'sorting hat',
#  'flint',
#  'albus dumbledore',
#  'penelope clearwater',
#  'harry /ron/hermione',
#  'the chamber of secrets has been opened',
#  'back to scene',
#  'dissolve',
#  "at work and it's entirely your",
#  'nearly headless nick',
#  'lucious malfoy']

# %%
# Todo, finish up the moving average plot, set different colors on different movies
df[df.character ==  'aragog']['sentence']
# Out:
# 1573    You do not come from the forest. Your hearts b...
# 1575    Hagrid has never sent men into our hollow before.
# 1577    That's a lie! Hagrid never opend the Chamber o...
# 1579    The monster was born in the castle. I came fro...
# 1582    We do not speak of it! It is an ancient creatu...
# 1584    I never saw any part of the castle but the cup...
# 1587    Go? I think not. My sons and daughters do not ...
# 2559    You do not come from the forest. Your hearts b...
# 2561    Hagrid has never sent men into our hollow before.
# 2563    That's a lie! Hagrid never opend the Chamber o...
# 2565    The monster was born in the castle. I came fro...
# 2568    We do not speak of it! It is an ancient creatu...
# 2570    I never saw any part of the castle but the cup...
# 2573    Go? I think not. My sons and daughters do not ...
# Name: sentence, dtype: object

# %%
sentiments['die']
# Out:
# 1.74
