# %%
import random
import nltk, re, pprint
from nltk import word_tokenize
from nltk.corpus import stopwords
import pandas as pd
import matplotlib.pyplot as plt
import copy
import numpy as np
import seaborn as sns
import itertools
import pickle
import math
import networkx as nx
import community
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator
from operator import itemgetter
from fa2 import ForceAtlas2
sns.set()
# %matplotlib inline

# %%
# Getting the ForceAtlas algorithm configuration ready

forceatlas2 = ForceAtlas2(
    # Behavior alternatives
    outboundAttractionDistribution = False, # Dissuade hubs
    edgeWeightInfluence=1,
    
    # Performance
    jitterTolerance=0.2, # Tolerance
    barnesHutOptimize=True,
    barnesHutTheta=0.6,
    
    # Tuning
    scalingRatio=5,
    strongGravityMode=True,
    gravity=1.0,
    
    # Log
    verbose=False
)

# %% [markdown]
# # Hugmyndir og tékk listi
#
#
# #### Must do:
# Wordclouds sem eru í laginu eins og characterinn fyrir top 10 characerana (flestar línur)
#
# Network fyrir hverja mynd byggt á hversu oft karakterar eru saman í senu
#
# Network fyrir hverja mynd með því að taka karaktera sem tala á undan hvorum öðrum (notað í stað línunar á undan), hér væri þá counter á milli karaktera ef þér koma í röð á eftir hvorum öðrum.
#
# Sentiment analysis á Karakterana og myndirnar,
#
# Almenn statistic um myndirnar, karakterar, sentimen....
#
#
# --------------
# #### Advanced hugmyndir:
# Gera svona transition network (einskonar race graph) þar sem networkið byggir á síðustu 500 setningnum og sýnir hverjir eru að tala mest saman í gegnum allar myndirnar.
#
#
#
# PUnktar sem ég hafði upphaflega....
# Skoða sentiment á setningum komið
#
# SKoða sentiment á scenes komið
#
# SKoða sentiment sérstakra karaktera  komið
#
# Skoða tengst karaktera m.v. scene eða röðun (fyrir og eftir), ef character kemur fyrir og eftir þá tala þeir sama t.d.
#
# Create wordclous out of sentences with the outlines of the characters
#
# Create a quiz where you get a sentence from character and guess who it was.

# %%
# Read in the dataframe
import pickle
import pandas as pd
import numpy as np

df = pd.read_pickle("script_df.pkl")
df.head()
# Out:
#   movie_nr sentence_number   character  \
# 0        1               1  Dumbledore
# 1        1               2  McGonagall
# 2        1               3  Dumbledore
# 3        1               4  McGonagall
# 4        1               5  Dumbledore
#
#                                             sentence  \
# 0  I should have known that you would be here...P...
# 1  Good evening, Professor Dumbledore. Are the ru...
# 2   I'm afraid so, Professor. The good, and the bad.
# 3                                       And the boy?
# 4                            Hagrid is bringing him.
#
#                                           scene_desc scene_id
# 0  A neighbourhood on a street called Privet Driv...        1
# 1  The cat meows, sniffs out and the camera pans ...        1
# 2  The cat meows, sniffs out and the camera pans ...        1
# 3  The cat meows, sniffs out and the camera pans ...        1
# 4  The cat meows, sniffs out and the camera pans ...        1

# %% [markdown]
# # Cleaning the dataframe:

# %%
# All the movie titles in correct order
move_titles = ["Harry Potter and the Philosopher's Stone","Harry Potter and the Chamber of Secrets",
              "Harry Potter and the Prisoner of Azkaban","Harry Potter and the Goblet of Fire",
              "Harry Potter and the Order of the Phoenix","Harry Potter and the Half-Blood Prince",
              "Harry Potter and the Deathly Hallows – Part 1","Harry Potter and the Deathly Hallows – Part 2"]
move_titles_short = [move_titles[i].split("Harry Potter and the ", 1)[1] for i in range(len(move_titles))]

# %%
#  Split on all character names that include / to give each character its own line even though many are saying the sentence at once
# symbols = ['/',' --- ','']
# for symbol in symbols:
df = df.drop('character', axis=1).join(df['character'].str.split('/', expand=True).stack().reset_index(level=1, drop=True).rename('character'))
df.character = df.character.str.strip()

df = df[['movie_nr', 'sentence_number', 'character', 'sentence', 'scene_desc', 'scene_id']]

# %%
# Lets first fix the characters So they all have lower_case letters
df['character'] = df['character'].str.lower()

# %%
# Throw out where character names include some words
throw_out_list = ['new','same','moving',' you ']
for throw in throw_out_list:
    df = df[~df.character.str.contains(throw)]
    

# TODO, clean all characters that have more than 4 word, len(str.split) > 4
df = df[df.character.str.split(' ').apply(len)<4]

# %%
# df[df.sentence != ''].groupby('character').size()
# sentence_count = df[df.sentence != ''].groupby('character').size()
# sentence_count_limit = sentence_count[sentence_count > 2]

map_characters = {'dumbledore': 'albus dumbledore',
                  'dumbledore (cont’d)': 'albus dumbledore',
                  'tom riddle': 'voldemort',
                  'riddle': 'voldemort',
                  'voldermort': 'voldemort',
                  'harry': 'harry potter',
                 'lucius': 'lucius malfoy',
                 'draco': 'draco malfoy',
                 'malfoy': 'draco malfoy'}

df.character = df.character.map(map_characters).fillna(df['character'])
# df.character = df.character.replace(map_characters)

#  Now when all names have been mapped and fixed we capitalize the names for cleaner representation 
df.character = df.character.str.title()

# %% [markdown]
# # Enrich the dataframe with sentiment analysis

# %% [markdown]
# ### Create dictionary of character and movie sentences

# %%
# Add new column to dataframe that include the tokenized sentences
# Function to calculate the sentiment of tokenized list
def tokenize(text):
    #toxenize the text 
    tokens = nltk.word_tokenize(text)
    words = [w.lower() for w in tokens if w.isalpha()]
    lem_words = [wnl.lemmatize(w) for w in words if w not in stopwords]
    return(lem_words)

stopwords = nltk.corpus.stopwords.words('english')
wnl = nltk.WordNetLemmatizer()

# %%
# Lets combine all sentences of characters into a dictionary

char_sentences = dict()
for character in df.character.unique():
    text = tokenize(df.sentence[df.character == character].str.cat(sep=' '))
    char_sentences[character] = text
    
# Lets combine all sentences for each movie into a dictionary
movie_sentences = dict()
for movie in df.movie_nr.unique():
    text = tokenize(df.sentence[df.movie_nr == movie].str.cat(sep=' '))
    movie_sentences[movie] = text
    
# maybe have dictionary that has the key movie, that has the key of character and and the value as sentence

# %%
# Read in the sentiment text file
import csv
sentiments = {}
with open('data/Data_Set_S1.txt', 'r') as f:
    reader = csv.reader(f, dialect='excel-tab')
    for row in reader:
        if len(row) == 8 and row[0] != "word": # skipping the first lines
            sentiments[row[0].lower()] = float(row[2]) # storing the average sentiment

# %%
# Function to calculate the average sentiment for each characters 
def sentiment(freqdist,cut_off=False):
    sentim_words = [w for w in freqdist.keys() if sentiments.get(w)] # get all word that are in sentiment list
    sentim_values = [sentiments[val]*freqdist[val] for val in sentim_words] # get the value and multiplay by frequency
    sentim_words_freq = sum([freqdist[w] for w in sentim_words]) # total occurances of all valid sentim words
    if cut_off:
        if sentim_words_freq > cut_off: # only take in words that have certin frequency of sentimental words
            return sum(sentim_values) / sentim_words_freq
        else: 
            return None
    else:
        if len(sentim_words) > 0:
            return sum(sentim_values) / sentim_words_freq
        else: 
            return None

# %%
# Get average sentiment for all sentences of character
char_sentiment = {}
for char in char_sentences:
    sentiment_for_char = sentiment(nltk.FreqDist(char_sentences[char]))
    if sentiment_for_char:
        char_sentiment[char] = sentiment_for_char
        
# Get average sentiment for all sentences of character
movie_sentiment = {}
for movie in movie_sentences:
    sentiment_for_movie = sentiment(nltk.FreqDist(movie_sentences[movie]))
    if sentiment_for_movie:
        movie_sentiment[movie] = sentiment_for_movie

# %%
# Function to calculate the sentiment of tokenized list
def token_getsent(text):
    #lets toxenize the text 
    tokens = nltk.word_tokenize(text)
    words = [w.lower() for w in tokens if w.isalpha()]
    lem_words = [wnl.lemmatize(w) for w in words if w not in stopwords]
    
    # Get the sentiment score
    return(sentiment(nltk.FreqDist(lem_words)))
    

# Add the sentiment for all scenes and sentences
df['sentence_sent'] = df.apply(lambda x: token_getsent(x['sentence']),axis=1)
df['scene_desc_sent'] = df.apply(lambda x: token_getsent(x['sentence']),axis=1)

# lets add the average sentence sentiment for each scene_id
df['avg_scene_sent'] = df.groupby(['scene_id'])['sentence_sent'].transform('mean')
df['avg_scene_desc_sent'] = df.groupby(['scene_id'])['scene_desc_sent'].transform('mean')

# %%
#Create a histogram of all character's associated page-sentiments.
import numpy as np 

plt.figure(figsize=(16,9))
plt.hist(char_sentiment.values(),bins=200)
sent_mean = np.mean((list(char_sentiment.values())))
plt.axvline(x=sent_mean, label=f'Mean={sent_mean}', c='red')
plt.legend()
plt.title('Sentiment distribution for all pages')
plt.ylabel('count')
plt.xlabel('Sentimental Score')

plt.show()

# %% [markdown]
# Now we only want to look at characters that have certain amount of sentences or words that actually compount to a meaninful sentiment analysis. To do this the limit of words needed is set to be 25, that is 25 words that have a sentiment rating needs to be said by a character to be considered in the following sentiment analysis.

# %%
# Top 10 worst and highest sentiment characters
char_list = sorted(char_sentiment, key=char_sentiment.get, reverse=False)[:10]
# Out:
# ['Waltress',
#  'Disheveled Wizard',
#  'Alastor',
#  'Lily Evans',
#  'Mrs Black',
#  'Centaur #2',
#  'Oiiver',
#  'Crucio!',
#  'Young Wizard',
#  'Action - Night']

# %%
sorted(char_sentiment, key=char_sentiment.get, reverse=True)[:10]
# Out:
# ['Snake',
#  'Justin-Finch-Fletchley',
#  'Charity',
#  'Skinny Wizard',
#  'Ron Harry',
#  'Narcissa Malfoy',
#  'Class',
#  'Closeup - Quaffle',
#  'Riddle-—Harry',
#  'Grawp']

# %% [markdown]
# ## General statistics about the script data set:

# %% [markdown]
# ### Creating count for various properties of the scripts

# %%
# Sentence count, that is the highset sentence number for each movie
sentence_count = []
for movie in df.movie_nr.unique():
    sentence_count.append(df.sentence_number[df.movie_nr == movie].max())
sentence_count

# Scene count
scene_count = []
for movie in df.movie_nr.unique():
    scene_count.append(df.scene_id[df.movie_nr == movie].max())
scene_count

# Character count
character_count = []
for movie in df.movie_nr.unique():
    character_count.append(len(df.character[df.movie_nr == movie].unique()))
character_count
# Out:
# [44, 56, 59, 58, 116, 56, 86, 76]

# %%
movie_sentiment.values()
# Out:
# dict_values([5.540098146128683, 5.472972222222221, 5.484966648137855, 5.5837273276904344, 5.486311643835612, 5.587887921411033, 5.506553549939833, 5.4650853548966785])

# %%
fig, axes = plt.subplots(2, 2, sharex=True, figsize=(20,10), gridspec_kw={'hspace': 0.1})

palette = itertools.cycle(sns.color_palette())

axes[0][0].bar(move_titles_short, sentence_count, width = 0.8, color=next(palette))
axes[0][0].set_title('Number of sentences', fontsize=16)
axes[0][0].set_ylabel('Count', fontsize=16)

axes[1][0].bar(move_titles_short, character_count, width = 0.8, color=next(palette))
axes[1][0].set_title('Number of characters', fontsize=16)
axes[1][0].set_ylabel('Count', fontsize=16)

axes[0][1].bar(move_titles_short, scene_count, width = 0.8, color=next(palette))
axes[0][1].set_title('Number of scenes', fontsize=16)
axes[0][1].set_ylabel('Count', fontsize=16)

axes[1][1].bar(move_titles_short, movie_sentiment.values(), width = 0.8, color=next(palette))
axes[1][1].set_title('Movie sentiment', fontsize=16)
axes[1][1].set_ylabel('Sentiment', fontsize=16)

# Set the rotation and horizontal alignment of the x tick labels
plt.setp(axes[1][0].get_xticklabels(), rotation=45, ha="right", fontsize=16);
plt.setp(axes[1][1].get_xticklabels(), rotation=45, ha="right", fontsize=16);

# Set plot title
plt.suptitle('General statistics of the Harry Potter scripts', fontsize=24, y = 0.95);

# %%
# Look at the top speaking characters and plot the total sentence count 
names = df['character'].value_counts()[:50].index
value = df['character'].value_counts()[:50]
# # Preparing figure
plt.figure(figsize=(15,10))

plt.bar(names,value,width=0.8)
plt.xlabel('Character')
plt.ylabel('Scripted line count')
plt.xticks(rotation=80)
plt.show()

# %%
#  Top 10 characters in each movie

#  TODO Create subplot with 7 figures and top 10 characters and their sentence count

# %% [markdown]
# # Create character connections based on how many times they in the same scene in the movies

# %%
# lets create connection between characters 

# for movie in df.movie_nr:
# movie = 1
# df_names = df['character'].unique()
# df_store = df[df.movie_nr == movie].groupby(['scene_id','movie_nr'])['character'].unique()

scene_interactions = dict()
for movie in df.movie_nr.unique():
    df_store = df[df.movie_nr == movie].groupby(['scene_id'])['character'].unique()
    for scene in df_store:
        for idx in range(len(scene)-1):
            for idx2 in range(idx+1,len(scene)):
                if (scene[idx],scene[idx2]) in scene_interactions:
                    scene_interactions[(scene[idx],scene[idx2])] += 1
                else:
                    if (scene[idx2],scene[idx]) in scene_interactions:
                        scene_interactions[(scene[idx2],scene[idx])] += 1
                    else:
                        scene_interactions[(scene[idx],scene[idx2])] = 1
scene_interactions
# Out:
# {('albus dumbledore', 'mcgonagall'): 5,
#  ('albus dumbledore', 'hagrid'): 8,
#  ('albus dumbledore', 'petunia'): 1,
#  ('albus dumbledore', 'dudley'): 1,
#  ('albus dumbledore', 'vernon'): 1,
#  ('albus dumbledore', 'harry potter'): 51,
#  ('mcgonagall', 'hagrid'): 2,
#  ('mcgonagall', 'petunia'): 1,
#  ('mcgonagall', 'dudley'): 1,
#  ('mcgonagall', 'vernon'): 1,
#  ('mcgonagall', 'harry potter'): 19,
#  ('hagrid', 'petunia'): 2,
#  ('hagrid', 'dudley'): 2,
#  ('hagrid', 'vernon'): 2,
#  ('hagrid', 'harry potter'): 46,
#  ('petunia', 'dudley'): 4,
#  ('petunia', 'vernon'): 7,
#  ('petunia', 'harry potter'): 5,
#  ('dudley', 'vernon'): 6,
#  ('dudley', 'harry potter'): 9,
#  ('vernon', 'harry potter'): 7,
#  ('dudley', 'snake'): 1,
#  ('dudley', 'man'): 1,
#  ('vernon', 'snake'): 1,
#  ('vernon', 'man'): 1,
#  ('harry potter', 'snake'): 1,
#  ('harry potter', 'man'): 7,
#  ('snake', 'man'): 1,
#  ('snake', 'petunia'): 1,
#  ('man', 'petunia'): 1,
#  ('harry potter', 'all'): 4,
#  ('vernon', 'all'): 1,
#  ('hagrid', 'all'): 3,
#  ('petunia', 'all'): 1,
#  ('all', 'dudley'): 1,
#  ('harry potter', 'tom'): 2,
#  ('harry potter', 'witch'): 1,
#  ('harry potter', 'quirrell'): 5,
#  ('harry potter', 'boy'): 5,
#  ('harry potter', 'goblin'): 1,
#  ('hagrid', 'tom'): 1,
#  ('hagrid', 'man'): 2,
#  ('hagrid', 'witch'): 1,
#  ('hagrid', 'quirrell'): 1,
#  ('hagrid', 'boy'): 1,
#  ('hagrid', 'goblin'): 1,
#  ('tom', 'man'): 1,
#  ('tom', 'witch'): 1,
#  ('tom', 'quirrell'): 1,
#  ('tom', 'boy'): 1,
#  ('tom', 'goblin'): 1,
#  ('man', 'witch'): 1,
#  ('man', 'quirrell'): 2,
#  ('man', 'boy'): 1,
#  ('man', 'goblin'): 1,
#  ('witch', 'quirrell'): 1,
#  ('witch', 'boy'): 1,
#  ('witch', 'goblin'): 1,
#  ('quirrell', 'boy'): 2,
#  ('quirrell', 'goblin'): 1,
#  ('boy', 'goblin'): 1,
#  ('griphook', 'hagrid'): 1,
#  ('griphook', 'harry potter'): 8,
#  ('harry potter', 'ollivander'): 3,
#  ('hagrid', 'ollivander'): 1,
#  ('man', 'trainmaster'): 1,
#  ('man', 'george'): 2,
#  ('man', 'fred'): 2,
#  ('harry potter', 'trainmaster'): 1,
#  ('harry potter', 'george'): 23,
#  ('harry potter', 'fred'): 25,
#  ('trainmaster', 'george'): 1,
#  ('trainmaster', 'fred'): 1,
#  ('george', 'fred'): 27,
#  ('ron', 'harry potter'): 233,
#  ('ron', 'woman'): 1,
#  ('harry potter', 'woman'): 3,
#  ('harry potter', 'frog'): 1,
#  ('harry potter', 'hermione'): 213,
#  ('ron', 'frog'): 1,
#  ('ron', 'hermione'): 181,
#  ('frog', 'hermione'): 1,
#  ('hagrid', 'ron'): 22,
#  ('mcgonagall', 'neville'): 2,
#  ('mcgonagall', 'draco'): 6,
#  ('mcgonagall', 'hermione'): 6,
#  ('mcgonagall', 'ron'): 10,
#  ('mcgonagall', 'seamus'): 1,
#  ('mcgonagall', 'percy'): 1,
#  ('mcgonagall', 'nick'): 1,
#  ('mcgonagall', 'girl'): 2,
#  ('neville', 'draco'): 6,
#  ('neville', 'harry potter'): 35,
#  ('neville', 'hermione'): 27,
#  ('neville', 'albus dumbledore'): 4,
#  ('neville', 'ron'): 29,
#  ('neville', 'seamus'): 20,
#  ('neville', 'percy'): 3,
#  ('neville', 'nick'): 1,
#  ('neville', 'girl'): 4,
#  ('draco', 'harry potter'): 23,
#  ('draco', 'hermione'): 20,
#  ('draco', 'albus dumbledore'): 3,
#  ('draco', 'ron'): 22,
#  ('draco', 'seamus'): 6,
#  ('draco', 'percy'): 2,
#  ('draco', 'nick'): 1,
#  ('draco', 'girl'): 2,
#  ('harry potter', 'seamus'): 15,
#  ('harry potter', 'percy'): 6,
#  ('harry potter', 'nick'): 2,
#  ('harry potter', 'girl'): 5,
#  ('hermione', 'albus dumbledore'): 16,
#  ('hermione', 'seamus'): 13,
#  ('hermione', 'percy'): 1,
#  ('hermione', 'nick'): 2,
#  ('hermione', 'girl'): 3,
#  ('albus dumbledore', 'ron'): 16,
#  ('albus dumbledore', 'seamus'): 2,
#  ('albus dumbledore', 'percy'): 3,
#  ('albus dumbledore', 'nick'): 1,
#  ('albus dumbledore', 'girl'): 2,
#  ('ron', 'seamus'): 16,
#  ('ron', 'percy'): 7,
#  ('ron', 'nick'): 2,
#  ('ron', 'girl'): 4,
#  ('seamus', 'percy'): 2,
#  ('seamus', 'nick'): 1,
#  ('seamus', 'girl'): 1,
#  ('percy', 'nick'): 1,
#  ('percy', 'girl'): 3,
#  ('nick', 'girl'): 1,
#  ('percy', 'boy'): 1,
#  ('boy', 'neville'): 3,
#  ('boy', 'ron'): 3,
#  ('boy', 'girl'): 3,
#  ('woman', 'percy'): 1,
#  ('woman', 'girl'): 1,
#  ('snape', 'harry potter'): 27,
#  ('hooch', 'class'): 1,
#  ('hooch', 'harry potter'): 3,
#  ('hooch', 'draco'): 3,
#  ('hooch', 'hermione'): 3,
#  ('hooch', 'ron'): 2,
#  ('hooch', 'neville'): 1,
#  ('hooch', 'girl'): 1,
#  ('hooch', 'students'): 1,
#  ('hooch', 'boy'): 1,
#  ('hooch', 'mcgonagall'): 3,
#  ('class', 'harry potter'): 1,
#  ('class', 'draco'): 1,
#  ('class', 'hermione'): 1,
#  ('class', 'ron'): 1,
#  ('class', 'neville'): 1,
#  ('class', 'girl'): 1,
#  ('class', 'students'): 1,
#  ('class', 'boy'): 1,
#  ('class', 'mcgonagall'): 1,
#  ('harry potter', 'students'): 2,
#  ('draco', 'students'): 3,
#  ('draco', 'boy'): 2,
#  ('hermione', 'students'): 3,
#  ('hermione', 'boy'): 1,
#  ('ron', 'students'): 2,
#  ('neville', 'students'): 2,
#  ('girl', 'students'): 1,
#  ('students', 'boy'): 1,
#  ('students', 'mcgonagall'): 1,
#  ('boy', 'mcgonagall'): 2,
#  ('quirrell', 'mcgonagall'): 2,
#  ('nick', 'fred'): 1,
#  ('nick', 'george'): 1,
#  ('ron', 'fred'): 22,
#  ('ron', 'george'): 19,
#  ('fred', 'hermione'): 16,
#  ('george', 'hermione'): 15,
#  ('ron', 'filch'): 4,
#  ('ron', 'all'): 3,
#  ('harry potter', 'filch'): 9,
#  ('hermione', 'filch'): 5,
#  ('hermione', 'all'): 3,
#  ('filch', 'all'): 1,
#  ('oliver', 'harry potter'): 2,
#  ('flitwick', 'draco'): 1,
#  ('flitwick', 'ron'): 3,
#  ('flitwick', 'hermione'): 3,
#  ('flitwick', 'seamus'): 2,
#  ('flitwick', 'harry potter'): 3,
#  ('neville', 'quirrell'): 1,
#  ('quirrell', 'albus dumbledore'): 1,
#  ('quirrell', 'girl'): 1,
#  ('albus dumbledore', 'boy'): 1,
#  ('hermione', 'quirrell'): 1,
#  ('ron', 'quirrell'): 1,
#  ('ron', 'snape'): 10,
#  ('hermione', 'snape'): 10,
#  ('oiiver', 'harry potter'): 1,
#  ('oiiver', 'oliver'): 1,
#  ('oiiver', 'lee'): 1,
#  ('oiiver', 'hooch'): 1,
#  ('oiiver', 'hagrid'): 1,
#  ('oiiver', 'gryffindors'): 1,
#  ('oiiver', 'flint'): 1,
#  ('oiiver', 'crowd'): 1,
#  ('oiiver', 'hermione'): 1,
#  ('oiiver', 'ron'): 1,
#  ('oiiver', 'man'): 1,
#  ('oiiver', 'snape'): 1,
#  ('oiiver', 'all'): 1,
#  ('oiiver', 'draco'): 1,
#  ('oiiver', 'mcgonagall'): 1,
#  ('harry potter', 'lee'): 2,
#  ('harry potter', 'gryffindors'): 1,
#  ('harry potter', 'flint'): 2,
#  ('harry potter', 'crowd'): 2,
#  ('oliver', 'lee'): 1,
#  ('oliver', 'hooch'): 1,
#  ('oliver', 'hagrid'): 1,
#  ('oliver', 'gryffindors'): 1,
#  ('oliver', 'flint'): 1,
#  ('oliver', 'crowd'): 1,
#  ('oliver', 'hermione'): 1,
#  ('oliver', 'ron'): 1,
#  ('oliver', 'man'): 1,
#  ('oliver', 'snape'): 1,
#  ('oliver', 'all'): 1,
#  ('oliver', 'draco'): 1,
#  ('oliver', 'mcgonagall'): 1,
#  ('lee', 'hooch'): 1,
#  ('lee', 'hagrid'): 2,
#  ('lee', 'gryffindors'): 1,
#  ('lee', 'flint'): 1,
#  ('lee', 'crowd'): 1,
#  ('lee', 'hermione'): 2,
#  ('lee', 'ron'): 1,
#  ('lee', 'man'): 1,
#  ('lee', 'snape'): 1,
#  ('lee', 'all'): 1,
#  ('lee', 'draco'): 2,
#  ('lee', 'mcgonagall'): 1,
#  ('hooch', 'hagrid'): 1,
#  ('hooch', 'gryffindors'): 1,
#  ('hooch', 'flint'): 1,
#  ('hooch', 'crowd'): 1,
#  ('hooch', 'man'): 1,
#  ('hooch', 'snape'): 1,
#  ('hooch', 'all'): 1,
#  ('hagrid', 'gryffindors'): 1,
#  ('hagrid', 'flint'): 1,
#  ('hagrid', 'crowd'): 1,
#  ('hagrid', 'hermione'): 25,
#  ('hagrid', 'snape'): 2,
#  ('hagrid', 'draco'): 8,
#  ('gryffindors', 'flint'): 1,
#  ('gryffindors', 'crowd'): 1,
#  ('gryffindors', 'hermione'): 1,
#  ('gryffindors', 'ron'): 1,
#  ('gryffindors', 'man'): 1,
#  ('gryffindors', 'snape'): 1,
#  ('gryffindors', 'all'): 1,
#  ('gryffindors', 'draco'): 1,
#  ('gryffindors', 'mcgonagall'): 1,
#  ('flint', 'crowd'): 1,
#  ('flint', 'hermione'): 2,
#  ('flint', 'ron'): 2,
#  ('flint', 'man'): 1,
#  ('flint', 'snape'): 1,
#  ('flint', 'all'): 1,
#  ('flint', 'draco'): 2,
#  ('flint', 'mcgonagall'): 1,
#  ('crowd', 'hermione'): 2,
#  ('crowd', 'ron'): 1,
#  ('crowd', 'man'): 1,
#  ('crowd', 'snape'): 1,
#  ('crowd', 'all'): 1,
#  ('crowd', 'draco'): 1,
#  ('crowd', 'mcgonagall'): 1,
#  ('hermione', 'man'): 2,
#  ('ron', 'man'): 2,
#  ('man', 'snape'): 2,
#  ('man', 'all'): 1,
#  ('man', 'draco'): 1,
#  ('man', 'mcgonagall'): 1,
#  ('snape', 'all'): 1,
#  ('snape', 'draco'): 4,
#  ('snape', 'mcgonagall'): 2,
#  ('all', 'draco'): 1,
#  ('all', 'mcgonagall'): 1,
#  ('man', 'filch'): 1,
#  ('quirrell', 'snape'): 1,
#  ('quirrell', 'filch'): 1,
#  ('snape', 'filch'): 5,
#  ('filch', 'hagrid'): 1,
#  ('filch', 'draco'): 2,
#  ('harry potter', 'firenze'): 1,
#  ('draco', 'firenze'): 1,
#  ('firenze', 'hermione'): 1,
#  ('firenze', 'hagrid'): 1,
#  ('harry potter', 'voldemort'): 13,
#  ('quirrell', 'voldemort'): 1,
#  ('albus dumbledore', 'students'): 1,
#  ('albus dumbledore', 'lee'): 1,
#  ('students', 'hagrid'): 1,
#  ('students', 'seamus'): 2,
#  ('students', 'lee'): 1,
#  ('hagrid', 'seamus'): 2,
#  ('seamus', 'lee'): 1,
#  ('harry potter', 'uncle vernon'): 11,
#  ('uncle vernon', 'dudley'): 3,
#  ('uncle vernon', 'aunt petunia'): 3,
#  ('harry potter', 'aunt petunia'): 4,
#  ('dudley', 'aunt petunia'): 1,
#  ('dobby', 'harry potter'): 12,
#  ('uncle vernon', 'mr. mason'): 1,
#  ('uncle vernon', 'dobby'): 2,
#  ('dudley', 'ron'): 1,
#  ('harry potter', "closeup - harry's trunk 13b"): 1,
#  ('harry potter', "insert - fred's foot 13c"): 1,
#  ('ron', "closeup - harry's trunk 13b"): 1,
#  ('ron', "insert - fred's foot 13c"): 1,
#  ("closeup - harry's trunk 13b", "insert - fred's foot 13c"): 1,
#  ('uncle vernon', 'ron'): 1,
#  ('ron', 'mrs. weasley'): 9,
#  ('ron', 'ginny'): 23,
#  ('ron', 'mr. weasley'): 2,
#  ('harry potter', 'mrs. weasley'): 13,
#  ('harry potter', 'ginny'): 29,
#  ('harry potter', 'mr. weasley'): 9,
#  ('mrs. weasley', 'ginny'): 9,
#  ('mrs. weasley', 'george'): 3,
#  ('mrs. weasley', 'mr. weasley'): 4,
#  ('mrs. weasley', 'fred'): 3,
#  ('ginny', 'george'): 7,
#  ('ginny', 'mr. weasley'): 2,
#  ('ginny', 'fred'): 7,
#  ('george', 'mr. weasley'): 2,
#  ('mr. weasley', 'fred'): 2,
#  ('mrs. weasley', 'percy'): 1,
#  ('mr. borgin', 'lucius malfoy'): 1,
#  ('mr. borgin', 'draco'): 1,
#  ('lucius malfoy', 'draco'): 3,
#  ('aged witch', 'harry potter'): 1,
#  ('aged witch', 'hagrid'): 1,
#  ('hagrid', 'mr. weasley'): 2,
#  ('hagrid', 'mrs. weasley'): 4,
#  ('hermione', 'mr. weasley'): 2,
#  ('hermione', 'mrs. weasley'): 6,
#  ('mrs. weasley', 'short man'): 1,
#  ('mrs. weasley', 'gilderoy lockhart'): 1,
#  ('mrs. weasley', 'draco'): 1,
#  ('mrs. weasley', 'lucius malfoy'): 2,
#  ('ron', 'short man'): 1,
#  ('ron', 'gilderoy lockhart'): 9,
#  ('ron', 'lucius malfoy'): 5,
#  ('short man', 'gilderoy lockhart'): 1,
#  ('short man', 'harry potter'): 1,
#  ('short man', 'draco'): 1,
#  ('short man', 'ginny'): 1,
#  ('short man', 'lucius malfoy'): 1,
#  ('short man', 'hermione'): 1,
#  ('short man', 'mr. weasley'): 1,
#  ('short man', 'hagrid'): 1,
#  ('gilderoy lockhart', 'harry potter'): 10,
#  ('gilderoy lockhart', 'draco'): 4,
#  ('gilderoy lockhart', 'ginny'): 2,
#  ('gilderoy lockhart', 'lucius malfoy'): 1,
#  ('gilderoy lockhart', 'hermione'): 5,
#  ('gilderoy lockhart', 'mr. weasley'): 1,
#  ('gilderoy lockhart', 'hagrid'): 2,
#  ('harry potter', 'lucius malfoy'): 5,
#  ('draco', 'ginny'): 2,
#  ('draco', 'mr. weasley'): 1,
#  ('ginny', 'lucius malfoy'): 3,
#  ('ginny', 'hermione'): 16,
#  ('ginny', 'hagrid'): 3,
#  ('lucius malfoy', 'hermione'): 2,
#  ('lucius malfoy', 'mr. weasley'): 1,
#  ('lucius malfoy', 'hagrid'): 3,
#  ('ron', 'guard'): 1,
#  ('guard', 'harry potter'): 1,
#  ('snape', 'albus dumbledore'): 11,
#  ('neville', 'professor sprout'): 1,
#  ('seamus', 'professor sprout'): 1,
#  ('hermione', 'professor sprout'): 1,
#  ('ron', 'professor sprout'): 1,
#  ('penelope clearwater', 'percy'): 1,
#  ('penelope clearwater', 'nearly headless nick'): 1,
#  ('penelope clearwater', 'ron'): 1,
#  ('penelope clearwater', 'harry potter'): 1,
#  ('penelope clearwater', 'colin'): 1,
#  ('penelope clearwater', 'dean thomas'): 1,
#  ('penelope clearwater', 'seamus'): 1,
#  ('penelope clearwater', 'neville'): 1,
#  ('penelope clearwater', "at work and it's entirely your"): 1,
#  ('penelope clearwater', "of line we'll bring you straight"): 1,
#  ('percy', 'nearly headless nick'): 1,
#  ('percy', 'colin'): 1,
#  ('percy', 'dean thomas'): 1,
#  ('percy', "at work and it's entirely your"): 1,
#  ('percy', "of line we'll bring you straight"): 1,
#  ('nearly headless nick', 'ron'): 1,
#  ('nearly headless nick', 'harry potter'): 1,
#  ('nearly headless nick', 'colin'): 1,
#  ('nearly headless nick', 'dean thomas'): 1,
#  ('nearly headless nick', 'seamus'): 1,
#  ('nearly headless nick', 'neville'): 1,
#  ('nearly headless nick', "at work and it's entirely your"): 1,
#  ('nearly headless nick', "of line we'll bring you straight"): 1,
#  ('ron', 'colin'): 2,
#  ('ron', 'dean thomas'): 5,
#  ('ron', "at work and it's entirely your"): 1,
#  ('ron', "of line we'll bring you straight"): 1,
#  ('harry potter', 'colin'): 3,
#  ('harry potter', 'dean thomas'): 2,
#  ('harry potter', "at work and it's entirely your"): 1,
#  ('harry potter', "of line we'll bring you straight"): 1,
#  ('colin', 'dean thomas'): 1,
#  ('colin', 'seamus'): 1,
#  ('colin', 'neville'): 1,
#  ('colin', "at work and it's entirely your"): 1,
#  ('colin', "of line we'll bring you straight"): 1,
#  ('dean thomas', 'seamus'): 5,
#  ('dean thomas', 'neville'): 5,
#  ('dean thomas', "at work and it's entirely your"): 1,
#  ('dean thomas', "of line we'll bring you straight"): 1,
#  ('seamus', "at work and it's entirely your"): 1,
#  ('seamus', "of line we'll bring you straight"): 1,
#  ('neville', "at work and it's entirely your"): 1,
#  ('neville', "of line we'll bring you straight"): 1,
#  ("at work and it's entirely your", "of line we'll bring you straight"): 1,
#  ('gilderoy lockhart', 'dissolve'): 1,
#  ('gilderoy lockhart', 'seamus'): 1,
#  ('gilderoy lockhart', 'neville'): 1,
#  ('ron', 'dissolve'): 2,
#  ('harry potter', 'dissolve'): 4,
#  ('dissolve', 'seamus'): 1,
#  ('dissolve', 'hermione'): 2,
#  ('dissolve', 'neville'): 1,
#  ('wood', 'ron'): 2,
#  ('wood', 'flint'): 1,
#  ('wood', 'harry potter'): 2,
#  ('wood', 'draco'): 1,
#  ('wood', 'hermione'): 2,
#  ('wood', 'colin'): 1,
#  ('flint', 'colin'): 1,
#  ('draco', 'colin'): 1,
#  ('hermione', 'colin'): 2,
#  ('gilderoy lockhart', 'voice'): 1,
#  ('voice', 'harry potter'): 7,
#  ('voice', 'hermione'): 4,
#  ('voice', 'ron'): 3,
#  ('ron', 'the chamber of secrets has been opened'): 1,
#  ('the chamber of secrets has been opened', 'hermione'): 1,
#  ('the chamber of secrets has been opened', 'harry potter'): 1,
#  ('the chamber of secrets has been opened', 'draco'): 1,
#  ('the chamber of secrets has been opened', 'filch'): 1,
#  ('the chamber of secrets has been opened', 'albus dumbledore'): 1,
#  ('the chamber of secrets has been opened', 'gilderoy lockhart'): 1,
#  ('the chamber of secrets has been opened', 'snape'): 1,
#  ('filch', 'albus dumbledore'): 3,
#  ('filch', 'gilderoy lockhart'): 1,
#  ('albus dumbledore', 'gilderoy lockhart'): 1,
#  ('gilderoy lockhart', 'snape'): 3,
#  ('hagrid', 'george'): 4,
#  ('draco', 'george'): 2,
#  ('george', 'gilderoy lockhart'): 1,
#  ('madam pomfrey', 'hermione'): 1,
#  ('madam pomfrey', 'colin'): 1,
#  ('madam pomfrey', 'back to scene'): 1,
#  ('madam pomfrey', 'harry potter'): 2,
#  ('madam pomfrey', 'dobby'): 1,
#  ('madam pomfrey', 'albus dumbledore'): 1,
#  ('hermione', 'back to scene'): 2,
#  ('hermione', 'dobby'): 4,
#  ('colin', 'back to scene'): 1,
#  ('colin', 'dobby'): 1,
#  ('colin', 'albus dumbledore'): 1,
#  ('back to scene', 'harry potter'): 3,
#  ('back to scene', 'dobby'): 1,
#  ('back to scene', 'albus dumbledore'): 1,
#  ('dobby', 'albus dumbledore'): 2,
#  ('hermione', 'young girl comes racing out of the wall. face to face'): 1,
#  ('hermione', 'moaning myrtle'): 2,
#  ('ron', 'young girl comes racing out of the wall. face to face'): 1,
#  ('ron', 'moaning myrtle'): 4,
#  ('young girl comes racing out of the wall. face to face',
#   'moaning myrtle'): 1,
#  ('gilderoy lockhart', 'justin finch-fletchley'): 1,
#  ('gilderoy lockhart', 'justin-finch-fletchley'): 1,
#  ('justin finch-fletchley', 'harry potter'): 1,
#  ('justin finch-fletchley', 'ron'): 1,
#  ('justin finch-fletchley', 'snape'): 1,
#  ('justin finch-fletchley', 'hermione'): 1,
#  ('justin finch-fletchley', 'draco'): 1,
#  ('justin finch-fletchley', 'justin-finch-fletchley'): 1,
#  ('harry potter', 'justin-finch-fletchley'): 1,
#  ('ron', 'justin-finch-fletchley'): 1,
#  ('snape', 'justin-finch-fletchley'): 1,
#  ('hermione', 'justin-finch-fletchley'): 1,
#  ('draco', 'justin-finch-fletchley'): 1,
#  ('ernie', 'hannah'): 1,
#  ('sorting hat', 'harry potter'): 1,
#  ('sorting hat', 'albus dumbledore'): 1,
#  ('sorting hat', 'hagrid'): 1,
#  ('hermione', 'closeup - the potion'): 1,
#  ('ron', 'closeup - the potion'): 1,
#  ('closeup - the potion', 'harry potter'): 1,
#  ('harry potter', 'moaning myrtle'): 3,
#  ('voice', 'voldemort'): 2,
#  ('voice', 'albus dumbledore'): 2,
#  ('voldemort', 'albus dumbledore'): 3,
#  ('voice', 'young hagrid'): 1,
#  ('voldemort', 'young hagrid'): 1,
#  ('hagrid', 'neville'): 2,
#  ('voice', 'wood'): 1,
#  ('voice', 'george'): 1,
#  ('wood', 'george'): 1,
#  ('harry potter', 'fudge'): 7,
#  ('hagrid', 'fudge'): 1,
#  ('albus dumbledore', 'fudge'): 6,
#  ('albus dumbledore', 'lucius malfoy'): 3,
#  ('ron', 'fudge'): 1,
#  ('fudge', 'lucius malfoy'): 1,
#  ('ron', 'aragog'): 1,
#  ('harry potter', 'aragog'): 1,
#  ('madam pomfrey', 'ron'): 1,
#  ('gilderoy lockhart', 'professor sprout'): 1,
#  ('snape', 'professor sprout'): 1,
#  ('moaning myrtle', 'gilderoy lockhart'): 1,
#  ('voldemort', 'ginny'): 2,
#  ('albus dumbledore', 'ginny'): 6,
#  ('albus dumbledore', 'mrs. weasley'): 1,
#  ('harry potter', 'lucious malfoy'): 1,
#  ('lucius malfoy', 'lucious malfoy'): 1,
#  ('lucius malfoy', 'dobby'): 1,
#  ('lucious malfoy', 'dobby'): 1,
#  ('lucious malfoy', 'hermione'): 1,
#  ('lucious malfoy', 'ron'): 1,
#  ('lucious malfoy', 'albus dumbledore'): 1,
#  ('lucious malfoy', 'hagrid'): 1,
#  ('dobby', 'ron'): 4,
#  ('dobby', 'hagrid'): 1,
#  ('aunt petunia', 'aunt marge'): 2,
#  ('aunt marge', 'harry potter'): 2,
#  ('aunt marge', 'uncle vernon'): 3,
#  ('harry potter', 'stan shunpike'): 2,
#  ('disheveled wizard', 'stan shunpike'): 1,
#  ('disheveled wizard', 'shrunken head'): 1,
#  ('disheveled wizard', 'harry potter'): 1,
#  ('stan shunpike', 'shrunken head'): 1,
#  ('shrunken head', 'harry potter'): 1,
#  ('harry potter', 'cornelius fudge'): 3,
#  ('tom', 'cornelius fudge'): 1,
#  ('ron', 'closeup - a dog-eared clipping'): 1,
#  ('hermione', 'closeup - a dog-eared clipping'): 1,
#  ('harry potter', 'arthur weasley'): 5,
#  ('ron', 'arthur weasley'): 6,
#  ('hermione', 'arthur weasley'): 2,
#  ('george', 'arthur weasley'): 3,
#  ('fred', 'arthur weasley'): 3,
#  ('mrs. weasley', 'arthur weasley'): 2,
#  ('arthur weasley', 'ginny'): 3,
#  ('ron', 'professor lupin'): 4,
#  ('harry potter', 'professor lupin'): 9,
#  ('hermione', 'professor lupin'): 4,
#  ('professor trelawney', 'hermione'): 2,
#  ('professor trelawney', 'ron'): 1,
#  ('professor trelawney', 'neville'): 1,
#  ('professor trelawney', 'teacup - detail - later'): 1,
#  ('professor trelawney', 'parvati'): 1,
#  ('professor trelawney', 'seamus'): 1,
#  ('professor trelawney', 'dean thomas'): 1,
#  ('professor trelawney', 'lavender'): 2,
#  ('hermione', 'teacup - detail - later'): 1,
#  ('hermione', 'parvati'): 3,
#  ('hermione', 'dean thomas'): 2,
#  ('hermione', 'lavender'): 3,
#  ('ron', 'teacup - detail - later'): 1,
#  ('ron', 'parvati'): 3,
#  ('ron', 'lavender'): 2,
#  ('neville', 'teacup - detail - later'): 1,
#  ('neville', 'parvati'): 2,
#  ('neville', 'lavender'): 2,
#  ('teacup - detail - later', 'parvati'): 1,
#  ('teacup - detail - later', 'seamus'): 1,
#  ('teacup - detail - later', 'dean thomas'): 1,
#  ('teacup - detail - later', 'lavender'): 1,
#  ('parvati', 'seamus'): 2,
#  ('parvati', 'dean thomas'): 2,
#  ('parvati', 'lavender'): 1,
#  ('seamus', 'lavender'): 2,
#  ('dean thomas', 'lavender'): 1,
#  ('pansy', 'draco'): 1,
#  ('pansy', 'ron'): 1,
#  ('pansy', 'harry potter'): 1,
#  ('pansy', 'hermione'): 1,
#  ('pansy', 'seamus'): 1,
#  ('pansy', 'neville'): 1,
#  ('pansy', 'lavender'): 1,
#  ('pansy', 'lavendar'): 1,
#  ('pansy', 'bem'): 1,
#  ('draco', 'lavender'): 1,
#  ('draco', 'lavendar'): 1,
#  ('draco', 'bem'): 1,
#  ('ron', 'lavendar'): 1,
#  ('ron', 'bem'): 1,
#  ('harry potter', 'lavender'): 1,
#  ('harry potter', 'lavendar'): 1,
#  ('harry potter', 'bem'): 1,
#  ('hermione', 'lavendar'): 1,
#  ('hermione', 'bem'): 1,
#  ('seamus', 'lavendar'): 1,
#  ('seamus', 'bem'): 1,
#  ('neville', 'lavendar'): 1,
#  ('neville', 'bem'): 1,
#  ('lavender', 'lavendar'): 1,
#  ('lavender', 'bem'): 1,
#  ('lavendar', 'bem'): 1,
#  ('bem,', 'professor lupin'): 1,
#  ('bem,', 'seamus'): 1,
#  ('bem,', 'hermione'): 1,
#  ('bem,', 'ron'): 1,
#  ('bem,', 'students'): 1,
#  ('bem,', 'draco'): 1,
#  ('bem,', 'neville'): 1,
#  ('bem,', 'parvati'): 1,
#  ('bem,', 'dean thomas'): 1,
#  ('professor lupin', 'seamus'): 1,
#  ('professor lupin', 'students'): 1,
#  ('professor lupin', 'draco'): 1,
#  ('professor lupin', 'neville'): 1,
#  ('professor lupin', 'parvati'): 1,
#  ('professor lupin', 'dean thomas'): 1,
#  ('students', 'parvati'): 1,
#  ('students', 'dean thomas'): 1,
#  ('draco', 'parvati'): 1,
#  ('draco', 'dean thomas'): 1,
#  ('ron', 'fat lady'): 1,
#  ('ron', 'montage - securing the castle - night 58'): 1,
#  ('percy', 'ginny'): 1,
#  ('percy', 'filch'): 1,
#  ('percy', 'fat lady'): 1,
#  ('percy', 'montage - securing the castle - night 58'): 1,
#  ('ginny', 'filch'): 2,
#  ('ginny', 'fat lady'): 1,
#  ('ginny', 'montage - securing the castle - night 58'): 1,
#  ('albus dumbledore', 'fat lady'): 1,
#  ('albus dumbledore', 'montage - securing the castle - night 58'): 1,
#  ('filch', 'fat lady'): 1,
#  ('filch', 'montage - securing the castle - night 58'): 1,
#  ('fat lady', 'montage - securing the castle - night 58'): 1,
#  ('snape', 'sir cadogan'): 1,
#  ('albus dumbledore', 'sir cadogan'): 2,
#  ('sir cadogan', 'seamus'): 1,
#  ('sir cadogan', 'dean thomas'): 1,
#  ('sir cadogan', 'neville'): 2,
#  ('sir cadogan', 'ron'): 2,
#  ("intercut harry's pov", 'in the stands'): 1,
#  ("intercut harry's pov", 'harry potter'): 1,
#  ("intercut harry's pov", 'hermione'): 1,
#  ("intercut harry's pov", 'ron'): 1,
#  ("intercut harry's pov", 'fred'): 1,
#  ("intercut harry's pov", 'george'): 1,
#  ('in the stands', 'harry potter'): 1,
#  ('in the stands', 'hermione'): 1,
#  ('in the stands', 'ron'): 1,
#  ('in the stands', 'fred'): 1,
#  ('in the stands', 'george'): 1,
#  ('fred', 'professor lupin'): 1,
#  ('harry potter', 'crates. huge rolling bins. a wood staircase. a'): 1,
#  ('crates. huge rolling bins. a wood staircase. a', 'woman'): 1,
#  ('ron', 'cornelius fudge'): 1,
#  ('ron', 'madam rosmerta'): 1,
#  ('hermione', 'cornelius fudge'): 2,
#  ('hermione', 'madam rosmerta'): 1,
#  ('cornelius fudge', 'madam rosmerta'): 2,
#  ('harry potter', 'madam rosmerta'): 1,
#  ('hermione', 'sir cadogan'): 1,
#  ('sir cadogan', 'harry potter'): 1,
#  ("insert - marauder's map", 'back to scene'): 1,
#  ("insert - marauder's map", 'himself'): 1,
#  ("insert - marauder's map", 'voice'): 1,
#  ("insert - marauder's map", 'harry potter'): 1,
#  ("insert - marauder's map", 'snape'): 1,
#  ("insert - marauder's map", 'professor lupin'): 1,
#  ("insert - marauder's map", 'closeup - crystal ball'): 1,
#  ('back to scene', 'himself'): 1,
#  ('back to scene', 'voice'): 1,
#  ('back to scene', 'snape'): 1,
#  ('back to scene', 'professor lupin'): 1,
#  ('back to scene', 'closeup - crystal ball'): 1,
#  ('himself', 'voice'): 1,
#  ('himself', 'harry potter'): 1,
#  ('himself', 'snape'): 1,
#  ('himself', 'professor lupin'): 1,
#  ('himself', 'closeup - crystal ball'): 1,
#  ('voice', 'snape'): 2,
#  ('voice', 'professor lupin'): 1,
#  ('voice', 'closeup - crystal ball'): 1,
#  ('harry potter', 'closeup - crystal ball'): 1,
#  ('snape', 'professor lupin'): 2,
#  ('snape', 'closeup - crystal ball'): 1,
#  ('professor lupin', 'closeup - crystal ball'): 1,
#  ('harry potter', 'professor trelawney'): 1,
#  ('afternoon', 'draco'): 1,
#  ('afternoon', 'hermione'): 3,
#  ('afternoon', 'ron'): 2,
#  ('hermione', "harry and hermione's pov - the branches overhead"): 1,
#  ('ron', "harry and hermione's pov - the branches overhead"): 1,
#  ('ron', 'back to scene'): 1,
#  ('harry potter', "harry and hermione's pov - the branches overhead"): 1,
#  ("harry and hermione's pov - the branches overhead", 'back to scene'): 1,
#  ('hermione', 'sirius black'): 3,
#  ('hermione', 'pettigrew'): 1,
#  ('harry potter', 'sirius black'): 3,
#  ('harry potter', 'pettigrew'): 1,
#  ('ron', 'sirius black'): 1,
#  ('ron', 'pettigrew'): 1,
#  ('sirius black', 'professor lupin'): 1,
#  ('sirius black', 'snape'): 1,
#  ('sirius black', 'pettigrew'): 1,
#  ('professor lupin', 'pettigrew'): 1,
#  ('snape', 'pettigrew'): 1,
#  ('afternoon', 'harry potter'): 2,
#  ('cornelius fudge', 'albus dumbledore'): 1,
#  ('cornelius fudge', 'hagrid'): 1,
#  ('seamus', 'fred'): 2,
#  ('seamus', 'george'): 2,
#  ('neville', 'fred'): 2,
#  ('neville', 'george'): 2,
#  ('fred', 'hagrid'): 3,
#  ('wormtail', 'voldemort'): 3,
#  ('wormtail', 'unknown man'): 1,
#  ('voldemort', 'unknown man'): 1,
#  ('hermione', 'arthur'): 2,
#  ('hermione', 'amos'): 1,
#  ('hermione', 'cedric'): 2,
#  ('harry potter', 'arthur'): 4,
#  ('harry potter', 'amos'): 2,
#  ('harry potter', 'cedric'): 5,
#  ('ron', 'arthur'): 3,
#  ('ron', 'amos'): 1,
#  ('ron', 'cedric'): 2,
#  ('arthur', 'amos'): 1,
#  ('arthur', 'cedric'): 1,
#  ('arthur', 'fred'): 3,
#  ('arthur', 'george'): 3,
#  ('amos', 'cedric'): 1,
#  ('amos', 'fred'): 1,
#  ('amos', 'george'): 1,
#  ('cedric', 'fred'): 1,
#  ('cedric', 'george'): 1,
#  ('arthur', 'twins'): 1,
#  ('twins', 'harry potter'): 2,
#  ('ron', 'lucius'): 2,
#  ('ron', 'weasleys'): 1,
#  ('lucius', 'draco'): 2,
#  ('lucius', 'arthur'): 1,
#  ('lucius', 'george'): 1,
#  ('lucius', 'fred'): 1,
#  ('lucius', 'weasleys'): 1,
#  ('draco', 'arthur'): 1,
#  ('draco', 'fred'): 1,
#  ('draco', 'weasleys'): 1,
#  ('arthur', 'weasleys'): 1,
#  ('george', 'weasleys'): 1,
#  ('fred', 'weasleys'): 1,
#  ('announcer', 'ron'): 1,
#  ('announcer', 'ginny'): 1,
#  ('announcer', 'twins'): 1,
#  ('announcer', 'boys'): 1,
#  ('announcer', 'fred'): 1,
#  ('ron', 'twins'): 2,
#  ('ron', 'boys'): 1,
#  ('ginny', 'twins'): 1,
#  ('ginny', 'boys'): 1,
#  ('twins', 'boys'): 1,
#  ('twins', 'fred'): 2,
#  ('boys', 'fred'): 1,
#  ('ron', 'barty'): 3,
#  ('harry potter', 'barty'): 5,
#  ('arthur', 'barty'): 1,
#  ('barty', 'hermione'): 4,
#  ('lady offscreen', 'lady'): 1,
#  ('lady offscreen', 'ron'): 1,
#  ('lady offscreen', 'harry potter'): 1,
#  ('lady offscreen', 'cho'): 1,
#  ('lady offscreen', 'hermione'): 1,
#  ('lady', 'ron'): 1,
#  ('lady', 'harry potter'): 1,
#  ('lady', 'cho'): 1,
#  ('lady', 'hermione'): 1,
#  ('ron', 'cho'): 3,
#  ('harry potter', 'cho'): 8,
#  ('cho', 'hermione'): 4,
#  ('hagrid', 'student'): 1,
#  ('hagrid', 'igor'): 1,
#  ('harry potter', 'student'): 1,
#  ('harry potter', 'igor'): 4,
#  ('albus dumbledore', 'student'): 1,
#  ('albus dumbledore', 'igor'): 3,
#  ('student', 'ron'): 1,
#  ('student', 'igor'): 1,
#  ('ron', 'igor'): 1,
#  ('madame maxime', 'albus dumbledore'): 2,
#  ('man', 'albus dumbledore'): 2,
#  ('man', 'mad-eye'): 2,
#  ('man', 'pupil'): 1,
#  ('man', 'barty'): 2,
#  ('albus dumbledore', 'fred'): 2,
#  ('albus dumbledore', 'mad-eye'): 9,
#  ('albus dumbledore', 'pupil'): 1,
#  ('albus dumbledore', 'barty'): 5,
#  ('albus dumbledore', 'george'): 2,
#  ('fred', 'mad-eye'): 3,
#  ('fred', 'pupil'): 1,
#  ('fred', 'barty'): 2,
#  ('ron', 'mad-eye'): 8,
#  ('ron', 'pupil'): 2,
#  ('hermione', 'mad-eye'): 7,
#  ('hermione', 'pupil'): 2,
#  ('mad-eye', 'pupil'): 2,
#  ('mad-eye', 'harry potter'): 13,
#  ('mad-eye', 'barty'): 4,
#  ('mad-eye', 'george'): 3,
#  ('pupil', 'harry potter'): 1,
#  ('pupil', 'barty'): 1,
#  ('pupil', 'george'): 1,
#  ('barty', 'george'): 2,
#  ('mad-eye', 'neville'): 3,
#  ('pupil', 'neville'): 1,
#  ('hagrid', 'voice'): 1,
#  ('harry potter', 'madame maxime'): 2,
#  ('madame maxime', 'mad-eye'): 1,
#  ('madame maxime', 'igor'): 1,
#  ('mad-eye', 'igor'): 2,
#  ('barty', 'mcgonagall'): 1,
#  ('barty', 'snape'): 1,
#  ('mcgonagall', 'mad-eye'): 2,
#  ('snape', 'mad-eye'): 2,
#  ('rita', 'harry potter'): 4,
#  ('sir', 'harry potter'): 1,
#  ('sir', 'rita'): 1,
#  ('sir', 'ron'): 1,
#  ('rita', 'ron'): 1,
#  ('hagrid', 'madame maxime'): 1,
#  ('boy', 'cedric'): 1,
#  ('boy', 'mad-eye'): 1,
#  ('cedric', 'draco'): 1,
#  ('cedric', 'mad-eye'): 2,
#  ('cedric', 'mcgonagall'): 1,
#  ('draco', 'mad-eye'): 1,
#  ('hermione', 'rita'): 2,
#  ('hermione', 'viktor'): 2,
#  ('harry potter', 'viktor'): 2,
#  ('rita', 'viktor'): 1,
#  ('rita', 'albus dumbledore'): 1,
#  ('rita', 'barty'): 1,
#  ('viktor', 'albus dumbledore'): 1,
#  ('viktor', 'barty'): 1,
#  ('hermione', 'nigel'): 2,
#  ('nigel', 'ron'): 2,
#  ('nigel', 'harry potter'): 2,
#  ('nigel', 'ginny'): 2,
#  ('mcgonagall', 'fred'): 1,
#  ('mcgonagall', 'twins'): 1,
#  ('harry potter', 'patils'): 1,
#  ('girl', 'patils'): 1,
#  ('hermione', 'patils'): 1,
#  ('ron', 'patils'): 1,
#  ('elsewhere', 'ron'): 1,
#  ('elsewhere', 'harry potter'): 1,
#  ('harry potter', 'parvati'): 1,
#  ('harry potter', 'padma'): 1,
#  ('ron', 'padma'): 1,
#  ('parvati', 'mcgonagall'): 1,
#  ('parvati', 'padma'): 1,
#  ('mcgonagall', 'padma'): 1,
#  ('padma', 'hermione'): 1,
#  ('hermione', 'nightmare sequence'): 1,
#  ('hermione', 'voldemort'): 1,
#  ('nightmare sequence', 'voldemort'): 1,
#  ('nightmare sequence', 'neville'): 1,
#  ('voldemort', 'neville'): 2,
#  ('harry potter', 'myrtle'): 1,
#  ('harry potter', 'voice singing'): 1,
#  ('myrtle', 'voice singing'): 1,
#  ('seamus', 'friend'): 1,
#  ('friend', 'neville'): 1,
#  ('harry potter', 'merperson'): 1,
#  ('albus dumbledore', 'fleur'): 1,
#  ('barty', 'fleur'): 1,
#  ('fleur', 'ron'): 5,
#  ('fleur', 'hermione'): 5,
#  ('fleur', 'harry potter'): 5,
#  ('fleur', 'fred'): 2,
#  ('fleur', 'george'): 2,
#  ('fleur', 'mad-eye'): 2,
#  ('mad-eye', 'hagrid'): 3,
#  ('fudge', 'mad-eye'): 1,
#  ('harry potter', 'barty jr'): 2,
#  ('harry potter', 'gahhhh!'): 1,
#  ('man', 'igor'): 1,
#  ('man', 'barty jr'): 1,
#  ('man', 'gahhhh!'): 1,
#  ('barty', 'igor'): 1,
#  ('barty', 'barty jr'): 1,
#  ('barty', 'gahhhh!'): 1,
#  ('igor', 'barty jr'): 1,
#  ('igor', 'gahhhh!'): 1,
#  ('mad-eye', 'barty jr'): 2,
#  ('mad-eye', 'gahhhh!'): 1,
#  ('albus dumbledore', 'barty jr'): 2,
#  ('albus dumbledore', 'gahhhh!'): 1,
#  ('barty jr', 'gahhhh!'): 1,
#  ('igor', 'snape'): 1,
#  ('albus dumbledore', 'cedric'): 1,
#  ('cedric', 'voldemort'): 1,
#  ('cedric', 'wormtail'): 1,
#  ('cedric', 'lucius'): 1,
#  ('cedric', "harry's dad"): 1,
#  ('cedric', "harry's mother"): 1,
#  ('harry potter', 'wormtail'): 2,
#  ('harry potter', 'lucius'): 4,
#  ('harry potter', "harry's dad"): 1,
#  ('harry potter', "harry's mother"): 1,
#  ('voldemort', 'lucius'): 2,
#  ('voldemort', "harry's dad"): 1,
#  ('voldemort', "harry's mother"): 1,
#  ('wormtail', 'lucius'): 2,
#  ('wormtail', "harry's dad"): 1,
#  ('wormtail', "harry's mother"): 1,
#  ('lucius', "harry's dad"): 1,
#  ('lucius', "harry's mother"): 1,
#  ("harry's dad", "harry's mother"): 1,
#  ('albus dumbledore', 'amos'): 1,
#  ('fudge', 'amos'): 1,
#  ('mad-eye', 'alastor'): 1,
#  ('harry potter', 'alastor'): 1,
#  ('albus dumbledore', 'alastor'): 1,
#  ('alastor', 'snape'): 1,
#  ('alastor', 'barty jr'): 1,
#  ('snape', 'barty jr'): 1,
#  ('viktor', 'fleur'): 1,
#  ('viktor', 'ron'): 1,
#  ('dudley', 'gang thug #1'): 1,
#  ('dudley', 'mrs. figg'): 1,
#  ('dudley', 'gang member #3'): 1,
#  ('dudley', 'i said, do you understand? !'): 1,
#  ('dudley', '(v.o.)'): 1,
#  ('dudley', 'lily potter'): 1,
#  ('dudley', 'moody'): 1,
#  ('dudley', 'lupin'): 1,
#  ('dudley', 'tonks'): 1,
#  ('dudley', 'kingsley'): 1,
#  ('gang thug #1', 'harry potter'): 1,
#  ('gang thug #1', 'mrs. figg'): 1,
#  ('gang thug #1', 'gang member #3'): 1,
#  ('gang thug #1', 'i said, do you understand? !'): 1,
#  ('gang thug #1', '(v.o.)'): 1,
#  ('gang thug #1', 'lily potter'): 1,
#  ('gang thug #1', 'vernon'): 1,
#  ('gang thug #1', 'petunia'): 1,
#  ('gang thug #1', 'moody'): 1,
#  ('gang thug #1', 'lupin'): 1,
#  ('gang thug #1', 'tonks'): 1,
#  ('gang thug #1', 'kingsley'): 1,
#  ('harry potter', 'mrs. figg'): 2,
#  ('harry potter', 'gang member #3'): 1,
#  ('harry potter', 'i said, do you understand? !'): 1,
#  ('harry potter', '(v.o.)'): 2,
#  ('harry potter', 'lily potter'): 2,
#  ('harry potter', 'moody'): 1,
#  ('harry potter', 'lupin'): 10,
#  ('harry potter', 'tonks'): 5,
#  ('harry potter', 'kingsley'): 1,
#  ('mrs. figg', 'gang member #3'): 1,
#  ('mrs. figg', 'i said, do you understand? !'): 1,
#  ('mrs. figg', '(v.o.)'): 1,
#  ('mrs. figg', 'lily potter'): 1,
#  ('mrs. figg', 'vernon'): 1,
#  ('mrs. figg', 'petunia'): 1,
#  ('mrs. figg', 'moody'): 1,
#  ('mrs. figg', 'lupin'): 1,
#  ('mrs. figg', 'tonks'): 1,
#  ('mrs. figg', 'kingsley'): 1,
#  ('gang member #3', 'i said, do you understand? !'): 1,
#  ('gang member #3', '(v.o.)'): 1,
#  ('gang member #3', 'lily potter'): 1,
#  ('gang member #3', 'vernon'): 1,
#  ('gang member #3', 'petunia'): 1,
#  ('gang member #3', 'moody'): 1,
#  ('gang member #3', 'lupin'): 1,
#  ('gang member #3', 'tonks'): 1,
#  ('gang member #3', 'kingsley'): 1,
#  ('i said, do you understand? !', '(v.o.)'): 1,
#  ('i said, do you understand? !', 'lily potter'): 1,
#  ('i said, do you understand? !', 'vernon'): 1,
#  ('i said, do you understand? !', 'petunia'): 1,
#  ('i said, do you understand? !', 'moody'): 1,
#  ('i said, do you understand? !', 'lupin'): 1,
#  ...}

# %%
G = nx.Graph()
# G.add_edge((2, 3, {'weight': 3.1415}))

G.add_edges_from([(2, 3, {'weight': 3.1415})])

# Create an undirected weighted graph
G = nx.Graph()
for edge in scene_interactions:
    edge_1 = edge[0]
    edge_2 = edge[1]
    weight = scene_interactions[edge]
    G.add_edges_from([(edge_1, edge_2, {'weight': weight})])

# %%
# Extracting the GCC
G_GCC = G.subgraph(max(nx.connected_components(G), key=len))

partition = community.best_partition(G_GCC, random_state = 0)

# %%
# Create a dictionary of node name and community number
communities = {}
for node in G_GCC.nodes:
    communities[node] = partition[node]
        
# Get all the community values in a single variable for counting
lovain_communities = communities.values()  

# Count and sort the communities
communities_counter = Counter(lovain_communities).most_common(max(lovain_communities))

# Add the community numbers to an attribute within the graph
nx.set_node_attributes(G_GCC, communities, "community")

# Print a single hero to see that this worked
#print(G.nodes['Rubeus Hagrid']['community'])

# %%
# Lets plot the communities and see how many are in each one
plt.figure(figsize = (15,7))

labels, values = zip(*communities_counter)
indexes = np.arange(len(labels))

plt.bar(indexes, values)
plt.xticks(indexes, labels)
plt.xlabel('Community number')
plt.ylabel('Number of members in community')
plt.title('Wiki universe communities and their member counts')
plt.show()

# %%
# Generate the numbers of the top 10 communities and top 6 communities
top_10_communities = [el[0] for el in Counter(lovain_communities).most_common(10)]

# Let's find out the 'biggest' nodes
nodes = dict(sorted(nx.degree_centrality(G_GCC).items(), key = itemgetter(1), reverse = True)[0:10])
top_nodes = list(nodes.keys())

# %%
# Finally lets plot these results on the undirected version of the graph - NOTE HERE WE USE UNDIRECTED FOR PLOTTING
import matplotlib as mtpl
from fa2 import ForceAtlas2

cmap = mtpl.cm.get_cmap('Set1', 10) # create 10 colors to use for plotting

colors = []

for i in range(cmap.N):
    rgb = cmap(i)[:3] # will return rgba, we take only first 3 so we get rgb
    colors.append(mtpl.colors.rgb2hex(rgb))


plt.figure(figsize=(15,10))

forceatlas3 = ForceAtlas2(
    # Behavior alternatives
    outboundAttractionDistribution = True, # Persuade hubs
    edgeWeightInfluence=1,
    
    # Performance
    jitterTolerance=0.7, # Tolerance
    barnesHutOptimize=True,
    barnesHutTheta=0.6,
    
    # Tuning
    scalingRatio=5.0,
    strongGravityMode=True,
    gravity=50.0,
    
    # Log
    verbose=True
)

positions = forceatlas2.forceatlas2_networkx_layout(G_GCC, pos=None, iterations=2000)

# Generate sizes based on node centrality
node_sizes = list(nx.degree_centrality(G_GCC).values())
node_sizes = [round(num,3) for num in node_sizes]
node_sizes = [num*5000 for num in node_sizes]

# Lets try only coloring in the 10 biggest communities - other minor communities will be gray
# Otherwise it gets to confusing
node_colors = [colors[top_10_communities.index(m)] if (m in top_10_communities) else '#808080' for m in lovain_communities]

# Generate the graph
nx.draw(G_GCC, positions, with_labels = False, node_size = node_sizes, 
        node_color = node_colors, edge_color = 'lightgray', alpha=0.2);

# Generate the labels
labels = {}    
for node in G_GCC.nodes():
    if node in top_nodes[:10]:
        #set the node name as the key and the label as its value 
        labels[node] = node

# Now draw only the labels of the top nodes
nx.draw_networkx_labels(G_GCC, positions, labels, font_size=16, font_color='black');

# %%
# Finally lets plot these results on the undirected version of the graph - NOTE HERE WE USE UNDIRECTED FOR PLOTTING

# Let's create the plot again with hubs being present
plt.figure(figsize=(15,10))

forceatlas3 = ForceAtlas2(
    # Behavior alternatives
    outboundAttractionDistribution = True, # Persuade hubs
    edgeWeightInfluence=1,
    
    # Performance
    jitterTolerance=0.7, # Tolerance
    barnesHutOptimize=True,
    barnesHutTheta=0.6,
    
    # Tuning
    scalingRatio=5.0,
    strongGravityMode=True,
    gravity=50.0,
    
    # Log
    verbose=True
)

node_sizes = list(nx.degree_centrality(G).values())
node_sizes = [round(num,3) for num in node_sizes]
node_sizes = [num*5000 for num in node_sizes]

positions3 = forceatlas3.forceatlas2_networkx_layout(G, pos=None, iterations=2000)

# Generate the graph
nx.draw(G, positions3, with_labels = False, node_size = node_sizes, 
        node_color = node_colors, edge_color = 'lightgray', alpha=0.2);

# Now draw only the labels of the top nodes
nx.draw_networkx_labels(G, positions3, labels, font_size=16, font_color='black');
# Out:
# 100%|██████████| 2000/2000 [00:04<00:00, 483.81it/s]
# BarnesHut Approximation  took  0.87  seconds
# Repulsion forces  took  2.97  seconds
# Gravitational forces  took  0.01  seconds
# Attraction forces  took  0.04  seconds
# AdjustSpeedAndApplyForces step  took  0.12  seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-304-f591f6be42c9> in <module>
#      31 # Generate the graph
#      32 nx.draw(G, positions3, with_labels = False, node_size = node_sizes,
# ---> 33         node_color = node_colors, edge_color = 'lightgray', alpha=0.2);
#      34
#      35 # Now draw only the labels of the top nodes
#
# NameError: name 'node_colors' is not defined

# %%
top_10 = sorted(scene_interactions, key=scene_interactions.get, reverse=True)[:10]

# scene_interactions[top_10]
# top_10
# top_list = []
# for pair in top_10:
#     top_list.append(scene_interactions[pair])

dict_you_want = { your_key: scene_interactions[your_key] for your_key in top_10 }
dict_you_want
# Out:
# {('ron', 'harry potter'): 233,
#  ('harry potter', 'hermione'): 213,
#  ('ron', 'hermione'): 181,
#  ('albus dumbledore', 'harry potter'): 51,
#  ('hagrid', 'harry potter'): 46,
#  ('neville', 'harry potter'): 35,
#  ('neville', 'ron'): 29,
#  ('harry potter', 'ginny'): 29,
#  ('george', 'fred'): 27,
#  ('neville', 'hermione'): 27}

# %% [markdown]
# ### Trying different method of interaction

# %%
# lets create connection between characters 

# for movie in df.movie_nr:
# movie = 1
# df_names = df['character'].unique()
# df_store = df[df.movie_nr == movie].groupby(['scene_id','movie_nr'])['character'].unique()

scene_interactions = dict()
for movie in df.movie_nr.unique():
    print(f'Going through movie {movie}')
    df_store = df[df.movie_nr == movie].groupby(['scene_id','movie_nr'])['character'].unique()
    for scene in df_store:
    #     print("Scene length:",len(scene))
        for idx in range(len(scene)-1):
            for idx2 in range(idx+1,len(scene)):
    #             print(scene[idx],scene[idx2])
                if (scene[idx],scene[idx2]) in scene_interactions:
                    scene_interactions[(scene[idx],scene[idx2])] += 1
                else:
                    if (scene[idx2],scene[idx]) in scene_interactions:
                        scene_interactions[(scene[idx2],scene[idx])] += 1
                    else:
                        scene_interactions[(scene[idx],scene[idx2])] = 1
scene_interactions
# Out:
# Going through movie 1
# Going through movie 2
# Going through movie 3
# Going through movie 4
# Going through movie 5
# Going through movie 6
# Going through movie 7
# Going through movie 8
# {('albus dumbledore', 'mcgonagall'): 5,
#  ('albus dumbledore', 'hagrid'): 8,
#  ('albus dumbledore', 'petunia'): 1,
#  ('albus dumbledore', 'dudley'): 1,
#  ('albus dumbledore', 'vernon'): 1,
#  ('albus dumbledore', 'harry potter'): 51,
#  ('mcgonagall', 'hagrid'): 2,
#  ('mcgonagall', 'petunia'): 1,
#  ('mcgonagall', 'dudley'): 1,
#  ('mcgonagall', 'vernon'): 1,
#  ('mcgonagall', 'harry potter'): 19,
#  ('hagrid', 'petunia'): 2,
#  ('hagrid', 'dudley'): 2,
#  ('hagrid', 'vernon'): 2,
#  ('hagrid', 'harry potter'): 46,
#  ('petunia', 'dudley'): 4,
#  ('petunia', 'vernon'): 7,
#  ('petunia', 'harry potter'): 5,
#  ('dudley', 'vernon'): 6,
#  ('dudley', 'harry potter'): 9,
#  ('vernon', 'harry potter'): 7,
#  ('dudley', 'snake'): 1,
#  ('dudley', 'man'): 1,
#  ('vernon', 'snake'): 1,
#  ('vernon', 'man'): 1,
#  ('harry potter', 'snake'): 1,
#  ('harry potter', 'man'): 7,
#  ('snake', 'man'): 1,
#  ('snake', 'petunia'): 1,
#  ('man', 'petunia'): 1,
#  ('harry potter', 'all'): 4,
#  ('vernon', 'all'): 1,
#  ('hagrid', 'all'): 3,
#  ('petunia', 'all'): 1,
#  ('all', 'dudley'): 1,
#  ('harry potter', 'tom'): 2,
#  ('harry potter', 'witch'): 1,
#  ('harry potter', 'quirrell'): 5,
#  ('harry potter', 'boy'): 5,
#  ('harry potter', 'goblin'): 1,
#  ('hagrid', 'tom'): 1,
#  ('hagrid', 'man'): 2,
#  ('hagrid', 'witch'): 1,
#  ('hagrid', 'quirrell'): 1,
#  ('hagrid', 'boy'): 1,
#  ('hagrid', 'goblin'): 1,
#  ('tom', 'man'): 1,
#  ('tom', 'witch'): 1,
#  ('tom', 'quirrell'): 1,
#  ('tom', 'boy'): 1,
#  ('tom', 'goblin'): 1,
#  ('man', 'witch'): 1,
#  ('man', 'quirrell'): 2,
#  ('man', 'boy'): 1,
#  ('man', 'goblin'): 1,
#  ('witch', 'quirrell'): 1,
#  ('witch', 'boy'): 1,
#  ('witch', 'goblin'): 1,
#  ('quirrell', 'boy'): 2,
#  ('quirrell', 'goblin'): 1,
#  ('boy', 'goblin'): 1,
#  ('griphook', 'hagrid'): 1,
#  ('griphook', 'harry potter'): 8,
#  ('harry potter', 'ollivander'): 3,
#  ('hagrid', 'ollivander'): 1,
#  ('man', 'trainmaster'): 1,
#  ('man', 'george'): 2,
#  ('man', 'fred'): 2,
#  ('harry potter', 'trainmaster'): 1,
#  ('harry potter', 'george'): 23,
#  ('harry potter', 'fred'): 25,
#  ('trainmaster', 'george'): 1,
#  ('trainmaster', 'fred'): 1,
#  ('george', 'fred'): 27,
#  ('ron', 'harry potter'): 233,
#  ('ron', 'woman'): 1,
#  ('harry potter', 'woman'): 3,
#  ('harry potter', 'frog'): 1,
#  ('harry potter', 'hermione'): 213,
#  ('ron', 'frog'): 1,
#  ('ron', 'hermione'): 181,
#  ('frog', 'hermione'): 1,
#  ('hagrid', 'ron'): 22,
#  ('mcgonagall', 'neville'): 2,
#  ('mcgonagall', 'draco'): 6,
#  ('mcgonagall', 'hermione'): 6,
#  ('mcgonagall', 'ron'): 10,
#  ('mcgonagall', 'seamus'): 1,
#  ('mcgonagall', 'percy'): 1,
#  ('mcgonagall', 'nick'): 1,
#  ('mcgonagall', 'girl'): 2,
#  ('neville', 'draco'): 6,
#  ('neville', 'harry potter'): 35,
#  ('neville', 'hermione'): 27,
#  ('neville', 'albus dumbledore'): 4,
#  ('neville', 'ron'): 29,
#  ('neville', 'seamus'): 20,
#  ('neville', 'percy'): 3,
#  ('neville', 'nick'): 1,
#  ('neville', 'girl'): 4,
#  ('draco', 'harry potter'): 23,
#  ('draco', 'hermione'): 20,
#  ('draco', 'albus dumbledore'): 3,
#  ('draco', 'ron'): 22,
#  ('draco', 'seamus'): 6,
#  ('draco', 'percy'): 2,
#  ('draco', 'nick'): 1,
#  ('draco', 'girl'): 2,
#  ('harry potter', 'seamus'): 15,
#  ('harry potter', 'percy'): 6,
#  ('harry potter', 'nick'): 2,
#  ('harry potter', 'girl'): 5,
#  ('hermione', 'albus dumbledore'): 16,
#  ('hermione', 'seamus'): 13,
#  ('hermione', 'percy'): 1,
#  ('hermione', 'nick'): 2,
#  ('hermione', 'girl'): 3,
#  ('albus dumbledore', 'ron'): 16,
#  ('albus dumbledore', 'seamus'): 2,
#  ('albus dumbledore', 'percy'): 3,
#  ('albus dumbledore', 'nick'): 1,
#  ('albus dumbledore', 'girl'): 2,
#  ('ron', 'seamus'): 16,
#  ('ron', 'percy'): 7,
#  ('ron', 'nick'): 2,
#  ('ron', 'girl'): 4,
#  ('seamus', 'percy'): 2,
#  ('seamus', 'nick'): 1,
#  ('seamus', 'girl'): 1,
#  ('percy', 'nick'): 1,
#  ('percy', 'girl'): 3,
#  ('nick', 'girl'): 1,
#  ('percy', 'boy'): 1,
#  ('boy', 'neville'): 3,
#  ('boy', 'ron'): 3,
#  ('boy', 'girl'): 3,
#  ('woman', 'percy'): 1,
#  ('woman', 'girl'): 1,
#  ('snape', 'harry potter'): 27,
#  ('hooch', 'class'): 1,
#  ('hooch', 'harry potter'): 3,
#  ('hooch', 'draco'): 3,
#  ('hooch', 'hermione'): 3,
#  ('hooch', 'ron'): 2,
#  ('hooch', 'neville'): 1,
#  ('hooch', 'girl'): 1,
#  ('hooch', 'students'): 1,
#  ('hooch', 'boy'): 1,
#  ('hooch', 'mcgonagall'): 3,
#  ('class', 'harry potter'): 1,
#  ('class', 'draco'): 1,
#  ('class', 'hermione'): 1,
#  ('class', 'ron'): 1,
#  ('class', 'neville'): 1,
#  ('class', 'girl'): 1,
#  ('class', 'students'): 1,
#  ('class', 'boy'): 1,
#  ('class', 'mcgonagall'): 1,
#  ('harry potter', 'students'): 2,
#  ('draco', 'students'): 3,
#  ('draco', 'boy'): 2,
#  ('hermione', 'students'): 3,
#  ('hermione', 'boy'): 1,
#  ('ron', 'students'): 2,
#  ('neville', 'students'): 2,
#  ('girl', 'students'): 1,
#  ('students', 'boy'): 1,
#  ('students', 'mcgonagall'): 1,
#  ('boy', 'mcgonagall'): 2,
#  ('quirrell', 'mcgonagall'): 2,
#  ('nick', 'fred'): 1,
#  ('nick', 'george'): 1,
#  ('ron', 'fred'): 22,
#  ('ron', 'george'): 19,
#  ('fred', 'hermione'): 16,
#  ('george', 'hermione'): 15,
#  ('ron', 'filch'): 4,
#  ('ron', 'all'): 3,
#  ('harry potter', 'filch'): 9,
#  ('hermione', 'filch'): 5,
#  ('hermione', 'all'): 3,
#  ('filch', 'all'): 1,
#  ('oliver', 'harry potter'): 2,
#  ('flitwick', 'draco'): 1,
#  ('flitwick', 'ron'): 3,
#  ('flitwick', 'hermione'): 3,
#  ('flitwick', 'seamus'): 2,
#  ('flitwick', 'harry potter'): 3,
#  ('neville', 'quirrell'): 1,
#  ('quirrell', 'albus dumbledore'): 1,
#  ('quirrell', 'girl'): 1,
#  ('albus dumbledore', 'boy'): 1,
#  ('hermione', 'quirrell'): 1,
#  ('ron', 'quirrell'): 1,
#  ('ron', 'snape'): 10,
#  ('hermione', 'snape'): 10,
#  ('oiiver', 'harry potter'): 1,
#  ('oiiver', 'oliver'): 1,
#  ('oiiver', 'lee'): 1,
#  ('oiiver', 'hooch'): 1,
#  ('oiiver', 'hagrid'): 1,
#  ('oiiver', 'gryffindors'): 1,
#  ('oiiver', 'flint'): 1,
#  ('oiiver', 'crowd'): 1,
#  ('oiiver', 'hermione'): 1,
#  ('oiiver', 'ron'): 1,
#  ('oiiver', 'man'): 1,
#  ('oiiver', 'snape'): 1,
#  ('oiiver', 'all'): 1,
#  ('oiiver', 'draco'): 1,
#  ('oiiver', 'mcgonagall'): 1,
#  ('harry potter', 'lee'): 2,
#  ('harry potter', 'gryffindors'): 1,
#  ('harry potter', 'flint'): 2,
#  ('harry potter', 'crowd'): 2,
#  ('oliver', 'lee'): 1,
#  ('oliver', 'hooch'): 1,
#  ('oliver', 'hagrid'): 1,
#  ('oliver', 'gryffindors'): 1,
#  ('oliver', 'flint'): 1,
#  ('oliver', 'crowd'): 1,
#  ('oliver', 'hermione'): 1,
#  ('oliver', 'ron'): 1,
#  ('oliver', 'man'): 1,
#  ('oliver', 'snape'): 1,
#  ('oliver', 'all'): 1,
#  ('oliver', 'draco'): 1,
#  ('oliver', 'mcgonagall'): 1,
#  ('lee', 'hooch'): 1,
#  ('lee', 'hagrid'): 2,
#  ('lee', 'gryffindors'): 1,
#  ('lee', 'flint'): 1,
#  ('lee', 'crowd'): 1,
#  ('lee', 'hermione'): 2,
#  ('lee', 'ron'): 1,
#  ('lee', 'man'): 1,
#  ('lee', 'snape'): 1,
#  ('lee', 'all'): 1,
#  ('lee', 'draco'): 2,
#  ('lee', 'mcgonagall'): 1,
#  ('hooch', 'hagrid'): 1,
#  ('hooch', 'gryffindors'): 1,
#  ('hooch', 'flint'): 1,
#  ('hooch', 'crowd'): 1,
#  ('hooch', 'man'): 1,
#  ('hooch', 'snape'): 1,
#  ('hooch', 'all'): 1,
#  ('hagrid', 'gryffindors'): 1,
#  ('hagrid', 'flint'): 1,
#  ('hagrid', 'crowd'): 1,
#  ('hagrid', 'hermione'): 25,
#  ('hagrid', 'snape'): 2,
#  ('hagrid', 'draco'): 8,
#  ('gryffindors', 'flint'): 1,
#  ('gryffindors', 'crowd'): 1,
#  ('gryffindors', 'hermione'): 1,
#  ('gryffindors', 'ron'): 1,
#  ('gryffindors', 'man'): 1,
#  ('gryffindors', 'snape'): 1,
#  ('gryffindors', 'all'): 1,
#  ('gryffindors', 'draco'): 1,
#  ('gryffindors', 'mcgonagall'): 1,
#  ('flint', 'crowd'): 1,
#  ('flint', 'hermione'): 2,
#  ('flint', 'ron'): 2,
#  ('flint', 'man'): 1,
#  ('flint', 'snape'): 1,
#  ('flint', 'all'): 1,
#  ('flint', 'draco'): 2,
#  ('flint', 'mcgonagall'): 1,
#  ('crowd', 'hermione'): 2,
#  ('crowd', 'ron'): 1,
#  ('crowd', 'man'): 1,
#  ('crowd', 'snape'): 1,
#  ('crowd', 'all'): 1,
#  ('crowd', 'draco'): 1,
#  ('crowd', 'mcgonagall'): 1,
#  ('hermione', 'man'): 2,
#  ('ron', 'man'): 2,
#  ('man', 'snape'): 2,
#  ('man', 'all'): 1,
#  ('man', 'draco'): 1,
#  ('man', 'mcgonagall'): 1,
#  ('snape', 'all'): 1,
#  ('snape', 'draco'): 4,
#  ('snape', 'mcgonagall'): 2,
#  ('all', 'draco'): 1,
#  ('all', 'mcgonagall'): 1,
#  ('man', 'filch'): 1,
#  ('quirrell', 'snape'): 1,
#  ('quirrell', 'filch'): 1,
#  ('snape', 'filch'): 5,
#  ('filch', 'hagrid'): 1,
#  ('filch', 'draco'): 2,
#  ('harry potter', 'firenze'): 1,
#  ('draco', 'firenze'): 1,
#  ('firenze', 'hermione'): 1,
#  ('firenze', 'hagrid'): 1,
#  ('harry potter', 'voldemort'): 13,
#  ('quirrell', 'voldemort'): 1,
#  ('albus dumbledore', 'students'): 1,
#  ('albus dumbledore', 'lee'): 1,
#  ('students', 'hagrid'): 1,
#  ('students', 'seamus'): 2,
#  ('students', 'lee'): 1,
#  ('hagrid', 'seamus'): 2,
#  ('seamus', 'lee'): 1,
#  ('harry potter', 'uncle vernon'): 11,
#  ('uncle vernon', 'dudley'): 3,
#  ('uncle vernon', 'aunt petunia'): 3,
#  ('harry potter', 'aunt petunia'): 4,
#  ('dudley', 'aunt petunia'): 1,
#  ('dobby', 'harry potter'): 12,
#  ('uncle vernon', 'mr. mason'): 1,
#  ('uncle vernon', 'dobby'): 2,
#  ('dudley', 'ron'): 1,
#  ('harry potter', "closeup - harry's trunk 13b"): 1,
#  ('harry potter', "insert - fred's foot 13c"): 1,
#  ('ron', "closeup - harry's trunk 13b"): 1,
#  ('ron', "insert - fred's foot 13c"): 1,
#  ("closeup - harry's trunk 13b", "insert - fred's foot 13c"): 1,
#  ('uncle vernon', 'ron'): 1,
#  ('ron', 'mrs. weasley'): 9,
#  ('ron', 'ginny'): 23,
#  ('ron', 'mr. weasley'): 2,
#  ('harry potter', 'mrs. weasley'): 13,
#  ('harry potter', 'ginny'): 29,
#  ('harry potter', 'mr. weasley'): 9,
#  ('mrs. weasley', 'ginny'): 9,
#  ('mrs. weasley', 'george'): 3,
#  ('mrs. weasley', 'mr. weasley'): 4,
#  ('mrs. weasley', 'fred'): 3,
#  ('ginny', 'george'): 7,
#  ('ginny', 'mr. weasley'): 2,
#  ('ginny', 'fred'): 7,
#  ('george', 'mr. weasley'): 2,
#  ('mr. weasley', 'fred'): 2,
#  ('mrs. weasley', 'percy'): 1,
#  ('mr. borgin', 'lucius malfoy'): 1,
#  ('mr. borgin', 'draco'): 1,
#  ('lucius malfoy', 'draco'): 3,
#  ('aged witch', 'harry potter'): 1,
#  ('aged witch', 'hagrid'): 1,
#  ('hagrid', 'mr. weasley'): 2,
#  ('hagrid', 'mrs. weasley'): 4,
#  ('hermione', 'mr. weasley'): 2,
#  ('hermione', 'mrs. weasley'): 6,
#  ('mrs. weasley', 'short man'): 1,
#  ('mrs. weasley', 'gilderoy lockhart'): 1,
#  ('mrs. weasley', 'draco'): 1,
#  ('mrs. weasley', 'lucius malfoy'): 2,
#  ('ron', 'short man'): 1,
#  ('ron', 'gilderoy lockhart'): 9,
#  ('ron', 'lucius malfoy'): 5,
#  ('short man', 'gilderoy lockhart'): 1,
#  ('short man', 'harry potter'): 1,
#  ('short man', 'draco'): 1,
#  ('short man', 'ginny'): 1,
#  ('short man', 'lucius malfoy'): 1,
#  ('short man', 'hermione'): 1,
#  ('short man', 'mr. weasley'): 1,
#  ('short man', 'hagrid'): 1,
#  ('gilderoy lockhart', 'harry potter'): 10,
#  ('gilderoy lockhart', 'draco'): 4,
#  ('gilderoy lockhart', 'ginny'): 2,
#  ('gilderoy lockhart', 'lucius malfoy'): 1,
#  ('gilderoy lockhart', 'hermione'): 5,
#  ('gilderoy lockhart', 'mr. weasley'): 1,
#  ('gilderoy lockhart', 'hagrid'): 2,
#  ('harry potter', 'lucius malfoy'): 5,
#  ('draco', 'ginny'): 2,
#  ('draco', 'mr. weasley'): 1,
#  ('ginny', 'lucius malfoy'): 3,
#  ('ginny', 'hermione'): 16,
#  ('ginny', 'hagrid'): 3,
#  ('lucius malfoy', 'hermione'): 2,
#  ('lucius malfoy', 'mr. weasley'): 1,
#  ('lucius malfoy', 'hagrid'): 3,
#  ('ron', 'guard'): 1,
#  ('guard', 'harry potter'): 1,
#  ('snape', 'albus dumbledore'): 11,
#  ('neville', 'professor sprout'): 1,
#  ('seamus', 'professor sprout'): 1,
#  ('hermione', 'professor sprout'): 1,
#  ('ron', 'professor sprout'): 1,
#  ('penelope clearwater', 'percy'): 1,
#  ('penelope clearwater', 'nearly headless nick'): 1,
#  ('penelope clearwater', 'ron'): 1,
#  ('penelope clearwater', 'harry potter'): 1,
#  ('penelope clearwater', 'colin'): 1,
#  ('penelope clearwater', 'dean thomas'): 1,
#  ('penelope clearwater', 'seamus'): 1,
#  ('penelope clearwater', 'neville'): 1,
#  ('penelope clearwater', "at work and it's entirely your"): 1,
#  ('penelope clearwater', "of line we'll bring you straight"): 1,
#  ('percy', 'nearly headless nick'): 1,
#  ('percy', 'colin'): 1,
#  ('percy', 'dean thomas'): 1,
#  ('percy', "at work and it's entirely your"): 1,
#  ('percy', "of line we'll bring you straight"): 1,
#  ('nearly headless nick', 'ron'): 1,
#  ('nearly headless nick', 'harry potter'): 1,
#  ('nearly headless nick', 'colin'): 1,
#  ('nearly headless nick', 'dean thomas'): 1,
#  ('nearly headless nick', 'seamus'): 1,
#  ('nearly headless nick', 'neville'): 1,
#  ('nearly headless nick', "at work and it's entirely your"): 1,
#  ('nearly headless nick', "of line we'll bring you straight"): 1,
#  ('ron', 'colin'): 2,
#  ('ron', 'dean thomas'): 5,
#  ('ron', "at work and it's entirely your"): 1,
#  ('ron', "of line we'll bring you straight"): 1,
#  ('harry potter', 'colin'): 3,
#  ('harry potter', 'dean thomas'): 2,
#  ('harry potter', "at work and it's entirely your"): 1,
#  ('harry potter', "of line we'll bring you straight"): 1,
#  ('colin', 'dean thomas'): 1,
#  ('colin', 'seamus'): 1,
#  ('colin', 'neville'): 1,
#  ('colin', "at work and it's entirely your"): 1,
#  ('colin', "of line we'll bring you straight"): 1,
#  ('dean thomas', 'seamus'): 5,
#  ('dean thomas', 'neville'): 5,
#  ('dean thomas', "at work and it's entirely your"): 1,
#  ('dean thomas', "of line we'll bring you straight"): 1,
#  ('seamus', "at work and it's entirely your"): 1,
#  ('seamus', "of line we'll bring you straight"): 1,
#  ('neville', "at work and it's entirely your"): 1,
#  ('neville', "of line we'll bring you straight"): 1,
#  ("at work and it's entirely your", "of line we'll bring you straight"): 1,
#  ('gilderoy lockhart', 'dissolve'): 1,
#  ('gilderoy lockhart', 'seamus'): 1,
#  ('gilderoy lockhart', 'neville'): 1,
#  ('ron', 'dissolve'): 2,
#  ('harry potter', 'dissolve'): 4,
#  ('dissolve', 'seamus'): 1,
#  ('dissolve', 'hermione'): 2,
#  ('dissolve', 'neville'): 1,
#  ('wood', 'ron'): 2,
#  ('wood', 'flint'): 1,
#  ('wood', 'harry potter'): 2,
#  ('wood', 'draco'): 1,
#  ('wood', 'hermione'): 2,
#  ('wood', 'colin'): 1,
#  ('flint', 'colin'): 1,
#  ('draco', 'colin'): 1,
#  ('hermione', 'colin'): 2,
#  ('gilderoy lockhart', 'voice'): 1,
#  ('voice', 'harry potter'): 7,
#  ('voice', 'hermione'): 4,
#  ('voice', 'ron'): 3,
#  ('ron', 'the chamber of secrets has been opened'): 1,
#  ('the chamber of secrets has been opened', 'hermione'): 1,
#  ('the chamber of secrets has been opened', 'harry potter'): 1,
#  ('the chamber of secrets has been opened', 'draco'): 1,
#  ('the chamber of secrets has been opened', 'filch'): 1,
#  ('the chamber of secrets has been opened', 'albus dumbledore'): 1,
#  ('the chamber of secrets has been opened', 'gilderoy lockhart'): 1,
#  ('the chamber of secrets has been opened', 'snape'): 1,
#  ('filch', 'albus dumbledore'): 3,
#  ('filch', 'gilderoy lockhart'): 1,
#  ('albus dumbledore', 'gilderoy lockhart'): 1,
#  ('gilderoy lockhart', 'snape'): 3,
#  ('hagrid', 'george'): 4,
#  ('draco', 'george'): 2,
#  ('george', 'gilderoy lockhart'): 1,
#  ('madam pomfrey', 'hermione'): 1,
#  ('madam pomfrey', 'colin'): 1,
#  ('madam pomfrey', 'back to scene'): 1,
#  ('madam pomfrey', 'harry potter'): 2,
#  ('madam pomfrey', 'dobby'): 1,
#  ('madam pomfrey', 'albus dumbledore'): 1,
#  ('hermione', 'back to scene'): 2,
#  ('hermione', 'dobby'): 4,
#  ('colin', 'back to scene'): 1,
#  ('colin', 'dobby'): 1,
#  ('colin', 'albus dumbledore'): 1,
#  ('back to scene', 'harry potter'): 3,
#  ('back to scene', 'dobby'): 1,
#  ('back to scene', 'albus dumbledore'): 1,
#  ('dobby', 'albus dumbledore'): 2,
#  ('hermione', 'young girl comes racing out of the wall. face to face'): 1,
#  ('hermione', 'moaning myrtle'): 2,
#  ('ron', 'young girl comes racing out of the wall. face to face'): 1,
#  ('ron', 'moaning myrtle'): 4,
#  ('young girl comes racing out of the wall. face to face',
#   'moaning myrtle'): 1,
#  ('gilderoy lockhart', 'justin finch-fletchley'): 1,
#  ('gilderoy lockhart', 'justin-finch-fletchley'): 1,
#  ('justin finch-fletchley', 'harry potter'): 1,
#  ('justin finch-fletchley', 'ron'): 1,
#  ('justin finch-fletchley', 'snape'): 1,
#  ('justin finch-fletchley', 'hermione'): 1,
#  ('justin finch-fletchley', 'draco'): 1,
#  ('justin finch-fletchley', 'justin-finch-fletchley'): 1,
#  ('harry potter', 'justin-finch-fletchley'): 1,
#  ('ron', 'justin-finch-fletchley'): 1,
#  ('snape', 'justin-finch-fletchley'): 1,
#  ('hermione', 'justin-finch-fletchley'): 1,
#  ('draco', 'justin-finch-fletchley'): 1,
#  ('ernie', 'hannah'): 1,
#  ('sorting hat', 'harry potter'): 1,
#  ('sorting hat', 'albus dumbledore'): 1,
#  ('sorting hat', 'hagrid'): 1,
#  ('hermione', 'closeup - the potion'): 1,
#  ('ron', 'closeup - the potion'): 1,
#  ('closeup - the potion', 'harry potter'): 1,
#  ('harry potter', 'moaning myrtle'): 3,
#  ('voice', 'voldemort'): 2,
#  ('voice', 'albus dumbledore'): 2,
#  ('voldemort', 'albus dumbledore'): 3,
#  ('voice', 'young hagrid'): 1,
#  ('voldemort', 'young hagrid'): 1,
#  ('hagrid', 'neville'): 2,
#  ('voice', 'wood'): 1,
#  ('voice', 'george'): 1,
#  ('wood', 'george'): 1,
#  ('harry potter', 'fudge'): 7,
#  ('hagrid', 'fudge'): 1,
#  ('albus dumbledore', 'fudge'): 6,
#  ('albus dumbledore', 'lucius malfoy'): 3,
#  ('ron', 'fudge'): 1,
#  ('fudge', 'lucius malfoy'): 1,
#  ('ron', 'aragog'): 1,
#  ('harry potter', 'aragog'): 1,
#  ('madam pomfrey', 'ron'): 1,
#  ('gilderoy lockhart', 'professor sprout'): 1,
#  ('snape', 'professor sprout'): 1,
#  ('moaning myrtle', 'gilderoy lockhart'): 1,
#  ('voldemort', 'ginny'): 2,
#  ('albus dumbledore', 'ginny'): 6,
#  ('albus dumbledore', 'mrs. weasley'): 1,
#  ('harry potter', 'lucious malfoy'): 1,
#  ('lucius malfoy', 'lucious malfoy'): 1,
#  ('lucius malfoy', 'dobby'): 1,
#  ('lucious malfoy', 'dobby'): 1,
#  ('lucious malfoy', 'hermione'): 1,
#  ('lucious malfoy', 'ron'): 1,
#  ('lucious malfoy', 'albus dumbledore'): 1,
#  ('lucious malfoy', 'hagrid'): 1,
#  ('dobby', 'ron'): 4,
#  ('dobby', 'hagrid'): 1,
#  ('aunt petunia', 'aunt marge'): 2,
#  ('aunt marge', 'harry potter'): 2,
#  ('aunt marge', 'uncle vernon'): 3,
#  ('harry potter', 'stan shunpike'): 2,
#  ('disheveled wizard', 'stan shunpike'): 1,
#  ('disheveled wizard', 'shrunken head'): 1,
#  ('disheveled wizard', 'harry potter'): 1,
#  ('stan shunpike', 'shrunken head'): 1,
#  ('shrunken head', 'harry potter'): 1,
#  ('harry potter', 'cornelius fudge'): 3,
#  ('tom', 'cornelius fudge'): 1,
#  ('ron', 'closeup - a dog-eared clipping'): 1,
#  ('hermione', 'closeup - a dog-eared clipping'): 1,
#  ('harry potter', 'arthur weasley'): 5,
#  ('ron', 'arthur weasley'): 6,
#  ('hermione', 'arthur weasley'): 2,
#  ('george', 'arthur weasley'): 3,
#  ('fred', 'arthur weasley'): 3,
#  ('mrs. weasley', 'arthur weasley'): 2,
#  ('arthur weasley', 'ginny'): 3,
#  ('ron', 'professor lupin'): 4,
#  ('harry potter', 'professor lupin'): 9,
#  ('hermione', 'professor lupin'): 4,
#  ('professor trelawney', 'hermione'): 2,
#  ('professor trelawney', 'ron'): 1,
#  ('professor trelawney', 'neville'): 1,
#  ('professor trelawney', 'teacup - detail - later'): 1,
#  ('professor trelawney', 'parvati'): 1,
#  ('professor trelawney', 'seamus'): 1,
#  ('professor trelawney', 'dean thomas'): 1,
#  ('professor trelawney', 'lavender'): 2,
#  ('hermione', 'teacup - detail - later'): 1,
#  ('hermione', 'parvati'): 3,
#  ('hermione', 'dean thomas'): 2,
#  ('hermione', 'lavender'): 3,
#  ('ron', 'teacup - detail - later'): 1,
#  ('ron', 'parvati'): 3,
#  ('ron', 'lavender'): 2,
#  ('neville', 'teacup - detail - later'): 1,
#  ('neville', 'parvati'): 2,
#  ('neville', 'lavender'): 2,
#  ('teacup - detail - later', 'parvati'): 1,
#  ('teacup - detail - later', 'seamus'): 1,
#  ('teacup - detail - later', 'dean thomas'): 1,
#  ('teacup - detail - later', 'lavender'): 1,
#  ('parvati', 'seamus'): 2,
#  ('parvati', 'dean thomas'): 2,
#  ('parvati', 'lavender'): 1,
#  ('seamus', 'lavender'): 2,
#  ('dean thomas', 'lavender'): 1,
#  ('pansy', 'draco'): 1,
#  ('pansy', 'ron'): 1,
#  ('pansy', 'harry potter'): 1,
#  ('pansy', 'hermione'): 1,
#  ('pansy', 'seamus'): 1,
#  ('pansy', 'neville'): 1,
#  ('pansy', 'lavender'): 1,
#  ('pansy', 'lavendar'): 1,
#  ('pansy', 'bem'): 1,
#  ('draco', 'lavender'): 1,
#  ('draco', 'lavendar'): 1,
#  ('draco', 'bem'): 1,
#  ('ron', 'lavendar'): 1,
#  ('ron', 'bem'): 1,
#  ('harry potter', 'lavender'): 1,
#  ('harry potter', 'lavendar'): 1,
#  ('harry potter', 'bem'): 1,
#  ('hermione', 'lavendar'): 1,
#  ('hermione', 'bem'): 1,
#  ('seamus', 'lavendar'): 1,
#  ('seamus', 'bem'): 1,
#  ('neville', 'lavendar'): 1,
#  ('neville', 'bem'): 1,
#  ('lavender', 'lavendar'): 1,
#  ('lavender', 'bem'): 1,
#  ('lavendar', 'bem'): 1,
#  ('bem,', 'professor lupin'): 1,
#  ('bem,', 'seamus'): 1,
#  ('bem,', 'hermione'): 1,
#  ('bem,', 'ron'): 1,
#  ('bem,', 'students'): 1,
#  ('bem,', 'draco'): 1,
#  ('bem,', 'neville'): 1,
#  ('bem,', 'parvati'): 1,
#  ('bem,', 'dean thomas'): 1,
#  ('professor lupin', 'seamus'): 1,
#  ('professor lupin', 'students'): 1,
#  ('professor lupin', 'draco'): 1,
#  ('professor lupin', 'neville'): 1,
#  ('professor lupin', 'parvati'): 1,
#  ('professor lupin', 'dean thomas'): 1,
#  ('students', 'parvati'): 1,
#  ('students', 'dean thomas'): 1,
#  ('draco', 'parvati'): 1,
#  ('draco', 'dean thomas'): 1,
#  ('ron', 'fat lady'): 1,
#  ('ron', 'montage - securing the castle - night 58'): 1,
#  ('percy', 'ginny'): 1,
#  ('percy', 'filch'): 1,
#  ('percy', 'fat lady'): 1,
#  ('percy', 'montage - securing the castle - night 58'): 1,
#  ('ginny', 'filch'): 2,
#  ('ginny', 'fat lady'): 1,
#  ('ginny', 'montage - securing the castle - night 58'): 1,
#  ('albus dumbledore', 'fat lady'): 1,
#  ('albus dumbledore', 'montage - securing the castle - night 58'): 1,
#  ('filch', 'fat lady'): 1,
#  ('filch', 'montage - securing the castle - night 58'): 1,
#  ('fat lady', 'montage - securing the castle - night 58'): 1,
#  ('snape', 'sir cadogan'): 1,
#  ('albus dumbledore', 'sir cadogan'): 2,
#  ('sir cadogan', 'seamus'): 1,
#  ('sir cadogan', 'dean thomas'): 1,
#  ('sir cadogan', 'neville'): 2,
#  ('sir cadogan', 'ron'): 2,
#  ("intercut harry's pov", 'in the stands'): 1,
#  ("intercut harry's pov", 'harry potter'): 1,
#  ("intercut harry's pov", 'hermione'): 1,
#  ("intercut harry's pov", 'ron'): 1,
#  ("intercut harry's pov", 'fred'): 1,
#  ("intercut harry's pov", 'george'): 1,
#  ('in the stands', 'harry potter'): 1,
#  ('in the stands', 'hermione'): 1,
#  ('in the stands', 'ron'): 1,
#  ('in the stands', 'fred'): 1,
#  ('in the stands', 'george'): 1,
#  ('fred', 'professor lupin'): 1,
#  ('harry potter', 'crates. huge rolling bins. a wood staircase. a'): 1,
#  ('crates. huge rolling bins. a wood staircase. a', 'woman'): 1,
#  ('ron', 'cornelius fudge'): 1,
#  ('ron', 'madam rosmerta'): 1,
#  ('hermione', 'cornelius fudge'): 2,
#  ('hermione', 'madam rosmerta'): 1,
#  ('cornelius fudge', 'madam rosmerta'): 2,
#  ('harry potter', 'madam rosmerta'): 1,
#  ('hermione', 'sir cadogan'): 1,
#  ('sir cadogan', 'harry potter'): 1,
#  ("insert - marauder's map", 'back to scene'): 1,
#  ("insert - marauder's map", 'himself'): 1,
#  ("insert - marauder's map", 'voice'): 1,
#  ("insert - marauder's map", 'harry potter'): 1,
#  ("insert - marauder's map", 'snape'): 1,
#  ("insert - marauder's map", 'professor lupin'): 1,
#  ("insert - marauder's map", 'closeup - crystal ball'): 1,
#  ('back to scene', 'himself'): 1,
#  ('back to scene', 'voice'): 1,
#  ('back to scene', 'snape'): 1,
#  ('back to scene', 'professor lupin'): 1,
#  ('back to scene', 'closeup - crystal ball'): 1,
#  ('himself', 'voice'): 1,
#  ('himself', 'harry potter'): 1,
#  ('himself', 'snape'): 1,
#  ('himself', 'professor lupin'): 1,
#  ('himself', 'closeup - crystal ball'): 1,
#  ('voice', 'snape'): 2,
#  ('voice', 'professor lupin'): 1,
#  ('voice', 'closeup - crystal ball'): 1,
#  ('harry potter', 'closeup - crystal ball'): 1,
#  ('snape', 'professor lupin'): 2,
#  ('snape', 'closeup - crystal ball'): 1,
#  ('professor lupin', 'closeup - crystal ball'): 1,
#  ('harry potter', 'professor trelawney'): 1,
#  ('afternoon', 'draco'): 1,
#  ('afternoon', 'hermione'): 3,
#  ('afternoon', 'ron'): 2,
#  ('hermione', "harry and hermione's pov - the branches overhead"): 1,
#  ('ron', "harry and hermione's pov - the branches overhead"): 1,
#  ('ron', 'back to scene'): 1,
#  ('harry potter', "harry and hermione's pov - the branches overhead"): 1,
#  ("harry and hermione's pov - the branches overhead", 'back to scene'): 1,
#  ('hermione', 'sirius black'): 3,
#  ('hermione', 'pettigrew'): 1,
#  ('harry potter', 'sirius black'): 3,
#  ('harry potter', 'pettigrew'): 1,
#  ('ron', 'sirius black'): 1,
#  ('ron', 'pettigrew'): 1,
#  ('sirius black', 'professor lupin'): 1,
#  ('sirius black', 'snape'): 1,
#  ('sirius black', 'pettigrew'): 1,
#  ('professor lupin', 'pettigrew'): 1,
#  ('snape', 'pettigrew'): 1,
#  ('afternoon', 'harry potter'): 2,
#  ('cornelius fudge', 'albus dumbledore'): 1,
#  ('cornelius fudge', 'hagrid'): 1,
#  ('seamus', 'fred'): 2,
#  ('seamus', 'george'): 2,
#  ('neville', 'fred'): 2,
#  ('neville', 'george'): 2,
#  ('fred', 'hagrid'): 3,
#  ('wormtail', 'voldemort'): 3,
#  ('wormtail', 'unknown man'): 1,
#  ('voldemort', 'unknown man'): 1,
#  ('hermione', 'arthur'): 2,
#  ('hermione', 'amos'): 1,
#  ('hermione', 'cedric'): 2,
#  ('harry potter', 'arthur'): 4,
#  ('harry potter', 'amos'): 2,
#  ('harry potter', 'cedric'): 5,
#  ('ron', 'arthur'): 3,
#  ('ron', 'amos'): 1,
#  ('ron', 'cedric'): 2,
#  ('arthur', 'amos'): 1,
#  ('arthur', 'cedric'): 1,
#  ('arthur', 'fred'): 3,
#  ('arthur', 'george'): 3,
#  ('amos', 'cedric'): 1,
#  ('amos', 'fred'): 1,
#  ('amos', 'george'): 1,
#  ('cedric', 'fred'): 1,
#  ('cedric', 'george'): 1,
#  ('arthur', 'twins'): 1,
#  ('twins', 'harry potter'): 2,
#  ('ron', 'lucius'): 2,
#  ('ron', 'weasleys'): 1,
#  ('lucius', 'draco'): 2,
#  ('lucius', 'arthur'): 1,
#  ('lucius', 'george'): 1,
#  ('lucius', 'fred'): 1,
#  ('lucius', 'weasleys'): 1,
#  ('draco', 'arthur'): 1,
#  ('draco', 'fred'): 1,
#  ('draco', 'weasleys'): 1,
#  ('arthur', 'weasleys'): 1,
#  ('george', 'weasleys'): 1,
#  ('fred', 'weasleys'): 1,
#  ('announcer', 'ron'): 1,
#  ('announcer', 'ginny'): 1,
#  ('announcer', 'twins'): 1,
#  ('announcer', 'boys'): 1,
#  ('announcer', 'fred'): 1,
#  ('ron', 'twins'): 2,
#  ('ron', 'boys'): 1,
#  ('ginny', 'twins'): 1,
#  ('ginny', 'boys'): 1,
#  ('twins', 'boys'): 1,
#  ('twins', 'fred'): 2,
#  ('boys', 'fred'): 1,
#  ('ron', 'barty'): 3,
#  ('harry potter', 'barty'): 5,
#  ('arthur', 'barty'): 1,
#  ('barty', 'hermione'): 4,
#  ('lady offscreen', 'lady'): 1,
#  ('lady offscreen', 'ron'): 1,
#  ('lady offscreen', 'harry potter'): 1,
#  ('lady offscreen', 'cho'): 1,
#  ('lady offscreen', 'hermione'): 1,
#  ('lady', 'ron'): 1,
#  ('lady', 'harry potter'): 1,
#  ('lady', 'cho'): 1,
#  ('lady', 'hermione'): 1,
#  ('ron', 'cho'): 3,
#  ('harry potter', 'cho'): 8,
#  ('cho', 'hermione'): 4,
#  ('hagrid', 'student'): 1,
#  ('hagrid', 'igor'): 1,
#  ('harry potter', 'student'): 1,
#  ('harry potter', 'igor'): 4,
#  ('albus dumbledore', 'student'): 1,
#  ('albus dumbledore', 'igor'): 3,
#  ('student', 'ron'): 1,
#  ('student', 'igor'): 1,
#  ('ron', 'igor'): 1,
#  ('madame maxime', 'albus dumbledore'): 2,
#  ('man', 'albus dumbledore'): 2,
#  ('man', 'mad-eye'): 2,
#  ('man', 'pupil'): 1,
#  ('man', 'barty'): 2,
#  ('albus dumbledore', 'fred'): 2,
#  ('albus dumbledore', 'mad-eye'): 9,
#  ('albus dumbledore', 'pupil'): 1,
#  ('albus dumbledore', 'barty'): 5,
#  ('albus dumbledore', 'george'): 2,
#  ('fred', 'mad-eye'): 3,
#  ('fred', 'pupil'): 1,
#  ('fred', 'barty'): 2,
#  ('ron', 'mad-eye'): 8,
#  ('ron', 'pupil'): 2,
#  ('hermione', 'mad-eye'): 7,
#  ('hermione', 'pupil'): 2,
#  ('mad-eye', 'pupil'): 2,
#  ('mad-eye', 'harry potter'): 13,
#  ('mad-eye', 'barty'): 4,
#  ('mad-eye', 'george'): 3,
#  ('pupil', 'harry potter'): 1,
#  ('pupil', 'barty'): 1,
#  ('pupil', 'george'): 1,
#  ('barty', 'george'): 2,
#  ('mad-eye', 'neville'): 3,
#  ('pupil', 'neville'): 1,
#  ('hagrid', 'voice'): 1,
#  ('harry potter', 'madame maxime'): 2,
#  ('madame maxime', 'mad-eye'): 1,
#  ('madame maxime', 'igor'): 1,
#  ('mad-eye', 'igor'): 2,
#  ('barty', 'mcgonagall'): 1,
#  ('barty', 'snape'): 1,
#  ('mcgonagall', 'mad-eye'): 2,
#  ('snape', 'mad-eye'): 2,
#  ('rita', 'harry potter'): 4,
#  ('sir', 'harry potter'): 1,
#  ('sir', 'rita'): 1,
#  ('sir', 'ron'): 1,
#  ('rita', 'ron'): 1,
#  ('hagrid', 'madame maxime'): 1,
#  ('boy', 'cedric'): 1,
#  ('boy', 'mad-eye'): 1,
#  ('cedric', 'draco'): 1,
#  ('cedric', 'mad-eye'): 2,
#  ('cedric', 'mcgonagall'): 1,
#  ('draco', 'mad-eye'): 1,
#  ('hermione', 'rita'): 2,
#  ('hermione', 'viktor'): 2,
#  ('harry potter', 'viktor'): 2,
#  ('rita', 'viktor'): 1,
#  ('rita', 'albus dumbledore'): 1,
#  ('rita', 'barty'): 1,
#  ('viktor', 'albus dumbledore'): 1,
#  ('viktor', 'barty'): 1,
#  ('hermione', 'nigel'): 2,
#  ('nigel', 'ron'): 2,
#  ('nigel', 'harry potter'): 2,
#  ('nigel', 'ginny'): 2,
#  ('mcgonagall', 'fred'): 1,
#  ('mcgonagall', 'twins'): 1,
#  ('harry potter', 'patils'): 1,
#  ('girl', 'patils'): 1,
#  ('hermione', 'patils'): 1,
#  ('ron', 'patils'): 1,
#  ('elsewhere', 'ron'): 1,
#  ('elsewhere', 'harry potter'): 1,
#  ('harry potter', 'parvati'): 1,
#  ('harry potter', 'padma'): 1,
#  ('ron', 'padma'): 1,
#  ('parvati', 'mcgonagall'): 1,
#  ('parvati', 'padma'): 1,
#  ('mcgonagall', 'padma'): 1,
#  ('padma', 'hermione'): 1,
#  ('hermione', 'nightmare sequence'): 1,
#  ('hermione', 'voldemort'): 1,
#  ('nightmare sequence', 'voldemort'): 1,
#  ('nightmare sequence', 'neville'): 1,
#  ('voldemort', 'neville'): 2,
#  ('harry potter', 'myrtle'): 1,
#  ('harry potter', 'voice singing'): 1,
#  ('myrtle', 'voice singing'): 1,
#  ('seamus', 'friend'): 1,
#  ('friend', 'neville'): 1,
#  ('harry potter', 'merperson'): 1,
#  ('albus dumbledore', 'fleur'): 1,
#  ('barty', 'fleur'): 1,
#  ('fleur', 'ron'): 5,
#  ('fleur', 'hermione'): 5,
#  ('fleur', 'harry potter'): 5,
#  ('fleur', 'fred'): 2,
#  ('fleur', 'george'): 2,
#  ('fleur', 'mad-eye'): 2,
#  ('mad-eye', 'hagrid'): 3,
#  ('fudge', 'mad-eye'): 1,
#  ('harry potter', 'barty jr'): 2,
#  ('harry potter', 'gahhhh!'): 1,
#  ('man', 'igor'): 1,
#  ('man', 'barty jr'): 1,
#  ('man', 'gahhhh!'): 1,
#  ('barty', 'igor'): 1,
#  ('barty', 'barty jr'): 1,
#  ('barty', 'gahhhh!'): 1,
#  ('igor', 'barty jr'): 1,
#  ('igor', 'gahhhh!'): 1,
#  ('mad-eye', 'barty jr'): 2,
#  ('mad-eye', 'gahhhh!'): 1,
#  ('albus dumbledore', 'barty jr'): 2,
#  ('albus dumbledore', 'gahhhh!'): 1,
#  ('barty jr', 'gahhhh!'): 1,
#  ('igor', 'snape'): 1,
#  ('albus dumbledore', 'cedric'): 1,
#  ('cedric', 'voldemort'): 1,
#  ('cedric', 'wormtail'): 1,
#  ('cedric', 'lucius'): 1,
#  ('cedric', "harry's dad"): 1,
#  ('cedric', "harry's mother"): 1,
#  ('harry potter', 'wormtail'): 2,
#  ('harry potter', 'lucius'): 4,
#  ('harry potter', "harry's dad"): 1,
#  ('harry potter', "harry's mother"): 1,
#  ('voldemort', 'lucius'): 2,
#  ('voldemort', "harry's dad"): 1,
#  ('voldemort', "harry's mother"): 1,
#  ('wormtail', 'lucius'): 2,
#  ('wormtail', "harry's dad"): 1,
#  ('wormtail', "harry's mother"): 1,
#  ('lucius', "harry's dad"): 1,
#  ('lucius', "harry's mother"): 1,
#  ("harry's dad", "harry's mother"): 1,
#  ('albus dumbledore', 'amos'): 1,
#  ('fudge', 'amos'): 1,
#  ('mad-eye', 'alastor'): 1,
#  ('harry potter', 'alastor'): 1,
#  ('albus dumbledore', 'alastor'): 1,
#  ('alastor', 'snape'): 1,
#  ('alastor', 'barty jr'): 1,
#  ('snape', 'barty jr'): 1,
#  ('viktor', 'fleur'): 1,
#  ('viktor', 'ron'): 1,
#  ('dudley', 'gang thug #1'): 1,
#  ('dudley', 'mrs. figg'): 1,
#  ('dudley', 'gang member #3'): 1,
#  ('dudley', 'i said, do you understand? !'): 1,
#  ('dudley', '(v.o.)'): 1,
#  ('dudley', 'lily potter'): 1,
#  ('dudley', 'moody'): 1,
#  ('dudley', 'lupin'): 1,
#  ('dudley', 'tonks'): 1,
#  ('dudley', 'kingsley'): 1,
#  ('gang thug #1', 'harry potter'): 1,
#  ('gang thug #1', 'mrs. figg'): 1,
#  ('gang thug #1', 'gang member #3'): 1,
#  ('gang thug #1', 'i said, do you understand? !'): 1,
#  ('gang thug #1', '(v.o.)'): 1,
#  ('gang thug #1', 'lily potter'): 1,
#  ('gang thug #1', 'vernon'): 1,
#  ('gang thug #1', 'petunia'): 1,
#  ('gang thug #1', 'moody'): 1,
#  ('gang thug #1', 'lupin'): 1,
#  ('gang thug #1', 'tonks'): 1,
#  ('gang thug #1', 'kingsley'): 1,
#  ('harry potter', 'mrs. figg'): 2,
#  ('harry potter', 'gang member #3'): 1,
#  ('harry potter', 'i said, do you understand? !'): 1,
#  ('harry potter', '(v.o.)'): 2,
#  ('harry potter', 'lily potter'): 2,
#  ('harry potter', 'moody'): 1,
#  ('harry potter', 'lupin'): 10,
#  ('harry potter', 'tonks'): 5,
#  ('harry potter', 'kingsley'): 1,
#  ('mrs. figg', 'gang member #3'): 1,
#  ('mrs. figg', 'i said, do you understand? !'): 1,
#  ('mrs. figg', '(v.o.)'): 1,
#  ('mrs. figg', 'lily potter'): 1,
#  ('mrs. figg', 'vernon'): 1,
#  ('mrs. figg', 'petunia'): 1,
#  ('mrs. figg', 'moody'): 1,
#  ('mrs. figg', 'lupin'): 1,
#  ('mrs. figg', 'tonks'): 1,
#  ('mrs. figg', 'kingsley'): 1,
#  ('gang member #3', 'i said, do you understand? !'): 1,
#  ('gang member #3', '(v.o.)'): 1,
#  ('gang member #3', 'lily potter'): 1,
#  ('gang member #3', 'vernon'): 1,
#  ('gang member #3', 'petunia'): 1,
#  ('gang member #3', 'moody'): 1,
#  ('gang member #3', 'lupin'): 1,
#  ('gang member #3', 'tonks'): 1,
#  ('gang member #3', 'kingsley'): 1,
#  ('i said, do you understand? !', '(v.o.)'): 1,
#  ('i said, do you understand? !', 'lily potter'): 1,
#  ('i said, do you understand? !', 'vernon'): 1,
#  ('i said, do you understand? !', 'petunia'): 1,
#  ('i said, do you understand? !', 'moody'): 1,
#  ('i said, do you understand? !', 'lupin'): 1,
#  ...}

# %%
dict(sorted(scene_interactions.iteritems(), key=operator.itemgetter(1), reverse=True)[:5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-12a26783f5bd> in <module>
# ----> 1 dict(sorted(scene_interactions.iteritems(), key=operator.itemgetter(1), reverse=True)[:5])
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
dict(sorted(scene_interactions.items(), key=lambda x: x[1]['score'], reverse=True)[:2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-f254124435f4> in <module>
# ----> 1 dict(sorted(con_str.items(), key=lambda x: x[1]['score'], reverse=True)[:2])
#
# <ipython-input-107-f254124435f4> in <lambda>(x)
# ----> 1 dict(sorted(con_str.items(), key=lambda x: x[1]['score'], reverse=True)[:2])
#
# TypeError: 'int' object is not subscriptable

# %%
df_store = df[df.movie_nr == movie].groupby(['scene_id','movie_nr'])['character'].unique()
df_store
# Out:
# scene_id  movie_nr
# 1         1           [dumbledore, mcgonagall, hagrid, petunia, dudl...
# 2         1                                           [petunia, vernon]
# 3         1                [dudley, vernon, harry, snake, man, petunia]
# 4         1                                    [petunia, harry, vernon]
# 5         1                                     [vernon, dudley, harry]
#                                             ...
# 65        1                                [harry, quirrell, voldemort]
# 66        1                                         [dumbledore, harry]
# 67        1                                      [harry, ron, hermione]
# 68        1           [dumbledore, students, draco, harry, hermione,...
# 69        1                                   [hagrid, hermione, harry]
# Name: character, Length: 66, dtype: object

# %%
df_store = df[df.movie_nr == movie].groupby(['scene_desc','movie_nr'])['character'].unique()
# Out:
# scene_desc                                                                                                                                                                                                                     movie_nr
# (Cheering)                                                                                                                                                                                                                     1                             [mcgonagall]
# A couple look at Hagrid.                                                                                                                                                                                                       1                                 [hagrid]
# A girl, HERMIONE GRANGER, with bushy brown hair appears at the doorway.                                                                                                                                                        1                          [hermione, ron]
# A house, on a rock island somewhere out at sea. The family is sleeping, with Harry on the cold, dirt floor. He has drawn a birthday cake which reads, Happy Birthday Harry. Harry looks at Dudley's watch, which beeps 12:00.  1                                  [harry]
# A large, tubby boy, DUDLEY DURSLEY, suddenly comes running down the stairs above the closet. He stops half-way down and goes back, jumping on the staircase.                                                                   1                                 [dudley]
#                                                                                                                                                                                                                                                         ...
# {The boys shrug.} Dumbledore! As long as Dumbledore's around, you're safe. As long as Dumbledore's around, you can't be touched. {Harry smiles slightly.}Some time later. In the outdoor courtyard. The three are walking.     1           [hermione, ron, harry, hagrid]
# {They all come into Hagrid's small hut.}                                                                                                                                                                                       1                [harry, hagrid, hermione]
# {They open it.}                                                                                                                                                                                                                1                             [harry, ron]
# {Zap. Nothing happens. Ron shrugs.}                                                                                                                                                                                            1                  [hermione, ron, hagrid]
# {meow}                                                                                                                                                                                                                         1                             [ron, harry]
# Name: character, Length: 238, dtype: object

# %%
# con_scene_desc = dict()
# for movie in df.movie_nr:
movie = 1
# df_names = df['character'].unique()
df_store = df[df.movie_nr == movie].groupby(['scene_desc','movie_nr'])['character'].unique()

scene_interactions = dict()
for movie in df.movie_nr:
    df_movie = df[df.movie_nr == movie]
    for scene in df_scene:
        for idx in range(len(scene)-1):
            for idx2 in range(idx+1,len(scene)):
                if (scene[idx],scene[idx2]) in scene_interactions:
                    scene_interactions[(scene[idx],scene[idx2])] += 1
                else:
                    if (scene[idx2],scene[idx]) in scene_interactions:
                        scene_interactions[(scene[idx2],scene[idx])] += 1
                    else:
                        scene_interactions[(scene[idx],scene[idx2])] = 1
scene_interactions
# Out:
# {('hermione', 'ron'): 35,
#  ('quirrell', 'hagrid'): 1,
#  ('quirrell', 'harry'): 5,
#  ('hagrid', 'harry'): 25,
#  ('ron', 'mcgonagall'): 6,
#  ('harry', 'ron'): 48,
#  ('man', 'snape'): 1,
#  ('man', 'ron'): 1,
#  ('man', 'hagrid'): 1,
#  ('snape', 'ron'): 3,
#  ('snape', 'hagrid'): 1,
#  ('ron', 'hagrid'): 8,
#  ('woman', 'ron'): 2,
#  ('woman', 'harry'): 1,
#  ('harry', 'hermione'): 34,
#  ('dumbledore', 'harry'): 3,
#  ('woman', 'percy'): 1,
#  ('woman', 'girl'): 1,
#  ('percy', 'girl'): 3,
#  ('percy', 'ron'): 4,
#  ('girl', 'ron'): 3,
#  ('flitwick', 'harry'): 2,
#  ('flitwick', 'ron'): 1,
#  ('mcgonagall', 'quirrell'): 2,
#  ('mcgonagall', 'nick'): 1,
#  ('mcgonagall', 'harry'): 5,
#  ('quirrell', 'nick'): 1,
#  ('quirrell', 'ron'): 2,
#  ('nick', 'ron'): 3,
#  ('nick', 'harry'): 1,
#  ('draco', 'harry'): 8,
#  ('snake', 'harry'): 1,
#  ('dudley', 'harry'): 6,
#  ('dumbledore', 'mcgonagall'): 5,
#  ('dumbledore', 'hermione'): 2,
#  ('dumbledore', 'ron'): 1,
#  ('mcgonagall', 'hermione'): 4,
#  ('filch', 'hermione'): 2,
#  ('filch', 'ron'): 2,
#  ('filch', 'harry'): 2,
#  ('filch', 'all'): 1,
#  ('hermione', 'all'): 2,
#  ('ron', 'all'): 1,
#  ('harry', 'all'): 2,
#  ('harry', 'lee'): 1,
#  ('harry', 'gryffindors'): 1,
#  ('lee', 'gryffindors'): 1,
#  ('fred', 'ron'): 1,
#  ('fred', 'george'): 2,
#  ('fred', 'harry'): 1,
#  ('fred', 'hermione'): 1,
#  ('ron', 'george'): 1,
#  ('george', 'harry'): 1,
#  ('george', 'hermione'): 1,
#  ('hagrid', 'all'): 3,
#  ('hagrid', 'dudley'): 3,
#  ('all', 'dudley'): 2,
#  ('harry', 'vernon'): 5,
#  ('harry', 'petunia'): 4,
#  ('vernon', 'petunia'): 5,
#  ('vernon', 'hagrid'): 2,
#  ('petunia', 'hagrid'): 2,
#  ('hermione', 'hagrid'): 9,
#  ('boy', 'harry'): 2,
#  ('boy', 'hagrid'): 1,
#  ('firenze', 'harry'): 1,
#  ('harry', 'man'): 1,
#  ('lee', 'hooch'): 2,
#  ('lee', 'all'): 1,
#  ('lee', 'draco'): 1,
#  ('lee', 'hagrid'): 2,
#  ('lee', 'hermione'): 1,
#  ('lee', 'mcgonagall'): 1,
#  ('hooch', 'all'): 1,
#  ('hooch', 'draco'): 3,
#  ('hooch', 'hagrid'): 1,
#  ('hooch', 'hermione'): 3,
#  ('hooch', 'mcgonagall'): 1,
#  ('all', 'draco'): 1,
#  ('all', 'mcgonagall'): 1,
#  ('draco', 'hagrid'): 2,
#  ('draco', 'hermione'): 4,
#  ('draco', 'mcgonagall'): 2,
#  ('hagrid', 'mcgonagall'): 1,
#  ('harry', 'oliver'): 2,
#  ('hagrid', 'oliver'): 1,
#  ('harry', 'frog'): 1,
#  ('ron', 'frog'): 1,
#  ('harry', 'trainmaster'): 1,
#  ('quirrell', 'snape'): 1,
#  ('voldemort', 'harry'): 3,
#  ('harry', 'hooch'): 4,
#  ('draco', 'ron'): 2,
#  ('hooch', 'ron'): 1,
#  ('filch', 'hagrid'): 1,
#  ('filch', 'draco'): 1,
#  ('vernon', 'dudley'): 4,
#  ('neville', 'hooch'): 3,
#  ('neville', 'girl'): 3,
#  ('neville', 'draco'): 1,
#  ('neville', 'harry'): 6,
#  ('hooch', 'girl'): 2,
#  ('girl', 'draco'): 1,
#  ('girl', 'harry'): 3,
#  ('snape', 'harry'): 4,
#  ('hermione', 'flitwick'): 1,
#  ('neville', 'mcgonagall'): 1,
#  ('neville', 'students'): 1,
#  ('neville', 'boy'): 1,
#  ('hooch', 'students'): 1,
#  ('hooch', 'boy'): 1,
#  ('girl', 'students'): 1,
#  ('girl', 'boy'): 2,
#  ('students', 'boy'): 1,
#  ('students', 'harry'): 2,
#  ('seamus', 'hermione'): 1,
#  ('seamus', 'neville'): 1,
#  ('seamus', 'harry'): 2,
#  ('seamus', 'hooch'): 1,
#  ('seamus', 'class'): 1,
#  ('hermione', 'neville'): 2,
#  ('hermione', 'class'): 1,
#  ('neville', 'class'): 1,
#  ('harry', 'class'): 1,
#  ('hooch', 'class'): 1,
#  ('harry', 'percy'): 3,
#  ('girl', 'nick'): 1,
#  ('girl', 'hermione'): 1,
#  ('percy', 'nick'): 1,
#  ('percy', 'hermione'): 1,
#  ('nick', 'hermione'): 1,
#  ('percy', 'boy'): 1,
#  ('dudley', 'petunia'): 2,
#  ('quirrell', 'voldemort'): 1,
#  ('hermione', 'quirrell'): 1,
#  ('seamus', 'ron'): 1,
#  ('snape', 'hermione'): 2,
#  ('hermione', 'firenze'): 1,
#  ('hagrid', 'firenze'): 1,
#  ('flint', 'crowd'): 1,
#  ('percy', 'neville'): 1,
#  ('neville', 'ron'): 2,
#  ('mcgonagall', 'snape'): 1,
#  ('goblin', 'hagrid'): 1,
#  ('dumbledore', 'girl'): 1,
#  ('dumbledore', 'boy'): 1,
#  ('hagrid', 'dumbledore'): 1,
#  ('ollivander', 'harry'): 1,
#  ('students', 'draco'): 1,
#  ('students', 'dumbledore'): 1,
#  ('students', 'hermione'): 1,
#  ('draco', 'dumbledore'): 1,
#  ('griphook', 'harry'): 1,
#  ('griphook', 'hagrid'): 1,
#  ('hagrid', 'tom'): 1,
#  ('oiiver', 'harry'): 1,
#  ('oiiver', 'oliver'): 1,
#  ('snape', 'neville'): 1,
#  ('flitwick', 'draco'): 1}

# %%
df[df.sentence != ''].character.unique()
# Out:
# array(['dumbledore', 'mcgonagall', 'hagrid', 'petunia', 'dudley',
#        'vernon', 'harry', 'snake', 'man', 'all', 'tom', 'witch',
#        'quirrell', 'boy', 'goblin', 'griphook', 'ollivander',
#        'trainmaster', 'george', 'fred', 'ron', 'woman', 'frog',
#        'hermione', 'neville', 'draco', 'seamus', 'percy', 'nick', 'girl',
#        'snape', 'hooch', 'class', 'students', 'filch', 'oliver',
#        'flitwick', 'oiiver', 'lee', 'gryffindors', 'flint', 'crowd',
#        'firenze', 'voldemort', 'uncle vernon', 'aunt petunia', 'dobby',
#        'mr. mason', 'same scene - later', "closeup - harry's trunk 13b",
#        "insert - fred's foot 13c", 'mrs. weasley', 'ginny', 'mr. weasley',
#        'harry /ron/fred/george', 'mr. borgin', 'lucius malfoy',
#        'aged witch', 'short man', 'gilderoy lockhart', 'guard',
#        'harry /ron', 'albus dumbledore', 'professor sprout',
#        'penelope clearwater', 'nearly headless nick', 'colin',
#        'dean thomas', "at work and it's entirely your",
#        "of line we'll bring you straight", 'dissolve', 'wood', 'voice',
#        'the chamber of secrets has been opened', 'madam pomfrey',
#        "harry's moving pov", 'back to scene',
#        'young girl comes racing out of the wall. face to face',
#        'moaning myrtle', 'justin finch-fletchley',
#        'justin-finch-fletchley', 'ernie', 'hannah', 'sorting hat',
#        'closeup - the potion', 'tom riddle', 'young hagrid', 'riddle',
#        'harry /ron/hermione', 'fudge', 'aragog', 'lucious malfoy',
#        "harry's room -— same time - middle of the night 2",
#        'harry potter', 'aunt marge', 'stan shunpike', 'disheveled wizard',
#        'shrunken head', 'cornelius fudge', 'young witch', 'hermione/ron',
#        'closeup - a dog-eared clipping', 'arthur weasley',
#        'harry /hermione/ron', 'professor lupin', 'professor trelawney',
#        'teacup - detail - later', 'parvati', 'lavender', 'pansy',
#        'lavendar', 'bem', 'bem,', 'fat lady',
#        'montage - securing the castle - night 58', 'sir cadogan',
#        "intercut harry's pov", 'in the stands', "harry's pov",
#        'fred/george', 'crates. huge rolling bins. a wood staircase. a',
#        'action — day', 'madam rosmerta', 'shrunken head #1', 'day',
#        "insert - marauder's map", 'himself', 'closeup - crystal ball',
#        'harry, ron and hermione', 'afternoon',
#        "harry and hermione's pov - the branches overhead", 'sirius black',
#        'pettigrew', 'moving pov', 'old man', 'wormtail', 'unknown man',
#        'arthur', 'amos', 'cedric', 'twins', 'lucius', 'weasleys',
#        'announcer', 'boys', 'barty', 'lady offscreen', 'lady', 'cho',
#        'student', 'igor', 'madame maxime', 'mad-eye', 'pupil', 'rita',
#        'sir', 'viktor', 'nigel', 'patils', 'padma', 'voldermort',
#        'myrtle', 'voice singing', 'friend', 'merperson', 'fleur',
#        'barty jr', "harry's dad", "harry's mother", 'alastor',
#        'gang thug #1', 'mrs. figg', 'gang member #3',
#        'i said, do you understand? !', '(v.o.)', 'lily potter', 'moody',
#        'lupin', 'tonks', 'kingsley', 'mrs. black', 'sirius', 'mrs black',
#        'mrs weasley', 'hermione!', '(more )', 'mr weasley', 'phonebooth.',
#        'female volce', 'female voice', 'perkins', 'susan bones', 'figg',
#        'umbridge', 'fred, george, and ginny', '(more)', 'kreacher',
#        'luna lovegood', 'luna', 'dumbledore (cont’d)', 'dean',
#        'mcgonogall', 'angelina', 'gryffindor common room.',
#        'int, gryffindor common room - day', '(v.o. )', 'malfoy', 'so...',
#        'trelawney', 'trelawne y',
#        'macmillan, justin finch-fletchely, hannah abbott, anthony',
#        'zachartias', 'justin finch-fletchly', 'michael corner',
#        'lee jordan', 'd.a.?', 'slytherins', 'madam hooch', '(v.o0.)',
#        'rom', 'zachartas', 'peril.”', 'everard', 'dilys', 'phineas',
#        'lockhart', 'healer', 'mrs. longbottom', 'sirus', 'no!', 'grawp',
#        'bane', 'james', 'lily evens', 'professor tofty', 'hawlish',
#        'cowards !', 'professor marchbanks', 'golden orbs.',
#        'fred and george', 'itn. umbridge’s office - day', 'crucio!',
#        'magorian', 'centaur', 'centaur #2', 'grawp want haggar!',
#        'fountain.', 'candles.', 'bellatrix', 'now!', 'run!',
#        'death eater', 'liar!', 'i’ll kill you!!', 'harry /voldemort',
#        'nearly-headless nick', 'narcissa', 'new angle —- moments later',
#        'waitress', 'armchatr', 'slughorn', 'ron/hermione/mrs. weasley',
#        'shopping bag —- day', 'fred / george', 'lavender brown',
#        'new angle —- shop front —- moments later',
#        'new angle —- another alley —- dusk',
#        'new angle - other alleys - dusk',
#        'new angle -—- borgin & burkes - back courtyard - dusk', 'blaise',
#        '... strange moving pov - half red/half blue', 'o.w.l. -',
#        'katie bell', 'montage begins',
#        'the light shifts one last time. the vial glimmers like',
#        'another angle', 'wool’ §s orphanage', 'mrs. cole',
#        'new angle -—- corridor outside tom riddle’s room', 'cormac',
#        'begin montage', 'skinny kid', 'leanne', 'marcus belby',
#        'close on the hourglass', 'closeup - quaffle', 'night',
#        'new angle —- behind large rectangular mass', 'eldred worple',
#        'waiter', 'walter', 'new angle —- party —- same time',
#        'wider angle', 'arthur’s pov - lupin’s hand', 'new angle',
#        'new angles', 'greyback', 'new angle —- seconds later',
#        'ginny /harry', 'new angle —- behind vanishing cabinet',
#        'hermione /ron', 'hagrid/slughorn',
#        'new angle (small island ) —- moments later',
#        'new angle - underwater', 'new angle - the surface',
#        'new angle —- underwater', 'new angle —- harry', '+ + + + hf',
#        'the end', 'mrs. granger', 'mr. granger', 'television', 'radio',
#        'narcissa malfoy', 'yaxley', 'squat man', 'thicknesse', 'charity',
#        'shacklebolt', 'bill', 'mundungus', 'voldemont', 'scrimgeour',
#        'xenophilius lovegood', 'elphias doge', 'muriel', 'patronus',
#        'waltress', 'death eater #2',
#        'young hogwarts students -- james potter, sirius black,',
#        'letter (lily)', 'reg cattermole/ron', 'mafalda hopkirk/hermione',
#        'albert runcorn/harry', 'skinny wizard', 'balding wizard',
#        'female', 'young wizard', 'percy weasley', 'red-haired witch',
#        'bespectacled wizard',
#        'head of the muggle-born registration commission', 'morning',
#        'wakinda', 'scared man', 'mary cattermole', 'muttering wizard',
#        'reg cattermole', 'gregorovitch', 'scabior',
#        'new angle —- graveyard', 'new angle —- tombstones',
#        'james potter lily potter', 'same time - night',
#        'bathilda bagshot', 'action - night', 'riddle-harry',
#        'riddle-hermione', 'riddle-—harry', 'harry / hermione',
#        'dozens die as death eaters attack, harry in hiding, where',
#        'harry/ron/hermione', 'hermione/ron harry', 'ron hermione',
#        'grindelwald', 'snatcher', 'fenrir greyback', 'brown',
#        'closeup - linked hands - moments later', 'warlock', 'aged goblin',
#        'tall goblin', 'bogrod',
#        'into camera, eyes dark, the surface of his skin trembling',
#        'death eater #1', 'aberforth', '+ + + hf', 'alecto carrow',
#        'pansy parkinson', 'madam sprout', 'teachers',
#        'kingsley shacklebolt', 'the grey lady',
#        'their pov — an empty corridor', 'goyle', 'new angle - high',
#        'new angle —- ground level', 'if we die for them, i’ll kill you,',
#        'their pov', 'petunia evans', 'young snape', 'lily evans',
#        'oliver wood', 'young girl', 'james potter',
#        'new angle - harry and dumbledore', 'new angle —- neville - night',
#        'close on the peak of a hat', 'harry’s pov of neville',
#        'new angle - nagini - moving', 'new angle - lower stair',
#        'blurry pov', 'new angle —- harry and voldemort', 'older harry',
#        'older hermione', 'albus'], dtype=object)

# %%
df[['sentence','movie_nr']][df.character == 'RON/HERMIONE/MRS. WEASLEY']

# %% [markdown]
# # Wordclouds of characters

# %%
#Todo: 
# Make worlcloud for 5 most occuring characters from each house and plot there figure and worldcloud.

# %%
from os import path
from PIL import Image
import os

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
hp_mask = np.array(Image.open(path.join(d, "data/char_images/dobby.jpg")))

# Define the settings and input to the wordclouds - DC
wordcloud_all_books = WordCloud(background_color='white',   
                         width=1000,
                         max_words=2000,
                         height=1000, 
                         colormap="viridis",
                         mask = hp_mask,
                         random_state = 42
                         #contour_width=1, 
                         #contour_color='steelblue'
                        ).generate_from_frequencies(harry_freq)

plt.figure(figsize=(10,10))

plt.imshow(wordcloud_all_books, interpolation='bilinear')
plt.title("Wordcloud for all lines from Dobby", fontsize=18)
plt.axis("off")
plt.tight_layout()

# %%
df.head()
# Out:
#   movie_nr sentence_number   character  \
# 0        1               1  dumbledore
# 1        1               2  mcgonagall
# 2        1               3  dumbledore
# 3        1               4  mcgonagall
# 4        1               5  dumbledore
#
#                                             sentence  \
# 0  I should have known that you would be here...P...
# 1  Good evening, Professor Dumbledore. Are the ru...
# 2   I'm afraid so, Professor. The good, and the bad.
# 3                                       And the boy?
# 4                            Hagrid is bringing him.
#
#                                           scene_desc scene_id  sentence_sent  \
# 0  A neighbourhood on a street called Privet Driv...        1          5.740
# 1  The cat meows, sniffs out and the camera pans ...        1          6.685
# 2  The cat meows, sniffs out and the camera pans ...        1          4.635
# 3  The cat meows, sniffs out and the camera pans ...        1          6.240
# 4  The cat meows, sniffs out and the camera pans ...        1          6.040
#
#    scene_desc_sent  avg_scene_sent  avg_scene_desc_sent
# 0            5.740        5.506538             5.506538
# 1            6.685        5.506538             5.506538
# 2            4.635        5.506538             5.506538
# 3            6.240        5.506538             5.506538
# 4            6.040        5.506538             5.506538

# %%
# function to plot moving average 

def m_avg(values,N): # takes in the values and the N of average (how many values to use)
    size = len(values)
    if size-N < 2:
        return(f'Short list or N too big.')
    else:
        cumsum, moving_aves = [0], []

        for i, x in enumerate(values, 1):
            cumsum.append(cumsum[i-1] + x)
            if i>=N:
                moving_ave = (cumsum[i] - cumsum[i-N])/N
                
                # add the the average vector
                moving_aves.append(moving_ave)
    return(moving_aves)

# %%
# m_avg(df.sent_sentence.dropna(),10)
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
plt.plot(m_avg(df.sentence_sent.dropna(),150))

# %%
df[df.character == 'harry']['sentence']
# Out:
# 21                                     Yes, Aunt Petunia.
# 24                                     Yes, Uncle Vernon.
# 36                                           He's asleep!
# 38      Sorry about him. He doesn't understand what it...
# 39      Can you...hear me? {The snake nods} It's just....
#                               ...
# 7969                       Because it answers to another.
# 7970    When he killed Snape, he thought the wand woul...
# 7971    It was Draco who disarmed Dumbledore that nigh...
# 7973                                    It answers to me.
# 7977                      Well, it wasn’t boring, was it?
# Name: sentence, Length: 1995, dtype: object

# %%
df[df.character == 'sorting hat']
# Out:
#      movie_nr sentence_number    character  \
# 1334        2             520  sorting hat
# 1336        2             522  sorting hat
# 7895        8             791  sorting hat
#
#                                                sentence  \
# 1334                        Bee in your bonnet, Potter?
# 1336  If I put you in the right house? Yes... you we...
# 7895  Don't despair, Longbottom. I put you in Gryffi...
#
#                                              scene_desc scene_id  \
# 1334  McGonagall marches Harry down to an UGLY STONE...       49
# 1336  McGonagall marches Harry down to an UGLY STONE...       49
# 7895  The Sorting Hat. He ponders it, regarding its ...       80
#
#       sentence_sent  scene_desc_sent  avg_scene_sent  avg_scene_desc_sent
# 1334           5.61             5.61        5.311329             5.311329
# 1336           5.54             5.54        5.311329             5.311329
# 7895           5.15             5.15        5.555975             5.555975

# %%
df['character'][df.movie_nr == 1].value_counts()[:20].index.tolist() # get 20 most occuring characters
# Out:
# harry potter        227
# ron                 125
# hermione             90
# hagrid               85
# mcgonagall           31
# albus dumbledore     27
# vernon               22
# quirrell             19
# dudley               18
# neville              14
# draco                14
# hooch                13
# petunia              13
# snape                10
# percy                 9
# lee                   9
# girl                  7
# oliver                6
# voldemort             6
# filch                 5
# Name: character, dtype: int64

# %%
df[df.character == 'nick']
# Out:
#     movie_nr sentence_number character  \
# 254        1             255      nick
# 257        1             258      nick
# 259        1             260      nick
# 261        1             262      nick
# 339        1             340      nick
#
#                                               sentence  \
# 254         Hello! How are you? Welcome to Gryffindor.
# 257  Dismal. Once again, my request to join the hea...
# 259           I prefer Sir Nicholas if you don't mind.
# 261  Like this. {Grabs head and pulls it to the sid...
# 339  Have you heard? Harry Potter's the new Gryffin...
#
#                                             scene_desc scene_id  \
# 254  Ron, having just finished a chicken wing, reac...       21
# 257  Numerous ghosts come pouring from the walls, s...       21
# 259  Numerous ghosts come pouring from the walls, s...       21
# 261  Numerous ghosts come pouring from the walls, s...       21
# 339                 Boy 2: Oh, that was wicked, Harry.       30
#
#      sentence_sent  scene_desc_sent  avg_scene_sent  avg_scene_desc_sent
# 254       7.080000         7.080000         5.60133              5.60133
# 257       4.870000         4.870000         5.60133              5.60133
# 259       5.840000         5.840000         5.60133              5.60133
# 261       5.407500         5.407500         5.60133              5.60133
# 339       6.054286         6.054286         5.44075              5.44075

# %%
# Todo, finish up the moving average plot, set different colors on different movies
df[df.character ==  'aragog']['sentence']
# Out:
# 1573    You do not come from the forest. Your hearts b...
# 1575    Hagrid has never sent men into our hollow before.
# 1577    That's a lie! Hagrid never opend the Chamber o...
# 1579    The monster was born in the castle. I came fro...
# 1582    We do not speak of it! It is an ancient creatu...
# 1584    I never saw any part of the castle but the cup...
# 1587    Go? I think not. My sons and daughters do not ...
# 2559    You do not come from the forest. Your hearts b...
# 2561    Hagrid has never sent men into our hollow before.
# 2563    That's a lie! Hagrid never opend the Chamber o...
# 2565    The monster was born in the castle. I came fro...
# 2568    We do not speak of it! It is an ancient creatu...
# 2570    I never saw any part of the castle but the cup...
# 2573    Go? I think not. My sons and daughters do not ...
# Name: sentence, dtype: object

# %%
sentiments['die']
# Out:
# 1.74
